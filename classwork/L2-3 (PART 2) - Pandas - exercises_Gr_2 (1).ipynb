# %% [markdown]
# # ლექცია 2:
# Pandas ბიბლიოთეკის გაცნობა; მონაცემთა ტიპები;  სვეტებთან და სტრიქონებთან მუშაობა;
# ინდექსირება; ფილტრები, წაშლა, გადალაგება, დალაგება. არითმეტიკული და სტატისტიკური ოპერაციები.

# %%
5+7
# Out:
# 12

# %%
print("Hiii")
# Out:
# Hiii

# %% [markdown]
# # 1. სვეტებთან და სტრიქონებთან მუშაობა

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
person
# Out:
# {'first': 'Corey', 'last': 'Schafer', 'email': 'CoreyMSchafer@gmail.com'}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people
# Out:
# {'first': ['Corey', 'Jane', 'John'],
#  'last': ['Schafer', 'Doe', 'Doe'],
#  'email': ['CoreyMSchafer@gmail.com',
#   'JaneDoe@email.com',
#   'JohnDoe@email.com']}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df['first']
# Out:
# 0    Corey
# 1     Jane
# 2     John
# Name: first, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.iloc[2, 2]
# Out:
# 'JohnDoe@email.com'

# %%
df.iloc[[1,2]]
# Out:
#   first last              email
# 1  Jane  Doe  JaneDoe@email.com
# 2  John  Doe  JohnDoe@email.com

# %%
df.iloc[[1,2], [1,2]]
# Out:
#   last              email
# 1  Doe  JaneDoe@email.com
# 2  Doe  JohnDoe@email.com

# %%
df.iloc[0:2]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[0:2, ['last', 'email']]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df.loc['CoreyMSchafer@gmail.com']
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %%
filt = df['last'] == 'Doe'

# %%
df.loc[filt]
# Out:
#                email first last
# 1  JaneDoe@email.com  Jane  Doe
# 2  JohnDoe@email.com  John  Doe

# %%
# & - and, | - or, ~ - not
filt = (df['last'] == 'Doe') | (df['first']=='Corey')

# %%
filt = df['last'] == 'Doe'

# %%
df.loc[~filt]
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer

# %% [markdown]
# # 1. სვეტებთან და სტრიქონებთან მუშაობა - csv

# %%
import pandas as pd # 1. სვეტებთან და სტრიქონებთან მუშაობა

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
# 7     Less than once per year
# 8  Once a month or more often
# 9  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
# 6  The quality of OSS and closed source software ...
# 7  OSS is, on average, of HIGHER quality than pro...
# 8  The quality of OSS and closed source software ...
# 9  OSS is, on average, of HIGHER quality than pro...
#
#                                           Employment                 Country  \
# 0             Not employed, and not looking for work          United Kingdom
# 1                 Not employed, but looking for work  Bosnia and Herzegovina
# 2                                 Employed full-time                Thailand
# 3                                 Employed full-time           United States
# 4                                 Employed full-time                 Ukraine
# 5                                 Employed full-time                  Canada
# 6  Independent contractor, freelancer, or self-em...                 Ukraine
# 7                 Not employed, but looking for work                   India
# 8                                 Employed full-time             New Zealand
# 9                                 Employed full-time                   India
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7             NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8              No  Some college/university study without earning ...
# 9              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                       UndergradMajor  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                      Web development or web design  ...
# 3  Computer science, computer engineering, or sof...  ...
# 4  Computer science, computer engineering, or sof...  ...
# 5                          Mathematics or statistics  ...
# 6  Another engineering discipline (ex. civil, ele...  ...
# 7  Computer science, computer engineering, or sof...  ...
# 8  Computer science, computer engineering, or sof...  ...
# 9                                                NaN  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2   Just as welcome now as I felt last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
# 5   Just as welcome now as I felt last year
# 6     A lot more welcome now than last year
# 7     A lot more welcome now than last year
# 8   Just as welcome now as I felt last year
# 9  Somewhat less welcome now than last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
# 5  Tech articles written by other developers;Indu...  28.0    Man    No
# 6                                                NaN  42.0    Man    No
# 7  Tech articles written by other developers;Indu...  24.0    Man    No
# 8                                                NaN  23.0    Man    No
# 9  Tech articles written by other developers;Tech...   NaN    NaN   NaN
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
# 5  Straight / Heterosexual                                East Asian
# 6  Straight / Heterosexual              White or of European descent
# 7  Straight / Heterosexual                                       NaN
# 8                 Bisexual              White or of European descent
# 9                      NaN                                       NaN
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
# 5         No               Too long  Neither easy nor difficult
# 6        Yes  Appropriate in length  Neither easy nor difficult
# 7        NaN  Appropriate in length  Neither easy nor difficult
# 8         No  Appropriate in length  Neither easy nor difficult
# 9        Yes               Too long                   Difficult
#
# [10 rows x 85 columns]

# %%
df.tail(2)
# Out:
#        Respondent MainBranch Hobbyist              OpenSourcer  \
# 88881       88816        NaN       No                    Never
# 88882       88863        NaN      Yes  Less than once per year
#
#                                               OpenSource  \
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country  \
# 88881  Independent contractor, freelancer, or self-em...     NaN
# 88882             Not employed, and not looking for work   Spain
#
#               Student                             EdLevel  \
# 88881             NaN                                 NaN
# 88882  Yes, full-time  Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength SurveyEase
# 88881                    NaN        NaN
# 88882  Appropriate in length       Easy
#
# [2 rows x 85 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
#  14  Age1stCode              87634 non-null  object
#  15  YearsCodePro            74331 non-null  object
#  16  CareerSat               72847 non-null  object
#  17  JobSat                  70988 non-null  object
#  18  MgrIdiot                61159 non-null  object
#  19  MgrMoney                61157 non-null  object
#  20  MgrWant                 61232 non-null  object
#  21  JobSeek                 80555 non-null  object
#  22  LastHireDate            79854 non-null  object
#  23  LastInt                 67155 non-null  object
#  24  FizzBuzz                71344 non-null  object
#  25  JobFactors              79371 non-null  object
#  26  ResumeUpdate            77877 non-null  object
#  27  CurrencySymbol          71392 non-null  object
#  28  CurrencyDesc            71392 non-null  object
#  29  CompTotal               55945 non-null  float64
#  30  CompFreq                63268 non-null  object
#  31  ConvertedComp           55823 non-null  float64
#  32  WorkWeekHrs             64503 non-null  float64
#  33  WorkPlan                68914 non-null  object
#  34  WorkChallenge           68141 non-null  object
#  35  WorkRemote              70284 non-null  object
#  36  WorkLoc                 70055 non-null  object
#  37  ImpSyn                  71779 non-null  object
#  38  CodeRev                 70390 non-null  object
#  39  CodeRevHrs              49790 non-null  float64
#  40  UnitTests               62668 non-null  object
#  41  PurchaseHow             61108 non-null  object
#  42  PurchaseWhat            62029 non-null  object
#  43  LanguageWorkedWith      87569 non-null  object
#  44  LanguageDesireNextYear  84088 non-null  object
#  45  DatabaseWorkedWith      76026 non-null  object
#  46  DatabaseDesireNextYear  69147 non-null  object
#  47  PlatformWorkedWith      80714 non-null  object
#  48  PlatformDesireNextYear  77443 non-null  object
#  49  WebFrameWorkedWith      65022 non-null  object
#  50  WebFrameDesireNextYear  62944 non-null  object
#  51  MiscTechWorkedWith      59586 non-null  object
#  52  MiscTechDesireNextYear  64511 non-null  object
#  53  DevEnviron              87317 non-null  object
#  54  OpSys                   87851 non-null  object
#  55  Containers              85366 non-null  object
#  56  BlockchainOrg           48175 non-null  object
#  57  BlockchainIs            60165 non-null  object
#  58  BetterLife              86269 non-null  object
#  59  ITperson                87141 non-null  object
#  60  OffOn                   86663 non-null  object
#  61  SocialMedia             84437 non-null  object
#  62  Extraversion            87305 non-null  object
#  63  ScreenName              80486 non-null  object
#  64  SOVisit1st              83877 non-null  object
#  65  SOVisitFreq             88263 non-null  object
#  66  SOVisitTo               88086 non-null  object
#  67  SOFindAnswer            87816 non-null  object
#  68  SOTimeSaved             86344 non-null  object
#  69  SOHowMuchTime           68378 non-null  object
#  70  SOAccount               87828 non-null  object
#  71  SOPartFreq              74692 non-null  object
#  72  SOJobs                  88066 non-null  object
#  73  EntTeams                87841 non-null  object
#  74  SOComm                  88131 non-null  object
#  75  WelcomeChange           85855 non-null  object
#  76  SONewContent            69560 non-null  object
#  77  Age                     79210 non-null  float64
#  78  Gender                  85406 non-null  object
#  79  Trans                   83607 non-null  object
#  80  Sexuality               76147 non-null  object
#  81  Ethnicity               76668 non-null  object
#  82  Dependents              83059 non-null  object
#  83  SurveyLength            86984 non-null  object
#  84  SurveyEase              87081 non-null  object
# dtypes: float64(5), int64(1), object(79)
# memory usage: 57.6+ MB

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.ConvertedComp
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
df['ConvertedComp']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
df.Hobbyist.value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.Hobbyist.value_counts(normalize=True)
# Out:
# Yes    0.801694
# No     0.198306
# Name: Hobbyist, dtype: float64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df[['Hobbyist', 'Country', 'Student']]
# Out:
#       Hobbyist                 Country         Student
# 0          Yes          United Kingdom              No
# 1           No  Bosnia and Herzegovina  Yes, full-time
# 2          Yes                Thailand              No
# 3           No           United States              No
# 4          Yes                 Ukraine              No
# ...        ...                     ...             ...
# 88878      Yes                  Canada              No
# 88879       No                     NaN             NaN
# 88880       No                     NaN             NaN
# 88881       No                     NaN             NaN
# 88882      Yes                   Spain  Yes, full-time
#
# [88883 rows x 3 columns]

# %%
df.loc[:,'Hobbyist':'Student']
# Out:
#       Hobbyist                                        OpenSourcer  \
# 0          Yes                                              Never
# 1           No                            Less than once per year
# 2          Yes                                              Never
# 3           No                                              Never
# 4          Yes                         Once a month or more often
# ...        ...                                                ...
# 88878      Yes  Less than once a month but more than once per ...
# 88879       No                                              Never
# 88880       No                                              Never
# 88881       No                                              Never
# 88882      Yes                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
# [88883 rows x 6 columns]

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# ...                                                  ...
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment  \
# 0                 Not employed, and not looking for work
# 1                     Not employed, but looking for work
# 2                                     Employed full-time
# 3                                     Employed full-time
# 4                                     Employed full-time
# ...                                                  ...
# 88878             Not employed, and not looking for work
# 88879                                                NaN
# 88880                                 Employed full-time
# 88881  Independent contractor, freelancer, or self-em...
# 88882             Not employed, and not looking for work
#
#                       Country         Student  \
# 0              United Kingdom              No
# 1      Bosnia and Herzegovina  Yes, full-time
# 2                    Thailand              No
# 3               United States              No
# 4                     Ukraine              No
# ...                       ...             ...
# 88878                  Canada              No
# 88879                     NaN             NaN
# 88880                     NaN             NaN
# 88881                     NaN             NaN
# 88882                   Spain  Yes, full-time
#
#                                                  EdLevel  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 88878                          Primary/elementary school
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 0                                                    NaN  ...
# 1                                                    NaN  ...
# 2                          Web development or web design  ...
# 3      Computer science, computer engineering, or sof...  ...
# 4      Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 0       Just as welcome now as I felt last year
# 1       Just as welcome now as I felt last year
# 2       Just as welcome now as I felt last year
# 3       Just as welcome now as I felt last year
# 4       Just as welcome now as I felt last year
# ...                                         ...
# 88878                                       NaN
# 88879                                       NaN
# 88880                                       NaN
# 88881                                       NaN
# 88882  Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 0      Tech articles written by other developers;Indu...  14.0    Man    No
# 1      Tech articles written by other developers;Indu...  19.0    Man    No
# 2      Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 4      Tech meetups or events in your area;Courses on...  30.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 0      Straight / Heterosexual
# 1      Straight / Heterosexual
# 2      Straight / Heterosexual
# 3      Straight / Heterosexual
# 4      Straight / Heterosexual
# ...                        ...
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# ...                                                  ...        ...
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# ...                      ...                         ...
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [88883 rows x 85 columns]

# %% [markdown]
# # 2. ინდექსირება (csv ფაილი)

# %%
import pandas as pd
# df = pd.read_csv('data/survey_results_public.csv')
# schema_df = pd.read_csv('data/survey_results_schema.csv')
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)  # check

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# Trans                                     Do you identify as transgender?
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...
# Student                 Are you currently enrolled in a formal, degree...
# SocialMedia                   What social media site do you use the most?
# Sexuality               Which of the following do you currently identi...
# ScreenName                                           What do you call it?
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisit1st              To the best of your memory, when did you first...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOPartFreq              How frequently would you say you participate i...
# SONewContent            Would you like to see any of the following on ...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOFindAnswer            On average, how many times a week do you find ...
# SOComm                  Do you consider yourself a member of the Stack...
# SOAccount                           Do you have a Stack Overflow account?
# ResumeUpdate            Think back to the last time you updated your r...
# Respondent              Randomized respondent ID number (not in order ...
# PurchaseWhat            What level of influence do you, personally, ha...
# PurchaseHow             How does your company make decisions about pur...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# OrgSize                 Approximately how many people are employed by ...
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# OpSys                   What is the primary operating system in which ...
# OffOn                         Have you tried turning it off and on again?
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# MgrWant                 Do you want to become a manager yourself in th...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrIdiot                How confident are you that your manager knows ...
# MainBranch              Which of the following options best describes ...
# LastInt                 In your most recent successful job interview (...
# LastHireDate            When was the last time that you took a job wit...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# JobSeek                 Which of the following best describes your cur...
# JobSat                  How satisfied are you with your current job? (...
# JobFactors              Imagine that you are deciding between two job ...
# ImpSyn                  For the specific work you do, and the years of...
# ITperson                 Are you the "IT support person" for your family?
# Hobbyist                                          Do you code as a hobby?
# Gender                  Which of the following do you currently identi...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# Extraversion              Do you prefer online chat or IRL conversations?
# Ethnicity               Which of the following do you identify as? Ple...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# Employment              Which of the following best describes your cur...
# EduOther                Which of the following types of non-degree edu...
# EdLevel                 Which of the following best describes the high...
# DevType                 Which of the following describe you? Please se...
# DevEnviron              Which development environment(s) do you use re...
# Dependents              Do you have any dependents (e.g., children, el...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# Country                         In which country do you currently reside?
# ConvertedComp           Salary converted to annual USD salaries using ...
# Containers              How do you use containers (Docker, Open Contai...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CodeRevHrs              On average, how many hours per week do you spe...
# CodeRev                          Do you review code as part of your work?
# CareerSat               Overall, how satisfied are you with your caree...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# Age1stCode              At what age did you write your first line of c...
# Age                     What is your age (in years)? If you prefer not...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# DevType                 Which of the following describe you? Please se...
# YearsCode               Including any education, how many years have y...
# Age1stCode              At what age did you write your first line of c...
# YearsCodePro            How many years have you coded professionally (...
# CareerSat               Overall, how satisfied are you with your caree...
# JobSat                  How satisfied are you with your current job? (...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# JobSeek                 Which of the following best describes your cur...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# JobFactors              Imagine that you are deciding between two job ...
# ResumeUpdate            Think back to the last time you updated your r...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# ConvertedComp           Salary converted to annual USD salaries using ...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkPlan                          How structured or planned is your work?
# WorkChallenge           Of these options, what are your greatest chall...
# WorkRemote                                How often do you work remotely?
# WorkLoc                                   Where would you prefer to work?
# ImpSyn                  For the specific work you do, and the years of...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# UnitTests               Does your company regularly employ unit tests ...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# DevEnviron              Which development environment(s) do you use re...
# OpSys                   What is the primary operating system in which ...
# Containers              How do you use containers (Docker, Open Contai...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# ITperson                 Are you the "IT support person" for your family?
# OffOn                         Have you tried turning it off and on again?
# SocialMedia                   What social media site do you use the most?
# Extraversion              Do you prefer online chat or IRL conversations?
# ScreenName                                           What do you call it?
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOFindAnswer            On average, how many times a week do you find ...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOAccount                           Do you have a Stack Overflow account?
# SOPartFreq              How frequently would you say you participate i...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# SOComm                  Do you consider yourself a member of the Stack...
# WelcomeChange           Compared to last year, how welcome do you feel...
# SONewContent            Would you like to see any of the following on ...
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following do you currently identi...
# Trans                                     Do you identify as transgender?
# Sexuality               Which of the following do you currently identi...
# Ethnicity               Which of the following do you identify as? Ple...
# Dependents              Do you have any dependents (e.g., children, el...
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...

# %%
df.loc[1:10]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
# 6                                Never
# 7                                Never
# 8              Less than once per year
# 9           Once a month or more often
# 10          Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 6           The quality of OSS and closed source software ...
# 7           The quality of OSS and closed source software ...
# 8           OSS is, on average, of HIGHER quality than pro...
# 9           The quality of OSS and closed source software ...
# 10          OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  \
# Respondent
# 1                      Not employed, and not looking for work
# 2                          Not employed, but looking for work
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 6                                          Employed full-time
# 7           Independent contractor, freelancer, or self-em...
# 8                          Not employed, but looking for work
# 9                                          Employed full-time
# 10                                         Employed full-time
#
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 4                    United States              No
# 5                          Ukraine              No
# 6                           Canada              No
# 7                          Ukraine              No
# 8                            India             NaN
# 9                      New Zealand              No
# 10                           India              No
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                   Mathematics or statistics
# 7           Another engineering discipline (ex. civil, ele...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                                        NaN
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 6           Taken an online course in programming or softw...
# 7           Taught yourself a new language, framework, or ...
# 8           Taught yourself a new language, framework, or ...
# 9           Taken an online course in programming or softw...
# 10                                                        NaN
#
#                                                       OrgSize  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                        100 to 499 employees
# 4                                        100 to 499 employees
# 5                                    10,000 or more employees
# 6                                                         NaN
# 7           Just me - I am a freelancer, sole proprietor, ...
# 8                                                         NaN
# 9                                          10 to 19 employees
# 10                                   10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
# 6           Data or business analyst;Data scientist or mac...        13
# 7                               Designer;Developer, front-end         6
# 8              Developer, back-end;Engineer, site reliability         8
# 9           Database administrator;Developer, back-end;Dev...        12
# 10          Data or business analyst;Data scientist or mac...        12
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 1                  10               NaN                    NaN
# 2                  17               NaN                    NaN
# 3                  22                 1     Slightly satisfied
# 4                  16  Less than 1 year         Very satisfied
# 5                  14                 9      Very dissatisfied
# 6                  15                 3         Very satisfied
# 7                  17                 4     Slightly satisfied
# 8                  16               NaN                    NaN
# 9                  11                 4     Slightly satisfied
# 10                 20                10  Slightly dissatisfied
#
#                                         JobSat              MgrIdiot  \
# Respondent
# 1                                          NaN                   NaN
# 2                                          NaN                   NaN
# 3                           Slightly satisfied  Not at all confident
# 4                           Slightly satisfied        Very confident
# 5                        Slightly dissatisfied    Somewhat confident
# 6                           Slightly satisfied        Very confident
# 7           Neither satisfied nor dissatisfied                   NaN
# 8                                          NaN                   NaN
# 9                           Slightly satisfied    Somewhat confident
# 10                       Slightly dissatisfied    Somewhat confident
#
#             MgrMoney   MgrWant  \
# Respondent
# 1                NaN       NaN
# 2                NaN       NaN
# 3           Not sure  Not sure
# 4                 No  Not sure
# 5                Yes        No
# 6                 No       Yes
# 7                NaN       NaN
# 8                NaN       NaN
# 9                 No  Not sure
# 10               Yes       Yes
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
# 6                I am not interested in new job opportunities
# 7           I’m not actively looking, but I am open to new...
# 8                                                         NaN
# 9           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
#
#                                                  LastHireDate  \
# Respondent
# 1                                                         NaN
# 2                                        I've never had a job
# 3                                               1-2 years ago
# 4                                        Less than a year ago
# 5                                        Less than a year ago
# 6                                               1-2 years ago
# 7           NA - I am an independent contractor or self em...
# 8                                                         NaN
# 9                                        Less than a year ago
# 10                                              3-4 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
# 6           Write any code;Complete a take-home project;In...       No
# 7                                              Write any code       No
# 8                                                         NaN      NaN
# 9           Write any code;Interview with people in peer r...      Yes
# 10                                                        NaN       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
# 6           Financial performance or funding status of the...
# 7           Remote work options;Opportunities for professi...
# 8                                                         NaN
# 9           Financial performance or funding status of the...
# 10          Languages, frameworks, and other technologies ...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
# 6           I heard about a job opportunity (from a recrui...            CAD
# 7                                                         NaN            USD
# 8                                                         NaN            NaN
# 9                            I was preparing for a job search            NZD
# 10                                                        NaN            INR
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
# 6                Canadian dollar    40000.0  Monthly       366420.0
# 7           United States dollar        NaN      NaN            NaN
# 8                            NaN        NaN      NaN            NaN
# 9             New Zealand dollar   138000.0   Yearly        95179.0
# 10                  Indian rupee   950000.0   Yearly        13293.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
# 6                  15.0  There's no schedule or spec; I work on what se...
# 7                  32.0  There is a schedule and/or spec (made by me or...
# 8                   NaN                                                NaN
# 9                  32.0  There is a schedule and/or spec (made by me or...
# 10                 70.0  There's no schedule or spec; I work on what se...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
# 6                                                         NaN
# 7           Being tasked with non-development work;Distrac...
# 8                                                         NaN
# 9           Being tasked with non-development work;Inadequ...
# 10                                                        NaN
#
#                                                    WorkRemote  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                            Less than once per month / Never
# 4                            Less than once per month / Never
# 5                                       A few days each month
# 6                                       A few days each month
# 7           All or almost all the time (I'm full-time remote)
# 8                                                         NaN
# 9                            Less than once per month / Never
# 10                                      A few days each month
#
#                                                    WorkLoc  \
# Respondent
# 1                                                      NaN
# 2                                                      NaN
# 3                                                     Home
# 4                                                     Home
# 5                                                   Office
# 6                                                     Home
# 7           Other place, such as a coworking space or cafe
# 8                                                      NaN
# 9                                                   Office
# 10                                                    Home
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 1                              NaN                                      NaN
# 2                              NaN                                      NaN
# 3                          Average                                       No
# 4           A little below average                                       No
# 5           A little above average  Yes, because I see value in code review
# 6           A little above average                                       No
# 7                          Average  Yes, because I see value in code review
# 8                              NaN                                      NaN
# 9           A little above average  Yes, because I see value in code review
# 10               Far above average  Yes, because I see value in code review
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                          No, but I think we should
# 4                  NaN                          No, but I think we should
# 5                  NaN                      Yes, it's part of our process
# 6                  NaN  Yes, it's not part of our process but the deve...
# 7                  6.0                                                NaN
# 8                  NaN                                                NaN
# 9                 12.0  Yes, it's not part of our process but the deve...
# 10                 4.0                      Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
# 6                                                    Not sure
# 7                                                         NaN
# 8                                                         NaN
# 9                                                    Not sure
# 10                                                        NaN
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
# 6           I have little or no influence
# 7                                     NaN
# 8                                     NaN
# 9                   I have some influence
# 10                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 2                                         C++;HTML/CSS;Python
# 3                                                    HTML/CSS
# 4                                         C;C++;C#;Python;SQL
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 6                                                  Java;R;SQL
# 7                                         HTML/CSS;JavaScript
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 9           Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 10                              C#;Go;JavaScript;Python;R;SQL
#
#                                        LanguageDesireNextYear  \
# Respondent
# 1             C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                                 C++;HTML/CSS;JavaScript;SQL
# 3                                             Elixir;HTML/CSS
# 4                                         C;C#;JavaScript;SQL
# 5                    HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 6                                            Python;Scala;SQL
# 7                                         HTML/CSS;JavaScript
# 8           Bash/Shell/PowerShell;C;C++;Elixir;Erlang;Go;P...
# 9           Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 10                       C#;Go;JavaScript;Kotlin;Python;R;SQL
#
#                                            DatabaseWorkedWith  \
# Respondent
# 1                                                      SQLite
# 2                                                         NaN
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5            Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 6                                          MongoDB;PostgreSQL
# 7                                                         NaN
# 8           Cassandra;Elasticsearch;MongoDB;MySQL;Oracle;R...
# 9                                  DynamoDB;PostgreSQL;SQLite
# 10          Elasticsearch;MongoDB;Microsoft SQL Server;MyS...
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 6                                                  PostgreSQL
# 7                                                         NaN
# 8           Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
# 9                                     PostgreSQL;Redis;SQLite
# 10                 Elasticsearch;MongoDB;Microsoft SQL Server
#
#                                      PlatformWorkedWith  \
# Respondent
# 1                                         MacOS;Windows
# 2                                               Windows
# 3                                                   NaN
# 4                                         Linux;Windows
# 5                     Android;Linux;MacOS;Slack;Windows
# 6           Android;Google Cloud Platform;Linux;Windows
# 7                                         MacOS;Windows
# 8                   AWS;Docker;Heroku;Linux;MacOS;Slack
# 9                   AWS;Docker;Heroku;Linux;MacOS;Slack
# 10                                        Linux;Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1                                     Android;Arduino;Windows
# 2                                                     Windows
# 3                                                         NaN
# 4                                               Linux;Windows
# 5                       Android;Docker;Kubernetes;Linux;Slack
# 6                 Android;Google Cloud Platform;Linux;Windows
# 7                                               MacOS;Windows
# 8           Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 9               AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# 10                         Android;Linux;Raspberry Pi;Windows
#
#                                            WebFrameWorkedWith  \
# Respondent
# 1                                                Django;Flask
# 2                                                      Django
# 3                                                         NaN
# 4                                                         NaN
# 5                 Django;Express;Flask;jQuery;React.js;Spring
# 6                                                         NaN
# 7                                                    React.js
# 8                               Express;Flask;React.js;Spring
# 9                             Express;Ruby on Rails;Other(s):
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 1                                                Flask;jQuery
# 2                                                      Django
# 3                                                   Other(s):
# 4                                                         NaN
# 5                                Flask;jQuery;React.js;Spring
# 6                                                         NaN
# 7                                                    React.js
# 8                        Django;Express;Flask;React.js;Vue.js
# 9                             Express;Ruby on Rails;Other(s):
# 10          Angular/Angular.js;ASP.NET;Django;Express;Flas...
#
#                            MiscTechWorkedWith  \
# Respondent
# 1                                     Node.js
# 2                                         NaN
# 3                                         NaN
# 4                                        .NET
# 5                             Cordova;Node.js
# 6                                      Hadoop
# 7                                         NaN
# 8                       Hadoop;Node.js;Pandas
# 9                            Node.js;Unity 3D
# 10          .NET;Node.js;Pandas;Torch/PyTorch
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 1                                                     Node.js
# 2                                                         NaN
# 3                                                         NaN
# 4                                                        .NET
# 5                    Apache Spark;Hadoop;Node.js;React Native
# 6                           Hadoop;Pandas;TensorFlow;Unity 3D
# 7                                                         NaN
# 8           Ansible;Apache Spark;Chef;Hadoop;Node.js;Panda...
# 9                                                     Node.js
# 10                      .NET;Node.js;TensorFlow;Torch/PyTorch
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 1                                  IntelliJ;Notepad++;PyCharm      Windows
# 2                                                Atom;PyCharm      Windows
# 3                                      Vim;Visual Studio Code  Linux-based
# 4                Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                      IntelliJ;Notepad++;Vim  Linux-based
# 6           Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 7                                                    PHPStorm      Windows
# 8           Atom;IntelliJ;IPython / Jupyter;PyCharm;Visual...  Linux-based
# 9                                                         Vim        MacOS
# 10          Android Studio;Eclipse;IPython / Jupyter;Notep...      Windows
#
#                                                    Containers BlockchainOrg  \
# Respondent
# 1                                     I do not use containers           NaN
# 2                                     I do not use containers           NaN
# 3                                     I do not use containers           NaN
# 4                                     I do not use containers    Not at all
# 5                      Outside of work, for personal projects    Not at all
# 6                                     I do not use containers    Not at all
# 7                                     I do not use containers           NaN
# 8           Development;Testing;Production;Outside of work...           NaN
# 9                              Development;Testing;Production    Not at all
# 10                                                        NaN    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
# 6                                                         NaN         No
# 7           Useful for decentralized currency (i.e., Bitcoin)         No
# 8           Useful across many domains and could change ma...        Yes
# 9                           An irresponsible use of resources         No
# 10          Useful for immutable record keeping outside of...         No
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
# 6                                                Yes    No     YouTube
# 7                                                Yes    No     YouTube
# 8                                               SIGH   Yes     YouTube
# 9                                               SIGH   Yes     Twitter
# 10                                               Yes   Yes     YouTube
#
#                         Extraversion   ScreenName        SOVisit1st  \
# Respondent
# 1                             Online     Username              2017
# 2                             Online     Username              2017
# 3           In real life (in person)     Username              2011
# 4           In real life (in person)     Username              2014
# 5           In real life (in person)     Username  I don't remember
# 6           In real life (in person)        Login              2011
# 7                                NaN          NaN              2014
# 8           In real life (in person)       Handle              2012
# 9           In real life (in person)     Username              2013
# 10                           Neither  Screen Name               NaN
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
# 6           A few times per month or weekly
# 7                     Daily or almost daily
# 8                      A few times per week
# 9                     Daily or almost daily
# 10                   Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
# 6                          Find answers to specific questions
# 7                          Find answers to specific questions
# 8           Find answers to specific questions;Learn how t...
# 9           Find answers to specific questions;Contribute ...
# 10          Find answers to specific questions;Get a sense...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 1                    3-5 times per week      Stack Overflow was much faster
# 2                    3-5 times per week      Stack Overflow was much faster
# 3                   6-10 times per week            They were about the same
# 4                    1-2 times per week      Stack Overflow was much faster
# 5           More than 10 times per week      Stack Overflow was much faster
# 6               Less than once per week  Stack Overflow was slightly faster
# 7                    3-5 times per week                                 NaN
# 8               Less than once per week  Stack Overflow was slightly faster
# 9                    3-5 times per week            They were about the same
# 10                   3-5 times per week            They were about the same
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 1           31-60 minutes        No
# 2           11-30 minutes       Yes
# 3                     NaN       Yes
# 4           31-60 minutes       Yes
# 5                     NaN       Yes
# 6             60+ minutes       Yes
# 7                     NaN       Yes
# 8           11-30 minutes       Yes
# 9                     NaN       Yes
# 10                    NaN       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 1                                                         NaN
# 2                             A few times per month or weekly
# 3                         Less than once per month or monthly
# 4                         Less than once per month or monthly
# 5                             A few times per month or weekly
# 6           I have never participated in Q&A on Stack Over...
# 7                         Less than once per month or monthly
# 8                         Less than once per month or monthly
# 9                         Less than once per month or monthly
# 10                            A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
# 6           No, I knew that Stack Overflow had a job board...
# 7                                                         Yes
# 8                                                         Yes
# 9           No, I knew that Stack Overflow had a job board...
# 10                                                        Yes
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
# 6                         No, and I don't know what those are
# 7                         No, and I don't know what those are
# 8                         No, and I don't know what those are
# 9                         No, and I don't know what those are
# 10                        No, and I don't know what those are
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 1                   Neutral   Just as welcome now as I felt last year
# 2             Yes, somewhat   Just as welcome now as I felt last year
# 3                   Neutral   Just as welcome now as I felt last year
# 4            No, not really   Just as welcome now as I felt last year
# 5           Yes, definitely   Just as welcome now as I felt last year
# 6            No, not really   Just as welcome now as I felt last year
# 7                   Neutral     A lot more welcome now than last year
# 8           Yes, definitely     A lot more welcome now than last year
# 9             Yes, somewhat   Just as welcome now as I felt last year
# 10            Yes, somewhat  Somewhat less welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# 6           Tech articles written by other developers;Indu...  28.0    Man
# 7                                                         NaN  42.0    Man
# 8           Tech articles written by other developers;Indu...  24.0    Man
# 9                                                         NaN  23.0    Man
# 10          Tech articles written by other developers;Tech...   NaN    NaN
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
# 6             No  Straight / Heterosexual
# 7             No  Straight / Heterosexual
# 8             No  Straight / Heterosexual
# 9             No                 Bisexual
# 10           NaN                      NaN
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
# 6                                         East Asian         No
# 7                       White or of European descent        Yes
# 8                                                NaN        NaN
# 9                       White or of European descent         No
# 10                                               NaN        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 7           Appropriate in length  Neither easy nor difficult
# 8           Appropriate in length  Neither easy nor difficult
# 9           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult

# %% [markdown]
# # 3. ფილტრაცია (csv ფაილი)

# %%
df.Country.value_counts()
# Out:
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: Country, Length: 179, dtype: int64

# %%
df.Country.value_counts()['India']
# Out:
# 9061

# %%
df.Country.value_counts().Georgia
# Out:
# 80

# %%
filt = df.Country == 'Georgia'

# %%
df_georgia = df.loc[filt]

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 774                            I am a developer by profession      Yes
# 2019                           I am a developer by profession       No
# 2036                           I am a developer by profession      Yes
# 4703                           I am a developer by profession      Yes
# 4704                           I am a developer by profession      Yes
# 5933                           I am a developer by profession      Yes
# 7464                           I am a developer by profession      Yes
# 8679                              I code primarily as a hobby      Yes
# 9590                           I am a developer by profession       No
# 9657                           I am a developer by profession      Yes
# 10909                          I am a developer by profession      Yes
# 13494                  I am a student who is learning to code      Yes
# 13623                          I am a developer by profession      Yes
# 13780                          I am a developer by profession      Yes
# 14013                          I am a developer by profession      Yes
# 14918                          I am a developer by profession      Yes
# 15096                          I am a developer by profession      Yes
# 15445                          I am a developer by profession      Yes
# 17822                          I am a developer by profession       No
# 19861                          I am a developer by profession       No
# 23808                  I am a student who is learning to code      Yes
# 27617                          I am a developer by profession      Yes
# 28147                          I am a developer by profession      Yes
# 28399                  I am a student who is learning to code      Yes
# 29693                             I code primarily as a hobby      Yes
# 30436                          I am a developer by profession       No
# 31561                             I code primarily as a hobby      Yes
# 32966                          I am a developer by profession       No
# 34021                          I am a developer by profession       No
# 34214                          I am a developer by profession       No
# 35026                  I am a student who is learning to code      Yes
# 37311                          I am a developer by profession      Yes
# 37750                          I am a developer by profession      Yes
# 38074                  I am a student who is learning to code      Yes
# 38974                          I am a developer by profession      Yes
# 42831                          I am a developer by profession      Yes
# 42839                  I am a student who is learning to code      Yes
# 43123                          I am a developer by profession      Yes
# 46536                          I am a developer by profession      Yes
# 47067       I am not primarily a developer, but I write co...      Yes
# 48586                          I am a developer by profession       No
# 49832                  I am a student who is learning to code       No
# 52685                          I am a developer by profession       No
# 52824                          I am a developer by profession      Yes
# 52855                          I am a developer by profession      Yes
# 54612                          I am a developer by profession      Yes
# 55308                          I am a developer by profession      Yes
# 58996       I am not primarily a developer, but I write co...      Yes
# 59330                          I am a developer by profession      Yes
# 60063                          I am a developer by profession      Yes
# 60365                          I am a developer by profession      Yes
# 61831                          I am a developer by profession       No
# 62191                          I am a developer by profession      Yes
# 62834                          I am a developer by profession      Yes
# 64615                          I am a developer by profession       No
# 64990                          I am a developer by profession      Yes
# 66632                          I am a developer by profession      Yes
# 67712                          I am a developer by profession      Yes
# 68956                          I am a developer by profession      Yes
# 71132                          I am a developer by profession       No
# 72347                          I am a developer by profession      Yes
# 72502                  I am a student who is learning to code      Yes
# 72794                          I am a developer by profession      Yes
# 73096                          I am a developer by profession      Yes
# 75985                  I am a student who is learning to code      Yes
# 76170                          I am a developer by profession       No
# 76780                          I am a developer by profession      Yes
# 77272                          I am a developer by profession      Yes
# 80032                  I am a student who is learning to code      Yes
# 80433       I am not primarily a developer, but I write co...      Yes
# 80621                  I am a student who is learning to code      Yes
# 81833                          I am a developer by profession       No
# 82030       I am not primarily a developer, but I write co...      Yes
# 82968       I am not primarily a developer, but I write co...      Yes
# 83079                          I am a developer by profession       No
# 83152                          I am a developer by profession      Yes
# 84099                          I am a developer by profession      Yes
# 87571                          I am a developer by profession      Yes
# 43870                                                     NaN      Yes
# 46303                                                     NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 774                                Once a month or more often
# 2019                               Once a month or more often
# 2036                                                    Never
# 4703                                                    Never
# 4704                                                    Never
# 5933        Less than once a month but more than once per ...
# 7464                                                    Never
# 8679                                                    Never
# 9590        Less than once a month but more than once per ...
# 9657                                  Less than once per year
# 10909                                                   Never
# 13494       Less than once a month but more than once per ...
# 13623                                 Less than once per year
# 13780                                 Less than once per year
# 14013       Less than once a month but more than once per ...
# 14918                                                   Never
# 15096       Less than once a month but more than once per ...
# 15445       Less than once a month but more than once per ...
# 17822       Less than once a month but more than once per ...
# 19861                                                   Never
# 23808                                                   Never
# 27617                                                   Never
# 28147       Less than once a month but more than once per ...
# 28399                                                   Never
# 29693                                                   Never
# 30436                                 Less than once per year
# 31561                                 Less than once per year
# 32966                                                   Never
# 34021                                                   Never
# 34214       Less than once a month but more than once per ...
# 35026                                 Less than once per year
# 37311       Less than once a month but more than once per ...
# 37750       Less than once a month but more than once per ...
# 38074                              Once a month or more often
# 38974       Less than once a month but more than once per ...
# 42831                                                   Never
# 42839                              Once a month or more often
# 43123                                 Less than once per year
# 46536                                 Less than once per year
# 47067                                                   Never
# 48586       Less than once a month but more than once per ...
# 49832       Less than once a month but more than once per ...
# 52685                                                   Never
# 52824                              Once a month or more often
# 52855       Less than once a month but more than once per ...
# 54612                              Once a month or more often
# 55308                                 Less than once per year
# 58996                              Once a month or more often
# 59330                                 Less than once per year
# 60063       Less than once a month but more than once per ...
# 60365                                                   Never
# 61831                                                   Never
# 62191                              Once a month or more often
# 62834                                 Less than once per year
# 64615                                                   Never
# 64990       Less than once a month but more than once per ...
# 66632                                 Less than once per year
# 67712                                                   Never
# 68956                              Once a month or more often
# 71132                                                   Never
# 72347       Less than once a month but more than once per ...
# 72502                                                   Never
# 72794                              Once a month or more often
# 73096                                 Less than once per year
# 75985                              Once a month or more often
# 76170                                                   Never
# 76780       Less than once a month but more than once per ...
# 77272                                                   Never
# 80032       Less than once a month but more than once per ...
# 80433                              Once a month or more often
# 80621       Less than once a month but more than once per ...
# 81833                                                   Never
# 82030                                 Less than once per year
# 82968       Less than once a month but more than once per ...
# 83079                              Once a month or more often
# 83152                              Once a month or more often
# 84099                                                   Never
# 87571                                 Less than once per year
# 43870                                                   Never
# 46303                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 774         The quality of OSS and closed source software ...
# 2019        The quality of OSS and closed source software ...
# 2036        OSS is, on average, of HIGHER quality than pro...
# 4703        OSS is, on average, of HIGHER quality than pro...
# 4704        The quality of OSS and closed source software ...
# 5933        The quality of OSS and closed source software ...
# 7464        OSS is, on average, of LOWER quality than prop...
# 8679        The quality of OSS and closed source software ...
# 9590        OSS is, on average, of HIGHER quality than pro...
# 9657        OSS is, on average, of HIGHER quality than pro...
# 10909       The quality of OSS and closed source software ...
# 13494       The quality of OSS and closed source software ...
# 13623       The quality of OSS and closed source software ...
# 13780       OSS is, on average, of HIGHER quality than pro...
# 14013       OSS is, on average, of HIGHER quality than pro...
# 14918       The quality of OSS and closed source software ...
# 15096       The quality of OSS and closed source software ...
# 15445       The quality of OSS and closed source software ...
# 17822       OSS is, on average, of HIGHER quality than pro...
# 19861       OSS is, on average, of HIGHER quality than pro...
# 23808       The quality of OSS and closed source software ...
# 27617       The quality of OSS and closed source software ...
# 28147       OSS is, on average, of HIGHER quality than pro...
# 28399       The quality of OSS and closed source software ...
# 29693       OSS is, on average, of HIGHER quality than pro...
# 30436                                                     NaN
# 31561       OSS is, on average, of LOWER quality than prop...
# 32966       OSS is, on average, of HIGHER quality than pro...
# 34021       OSS is, on average, of LOWER quality than prop...
# 34214       OSS is, on average, of HIGHER quality than pro...
# 35026       OSS is, on average, of HIGHER quality than pro...
# 37311       OSS is, on average, of HIGHER quality than pro...
# 37750       OSS is, on average, of HIGHER quality than pro...
# 38074       OSS is, on average, of HIGHER quality than pro...
# 38974       OSS is, on average, of HIGHER quality than pro...
# 42831       OSS is, on average, of HIGHER quality than pro...
# 42839       OSS is, on average, of HIGHER quality than pro...
# 43123       The quality of OSS and closed source software ...
# 46536       OSS is, on average, of HIGHER quality than pro...
# 47067       The quality of OSS and closed source software ...
# 48586       The quality of OSS and closed source software ...
# 49832       OSS is, on average, of HIGHER quality than pro...
# 52685       The quality of OSS and closed source software ...
# 52824       OSS is, on average, of HIGHER quality than pro...
# 52855       The quality of OSS and closed source software ...
# 54612       OSS is, on average, of HIGHER quality than pro...
# 55308       OSS is, on average, of HIGHER quality than pro...
# 58996       OSS is, on average, of LOWER quality than prop...
# 59330       OSS is, on average, of LOWER quality than prop...
# 60063       OSS is, on average, of HIGHER quality than pro...
# 60365       The quality of OSS and closed source software ...
# 61831       OSS is, on average, of HIGHER quality than pro...
# 62191       The quality of OSS and closed source software ...
# 62834       The quality of OSS and closed source software ...
# 64615       OSS is, on average, of HIGHER quality than pro...
# 64990       OSS is, on average, of LOWER quality than prop...
# 66632       OSS is, on average, of HIGHER quality than pro...
# 67712       OSS is, on average, of HIGHER quality than pro...
# 68956       The quality of OSS and closed source software ...
# 71132       The quality of OSS and closed source software ...
# 72347       OSS is, on average, of HIGHER quality than pro...
# 72502       OSS is, on average, of HIGHER quality than pro...
# 72794       OSS is, on average, of HIGHER quality than pro...
# 73096       The quality of OSS and closed source software ...
# 75985       OSS is, on average, of HIGHER quality than pro...
# 76170       OSS is, on average, of HIGHER quality than pro...
# 76780       OSS is, on average, of LOWER quality than prop...
# 77272       OSS is, on average, of HIGHER quality than pro...
# 80032       OSS is, on average, of HIGHER quality than pro...
# 80433       OSS is, on average, of LOWER quality than prop...
# 80621       OSS is, on average, of HIGHER quality than pro...
# 81833       OSS is, on average, of HIGHER quality than pro...
# 82030       OSS is, on average, of HIGHER quality than pro...
# 82968       OSS is, on average, of HIGHER quality than pro...
# 83079       OSS is, on average, of HIGHER quality than pro...
# 83152       OSS is, on average, of LOWER quality than prop...
# 84099       OSS is, on average, of HIGHER quality than pro...
# 87571       OSS is, on average, of HIGHER quality than pro...
# 43870                                                     NaN
# 46303       OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment  Country  \
# Respondent
# 774                                        Employed full-time  Georgia
# 2019                                       Employed full-time  Georgia
# 2036                                       Employed full-time  Georgia
# 4703                                       Employed full-time  Georgia
# 4704                                       Employed full-time  Georgia
# 5933        Independent contractor, freelancer, or self-em...  Georgia
# 7464        Independent contractor, freelancer, or self-em...  Georgia
# 8679        Independent contractor, freelancer, or self-em...  Georgia
# 9590                                       Employed full-time  Georgia
# 9657                                       Employed full-time  Georgia
# 10909                                      Employed full-time  Georgia
# 13494                  Not employed, and not looking for work  Georgia
# 13623                                      Employed full-time  Georgia
# 13780                                      Employed full-time  Georgia
# 14013                                      Employed full-time  Georgia
# 14918                                      Employed full-time  Georgia
# 15096                                      Employed full-time  Georgia
# 15445                                      Employed full-time  Georgia
# 17822       Independent contractor, freelancer, or self-em...  Georgia
# 19861                                      Employed part-time  Georgia
# 23808                                      Employed full-time  Georgia
# 27617                                      Employed full-time  Georgia
# 28147                      Not employed, but looking for work  Georgia
# 28399                                      Employed part-time  Georgia
# 29693                                                     NaN  Georgia
# 30436                                      Employed full-time  Georgia
# 31561                                                     NaN  Georgia
# 32966                                      Employed full-time  Georgia
# 34021                                      Employed full-time  Georgia
# 34214       Independent contractor, freelancer, or self-em...  Georgia
# 35026                  Not employed, and not looking for work  Georgia
# 37311                                      Employed full-time  Georgia
# 37750                                      Employed full-time  Georgia
# 38074                      Not employed, but looking for work  Georgia
# 38974                                      Employed full-time  Georgia
# 42831                                      Employed full-time  Georgia
# 42839                                      Employed part-time  Georgia
# 43123                                      Employed full-time  Georgia
# 46536                                      Employed full-time  Georgia
# 47067       Independent contractor, freelancer, or self-em...  Georgia
# 48586                                      Employed part-time  Georgia
# 49832                      Not employed, but looking for work  Georgia
# 52685                                      Employed full-time  Georgia
# 52824                                      Employed full-time  Georgia
# 52855                                      Employed full-time  Georgia
# 54612       Independent contractor, freelancer, or self-em...  Georgia
# 55308       Independent contractor, freelancer, or self-em...  Georgia
# 58996                                      Employed full-time  Georgia
# 59330                                      Employed full-time  Georgia
# 60063                                      Employed full-time  Georgia
# 60365                                      Employed full-time  Georgia
# 61831                                      Employed full-time  Georgia
# 62191                                      Employed full-time  Georgia
# 62834                                      Employed full-time  Georgia
# 64615                                      Employed full-time  Georgia
# 64990       Independent contractor, freelancer, or self-em...  Georgia
# 66632                                      Employed full-time  Georgia
# 67712       Independent contractor, freelancer, or self-em...  Georgia
# 68956                                      Employed full-time  Georgia
# 71132                                      Employed full-time  Georgia
# 72347       Independent contractor, freelancer, or self-em...  Georgia
# 72502                                      Employed full-time  Georgia
# 72794                                      Employed full-time  Georgia
# 73096                                      Employed full-time  Georgia
# 75985                      Not employed, but looking for work  Georgia
# 76170                                      Employed full-time  Georgia
# 76780                                      Employed full-time  Georgia
# 77272                                      Employed full-time  Georgia
# 80032                      Not employed, but looking for work  Georgia
# 80433                                      Employed full-time  Georgia
# 80621                                      Employed full-time  Georgia
# 81833                                      Employed full-time  Georgia
# 82030                                      Employed full-time  Georgia
# 82968                                      Employed full-time  Georgia
# 83079                                      Employed full-time  Georgia
# 83152                                      Employed full-time  Georgia
# 84099                                      Employed full-time  Georgia
# 87571       Independent contractor, freelancer, or self-em...  Georgia
# 43870                                      Employed full-time  Georgia
# 46303                                      Employed full-time  Georgia
#
#                    Student                                            EdLevel  \
# Respondent
# 774                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2019                    No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 2036        Yes, full-time                          Primary/elementary school
# 4703                    No                          Primary/elementary school
# 4704        Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5933        Yes, part-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7464                    No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 8679                    No                          Primary/elementary school
# 9590        Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9657        Yes, part-time  Some college/university study without earning ...
# 10909                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13494       Yes, full-time                          Primary/elementary school
# 13623                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13780       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14013       Yes, full-time  Secondary school (e.g. American high school, G...
# 14918                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15096       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15445       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 17822       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 19861       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23808                  NaN  Some college/university study without earning ...
# 27617       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28147       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28399       Yes, full-time                                                NaN
# 29693       Yes, part-time                                                NaN
# 30436                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 31561                   No                 Professional degree (JD, MD, etc.)
# 32966       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34021                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34214                   No  Some college/university study without earning ...
# 35026       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37311       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37750                   No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 38074       Yes, full-time  Secondary school (e.g. American high school, G...
# 38974                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42831       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42839       Yes, full-time  Some college/university study without earning ...
# 43123       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46536       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47067                   No                          Primary/elementary school
# 48586                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 49832                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52685       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52824                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52855                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 54612                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 55308                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 58996       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 59330       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 60063       Yes, part-time  Some college/university study without earning ...
# 60365       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 61831                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62191                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62834                   No  Some college/university study without earning ...
# 64615       Yes, full-time  Secondary school (e.g. American high school, G...
# 64990                   No  Some college/university study without earning ...
# 66632                   No                 Professional degree (JD, MD, etc.)
# 67712       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 68956                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 71132       Yes, part-time  Secondary school (e.g. American high school, G...
# 72347                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 72502       Yes, full-time                          Primary/elementary school
# 72794       Yes, full-time  Some college/university study without earning ...
# 73096                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75985                   No  Secondary school (e.g. American high school, G...
# 76170                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76780                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77272                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 80032       Yes, full-time  Some college/university study without earning ...
# 80433       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 80621       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 81833                   No  Secondary school (e.g. American high school, G...
# 82030                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 82968                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 83079       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83152                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84099                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87571                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43870                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46303                   No                          Primary/elementary school
#
#                                                UndergradMajor  \
# Respondent
# 774         Computer science, computer engineering, or sof...
# 2019                            Web development or web design
# 2036                                                      NaN
# 4703                                                      NaN
# 4704        Computer science, computer engineering, or sof...
# 5933        Computer science, computer engineering, or sof...
# 7464        Information systems, information technology, o...
# 8679                                                      NaN
# 9590        Computer science, computer engineering, or sof...
# 9657        A natural science (ex. biology, chemistry, phy...
# 10909       Computer science, computer engineering, or sof...
# 13494                                                     NaN
# 13623       Computer science, computer engineering, or sof...
# 13780       Information systems, information technology, o...
# 14013                                                     NaN
# 14918       Information systems, information technology, o...
# 15096                                                     NaN
# 15445                           Web development or web design
# 17822                               Mathematics or statistics
# 19861       Computer science, computer engineering, or sof...
# 23808       A humanities discipline (ex. literature, histo...
# 27617                           Web development or web design
# 28147       Computer science, computer engineering, or sof...
# 28399       Computer science, computer engineering, or sof...
# 29693                           Web development or web design
# 30436       Computer science, computer engineering, or sof...
# 31561       A health science (ex. nursing, pharmacy, radio...
# 32966       Computer science, computer engineering, or sof...
# 34021       Computer science, computer engineering, or sof...
# 34214       Fine arts or performing arts (ex. graphic desi...
# 35026       Another engineering discipline (ex. civil, ele...
# 37311       Computer science, computer engineering, or sof...
# 37750       A natural science (ex. biology, chemistry, phy...
# 38074                                                     NaN
# 38974       Computer science, computer engineering, or sof...
# 42831       Computer science, computer engineering, or sof...
# 42839                           Web development or web design
# 43123       Computer science, computer engineering, or sof...
# 46536       Computer science, computer engineering, or sof...
# 47067                                                     NaN
# 48586       Computer science, computer engineering, or sof...
# 49832       Another engineering discipline (ex. civil, ele...
# 52685       Computer science, computer engineering, or sof...
# 52824       Computer science, computer engineering, or sof...
# 52855       Computer science, computer engineering, or sof...
# 54612       Computer science, computer engineering, or sof...
# 55308       Computer science, computer engineering, or sof...
# 58996       Computer science, computer engineering, or sof...
# 59330       Computer science, computer engineering, or sof...
# 60063       Computer science, computer engineering, or sof...
# 60365       Computer science, computer engineering, or sof...
# 61831       Computer science, computer engineering, or sof...
# 62191                               Mathematics or statistics
# 62834       Computer science, computer engineering, or sof...
# 64615                                                     NaN
# 64990       A business discipline (ex. accounting, finance...
# 66632       Computer science, computer engineering, or sof...
# 67712       A natural science (ex. biology, chemistry, phy...
# 68956       A business discipline (ex. accounting, finance...
# 71132                                                     NaN
# 72347                           Web development or web design
# 72502                                                     NaN
# 72794       Computer science, computer engineering, or sof...
# 73096       Computer science, computer engineering, or sof...
# 75985                                                     NaN
# 76170       Computer science, computer engineering, or sof...
# 76780       Computer science, computer engineering, or sof...
# 77272       Computer science, computer engineering, or sof...
# 80032                           Web development or web design
# 80433                               Mathematics or statistics
# 80621       Computer science, computer engineering, or sof...
# 81833                                                     NaN
# 82030       A humanities discipline (ex. literature, histo...
# 82968       Computer science, computer engineering, or sof...
# 83079       Computer science, computer engineering, or sof...
# 83152       Another engineering discipline (ex. civil, ele...
# 84099       Computer science, computer engineering, or sof...
# 87571       Computer science, computer engineering, or sof...
# 43870                                                     NaN
# 46303                                                     NaN
#
#                                                      EduOther  \
# Respondent
# 774         Taken an online course in programming or softw...
# 2019        Taken an online course in programming or softw...
# 2036        Taken an online course in programming or softw...
# 4703        Taught yourself a new language, framework, or ...
# 4704        Taken a part-time in-person course in programm...
# 5933        Taken an online course in programming or softw...
# 7464        Taught yourself a new language, framework, or ...
# 8679        Taken an online course in programming or softw...
# 9590        Taken an online course in programming or softw...
# 9657        Participated in a full-time developer training...
# 10909       Taken an online course in programming or softw...
# 13494       Taken an online course in programming or softw...
# 13623       Taken an online course in programming or softw...
# 13780       Taken an online course in programming or softw...
# 14013       Taken an online course in programming or softw...
# 14918       Taught yourself a new language, framework, or ...
# 15096       Taken an online course in programming or softw...
# 15445       Taken an online course in programming or softw...
# 17822       Taken an online course in programming or softw...
# 19861       Taken an online course in programming or softw...
# 23808       Taken an online course in programming or softw...
# 27617       Taken an online course in programming or softw...
# 28147       Taken an online course in programming or softw...
# 28399       Taken an online course in programming or softw...
# 29693       Taken an online course in programming or softw...
# 30436       Taken an online course in programming or softw...
# 31561       Taken an online course in programming or softw...
# 32966       Taken an online course in programming or softw...
# 34021       Taken an online course in programming or softw...
# 34214                                                     NaN
# 35026       Taken an online course in programming or softw...
# 37311                                                     NaN
# 37750       Taught yourself a new language, framework, or ...
# 38074       Taken an online course in programming or softw...
# 38974       Completed an industry certification program (e...
# 42831       Taken an online course in programming or softw...
# 42839       Taken an online course in programming or softw...
# 43123       Taken an online course in programming or softw...
# 46536       Taken an online course in programming or softw...
# 47067                                                     NaN
# 48586       Taken an online course in programming or softw...
# 49832       Taken an online course in programming or softw...
# 52685       Taken an online course in programming or softw...
# 52824       Taken an online course in programming or softw...
# 52855       Taken an online course in programming or softw...
# 54612       Taught yourself a new language, framework, or ...
# 55308       Taken an online course in programming or softw...
# 58996                     Contributed to open source software
# 59330       Taken an online course in programming or softw...
# 60063       Taken an online course in programming or softw...
# 60365       Taken an online course in programming or softw...
# 61831       Taken an online course in programming or softw...
# 62191                             Participated in a hackathon
# 62834       Taught yourself a new language, framework, or ...
# 64615       Taken an online course in programming or softw...
# 64990       Taken an online course in programming or softw...
# 66632       Taken an online course in programming or softw...
# 67712       Taught yourself a new language, framework, or ...
# 68956       Taken an online course in programming or softw...
# 71132       Taken an online course in programming or softw...
# 72347                                                     NaN
# 72502       Taught yourself a new language, framework, or ...
# 72794       Taken an online course in programming or softw...
# 73096       Taken an online course in programming or softw...
# 75985       Taken a part-time in-person course in programm...
# 76170       Received on-the-job training in software devel...
# 76780       Received on-the-job training in software devel...
# 77272                                                     NaN
# 80032       Taught yourself a new language, framework, or ...
# 80433       Taken a part-time in-person course in programm...
# 80621       Taken an online course in programming or softw...
# 81833                                                     NaN
# 82030       Taken an online course in programming or softw...
# 82968       Taken an online course in programming or softw...
# 83079                     Contributed to open source software
# 83152       Taught yourself a new language, framework, or ...
# 84099                             Participated in a hackathon
# 87571       Taken an online course in programming or softw...
# 43870       Taught yourself a new language, framework, or ...
# 46303                                                     NaN
#
#                                                       OrgSize  \
# Respondent
# 774                                        20 to 99 employees
# 2019                                       10 to 19 employees
# 2036                                     100 to 499 employees
# 4703                                       20 to 99 employees
# 4704                                       20 to 99 employees
# 5933                                            2-9 employees
# 7464                                            2-9 employees
# 8679        Just me - I am a freelancer, sole proprietor, ...
# 9590                                            2-9 employees
# 9657                                     100 to 499 employees
# 10909                                      20 to 99 employees
# 13494                                                     NaN
# 13623                                1,000 to 4,999 employees
# 13780                                           2-9 employees
# 14013                                      20 to 99 employees
# 14918                                           2-9 employees
# 15096                                      10 to 19 employees
# 15445                                      10 to 19 employees
# 17822       Just me - I am a freelancer, sole proprietor, ...
# 19861                                           2-9 employees
# 23808                                                     NaN
# 27617                                                     NaN
# 28147                                                     NaN
# 28399                                                     NaN
# 29693                                                     NaN
# 30436                                                     NaN
# 31561                                                     NaN
# 32966                                           2-9 employees
# 34021                                           2-9 employees
# 34214                                           2-9 employees
# 35026                                                     NaN
# 37311                                      20 to 99 employees
# 37750                                           2-9 employees
# 38074                                                     NaN
# 38974                                1,000 to 4,999 employees
# 42831                                      20 to 99 employees
# 42839                                                     NaN
# 43123                                      10 to 19 employees
# 46536                                10,000 or more employees
# 47067       Just me - I am a freelancer, sole proprietor, ...
# 48586                                      20 to 99 employees
# 49832                                                     NaN
# 52685                                      10 to 19 employees
# 52824                                      20 to 99 employees
# 52855                                      10 to 19 employees
# 54612       Just me - I am a freelancer, sole proprietor, ...
# 55308                                      20 to 99 employees
# 58996                                    500 to 999 employees
# 59330                                      20 to 99 employees
# 60063                                    100 to 499 employees
# 60365                                      20 to 99 employees
# 61831                                      10 to 19 employees
# 62191                                1,000 to 4,999 employees
# 62834                                    100 to 499 employees
# 64615                                           2-9 employees
# 64990                                           2-9 employees
# 66632                                      10 to 19 employees
# 67712       Just me - I am a freelancer, sole proprietor, ...
# 68956                                      10 to 19 employees
# 71132                                           2-9 employees
# 72347       Just me - I am a freelancer, sole proprietor, ...
# 72502                                                     NaN
# 72794                                      10 to 19 employees
# 73096                                    100 to 499 employees
# 75985                                                     NaN
# 76170                                      10 to 19 employees
# 76780                                           2-9 employees
# 77272                                    500 to 999 employees
# 80032                                                     NaN
# 80433                                                     NaN
# 80621                                                     NaN
# 81833       Just me - I am a freelancer, sole proprietor, ...
# 82030                                      20 to 99 employees
# 82968                                    100 to 499 employees
# 83079                                      20 to 99 employees
# 83152                                5,000 to 9,999 employees
# 84099                                      20 to 99 employees
# 87571       Just me - I am a freelancer, sole proprietor, ...
# 43870                                      10 to 19 employees
# 46303                                    100 to 499 employees
#
#                                                       DevType  \
# Respondent
# 774                                       Developer, back-end
# 2019        Academic researcher;Data or business analyst;D...
# 2036        Developer, back-end;Developer, desktop or ente...
# 4703        Developer, back-end;Developer, desktop or ente...
# 4704                            Developer, full-stack;Student
# 5933        Developer, back-end;Developer, front-end;Devel...
# 7464                              Developer, game or graphics
# 8679                                     Developer, front-end
# 9590        Developer, back-end;Developer, front-end;Devel...
# 9657        Developer, back-end;Developer, front-end;Devel...
# 10909       Developer, back-end;Developer, front-end;Devel...
# 13494                                                     NaN
# 13623       Data or business analyst;Database administrato...
# 13780       Developer, front-end;Developer, mobile;Enginee...
# 14013       Developer, embedded applications or devices;De...
# 14918                                   Developer, full-stack
# 15096       Developer, back-end;Developer, front-end;Devel...
# 15445       Developer, back-end;Developer, front-end;Devel...
# 17822       Data or business analyst;Developer, front-end;...
# 19861                             Developer, back-end;Student
# 23808                            Developer, front-end;Student
# 27617                           Developer, full-stack;Student
# 28147       Developer, front-end;Developer, full-stack;Edu...
# 28399       Database administrator;Developer, back-end;Dev...
# 29693                                                     NaN
# 30436       Data or business analyst;Data scientist or mac...
# 31561                                                     NaN
# 32966                                     Developer, back-end
# 34021       Database administrator;Designer;Developer, bac...
# 34214       Designer;Developer, back-end;Developer, deskto...
# 35026                                                     NaN
# 37311       Developer, back-end;Developer, front-end;Devel...
# 37750       Academic researcher;Developer, back-end;Develo...
# 38074       Data scientist or machine learning specialist;...
# 38974       Developer, back-end;Developer, desktop or ente...
# 42831       Developer, back-end;Developer, front-end;Devel...
# 42839       Developer, back-end;Developer, desktop or ente...
# ...
# 67712       Tech articles written by other developers;Indu...   NaN
# 68956               Tech articles written by other developers  21.0
# 71132       Tech articles written by other developers;Cour...  22.0
# 72347       Tech articles written by other developers;Indu...  25.0
# 72502                                                     NaN  20.0
# 72794               Tech articles written by other developers  20.0
# 73096       Tech articles written by other developers;Indu...  27.0
# 75985       Tech articles written by other developers;Indu...  17.0
# 76170       Tech articles written by other developers;Indu...  26.0
# 76780       Tech articles written by other developers;Indu...  24.0
# 77272               Tech articles written by other developers  33.0
# 80032                     Tech meetups or events in your area  21.0
# 80433       Industry news about technologies you're intere...  25.0
# 80621       Tech articles written by other developers;Indu...  20.0
# 81833       Tech articles written by other developers;Indu...  43.0
# 82030       Tech articles written by other developers;Cour...  29.0
# 82968       Tech articles written by other developers;Indu...  34.0
# 83079       Tech articles written by other developers;Indu...  19.0
# 83152       Tech articles written by other developers;Indu...  32.0
# 84099       Tech articles written by other developers;Cour...  29.0
# 87571       Industry news about technologies you're intere...  23.0
# 43870       Industry news about technologies you're intere...  30.0
# 46303                     Tech meetups or events in your area   NaN
#
#                Gender Trans                Sexuality  \
# Respondent
# 774             Woman    No                      NaN
# 2019              Man    No                      NaN
# 2036              Man    No  Straight / Heterosexual
# 4703              Man    No  Straight / Heterosexual
# 4704              Man    No  Straight / Heterosexual
# 5933              Man    No  Straight / Heterosexual
# 7464              Man    No  Straight / Heterosexual
# 8679              Man    No  Straight / Heterosexual
# 9590        Woman;Man    No                      NaN
# 9657              Man    No  Straight / Heterosexual
# 10909             Man    No  Straight / Heterosexual
# 13494             Man    No  Straight / Heterosexual
# 13623             Man    No  Straight / Heterosexual
# 13780             Man    No  Straight / Heterosexual
# 14013             Man    No  Straight / Heterosexual
# 14918             Man    No  Straight / Heterosexual
# 15096             Man    No  Straight / Heterosexual
# 15445             Man    No  Straight / Heterosexual
# 17822             Man    No  Straight / Heterosexual
# 19861             Man    No  Straight / Heterosexual
# 23808             Man    No  Straight / Heterosexual
# 27617             NaN   NaN                      NaN
# 28147             Man    No  Straight / Heterosexual
# 28399             Man    No  Straight / Heterosexual
# 29693             Man    No  Straight / Heterosexual
# 30436           Woman    No                      NaN
# 31561             Man    No  Straight / Heterosexual
# 32966             Man    No  Straight / Heterosexual
# 34021             Man    No  Straight / Heterosexual
# 34214             Man    No  Straight / Heterosexual
# 35026             Man    No  Straight / Heterosexual
# 37311             Man    No  Straight / Heterosexual
# 37750             Man    No  Straight / Heterosexual
# 38074             Man    No                      NaN
# 38974             Man    No  Straight / Heterosexual
# 42831             Man   NaN  Straight / Heterosexual
# 42839             Man    No  Straight / Heterosexual
# 43123             Man   NaN  Straight / Heterosexual
# 46536             NaN   NaN                      NaN
# 47067             Man    No                      NaN
# 48586             Man    No  Straight / Heterosexual
# 49832           Woman    No  Straight / Heterosexual
# 52685           Woman    No                 Bisexual
# 52824             Man   NaN  Straight / Heterosexual
# 52855             Man    No  Straight / Heterosexual
# 54612             Man    No  Straight / Heterosexual
# 55308             Man    No  Straight / Heterosexual
# 58996             Man    No  Straight / Heterosexual
# 59330             Man    No  Straight / Heterosexual
# 60063             Man    No  Straight / Heterosexual
# 60365             Man   NaN  Straight / Heterosexual
# 61831             Man    No  Straight / Heterosexual
# 62191             Man    No  Straight / Heterosexual
# 62834             Man    No  Straight / Heterosexual
# 64615             Man    No  Straight / Heterosexual
# 64990             Man    No  Straight / Heterosexual
# 66632             Man    No  Straight / Heterosexual
# 67712             Man    No  Straight / Heterosexual
# 68956             Man    No  Straight / Heterosexual
# 71132           Woman    No                      NaN
# 72347             Man    No  Straight / Heterosexual
# 72502             Man    No  Straight / Heterosexual
# 72794             Man    No  Straight / Heterosexual
# 73096             Man    No  Straight / Heterosexual
# 75985             Man    No  Straight / Heterosexual
# 76170             Man    No  Straight / Heterosexual
# 76780             Man    No  Straight / Heterosexual
# 77272             Man   NaN  Straight / Heterosexual
# 80032             Man    No                      NaN
# 80433             Man    No  Straight / Heterosexual
# 80621           Woman    No                      NaN
# 81833             Man    No  Straight / Heterosexual
# 82030             Man    No  Straight / Heterosexual
# 82968             Man    No  Straight / Heterosexual
# 83079             Man    No  Straight / Heterosexual
# 83152             Man    No  Straight / Heterosexual
# 84099             Man    No  Straight / Heterosexual
# 87571             Man    No  Straight / Heterosexual
# 43870           Woman   NaN                 Bisexual
# 46303             NaN    No  Straight / Heterosexual
#
#                                Ethnicity Dependents           SurveyLength  \
# Respondent
# 774         White or of European descent         No               Too long
# 2019         Black or of African descent        Yes               Too long
# 2036        White or of European descent        Yes  Appropriate in length
# 4703        White or of European descent        Yes  Appropriate in length
# 4704        White or of European descent        Yes  Appropriate in length
# 5933        White or of European descent         No  Appropriate in length
# 7464        White or of European descent        Yes  Appropriate in length
# 8679        White or of European descent         No  Appropriate in length
# 9590                                 NaN        NaN  Appropriate in length
# 9657        White or of European descent        Yes  Appropriate in length
# 10909       White or of European descent        Yes  Appropriate in length
# 13494       White or of European descent        NaN  Appropriate in length
# 13623       White or of European descent        Yes  Appropriate in length
# 13780                                NaN         No               Too long
# 14013       White or of European descent         No               Too long
# 14918       White or of European descent        Yes  Appropriate in length
# 15096       White or of European descent        Yes  Appropriate in length
# 15445       White or of European descent        Yes  Appropriate in length
# 17822       White or of European descent         No  Appropriate in length
# 19861       White or of European descent        Yes  Appropriate in length
# 23808       White or of European descent         No  Appropriate in length
# 27617                                NaN        NaN  Appropriate in length
# 28147       White or of European descent         No  Appropriate in length
# 28399       White or of European descent        NaN  Appropriate in length
# 29693       White or of European descent        Yes  Appropriate in length
# 30436                                NaN        NaN               Too long
# 31561       White or of European descent         No  Appropriate in length
# 32966       White or of European descent         No               Too long
# 34021       White or of European descent        Yes  Appropriate in length
# 34214                        South Asian        Yes  Appropriate in length
# 35026       White or of European descent        Yes  Appropriate in length
# 37311       White or of European descent         No               Too long
# 37750       White or of European descent        Yes  Appropriate in length
# 38074                                NaN         No  Appropriate in length
# 38974       White or of European descent        Yes  Appropriate in length
# 42831       White or of European descent         No  Appropriate in length
# 42839       White or of European descent        Yes               Too long
# 43123       White or of European descent         No               Too long
# 46536                                NaN        NaN                    NaN
# 47067       White or of European descent         No  Appropriate in length
# 48586                     Middle Eastern        Yes               Too long
# 49832       White or of European descent         No  Appropriate in length
# 52685       White or of European descent         No  Appropriate in length
# 52824       White or of European descent         No               Too long
# 52855       White or of European descent        Yes  Appropriate in length
# 54612       White or of European descent        Yes  Appropriate in length
# 55308                                NaN        Yes  Appropriate in length
# 58996                                NaN        Yes  Appropriate in length
# 59330       White or of European descent         No  Appropriate in length
# 60063       White or of European descent        Yes              Too short
# 60365       White or of European descent        Yes              Too short
# 61831       White or of European descent         No  Appropriate in length
# 62191                                NaN         No               Too long
# 62834       White or of European descent        Yes               Too long
# 64615                                NaN         No  Appropriate in length
# 64990       White or of European descent        Yes  Appropriate in length
# 66632                                NaN        Yes               Too long
# 67712       White or of European descent         No  Appropriate in length
# 68956       White or of European descent         No  Appropriate in length
# 71132       White or of European descent         No  Appropriate in length
# 72347       White or of European descent        NaN  Appropriate in length
# 72502       White or of European descent         No  Appropriate in length
# 72794       White or of European descent         No  Appropriate in length
# 73096                                NaN         No               Too long
# 75985       White or of European descent         No               Too long
# 76170       White or of European descent         No  Appropriate in length
# 76780       White or of European descent        Yes  Appropriate in length
# 77272                                NaN        NaN               Too long
# 80032                                NaN        NaN                    NaN
# 80433       White or of European descent         No               Too long
# 80621       White or of European descent        Yes               Too long
# 81833                     Middle Eastern        Yes               Too long
# 82030       White or of European descent        Yes  Appropriate in length
# 82968       White or of European descent        Yes  Appropriate in length
# 83079       White or of European descent         No  Appropriate in length
# 83152       White or of European descent        Yes  Appropriate in length
# 84099                                NaN         No               Too long
# 87571       White or of European descent         No  Appropriate in length
# 43870       White or of European descent        Yes  Appropriate in length
# 46303        Black or of African descent        Yes  Appropriate in length
#
#                             SurveyEase
# Respondent
# 774         Neither easy nor difficult
# 2019                              Easy
# 2036                              Easy
# 4703        Neither easy nor difficult
# 4704        Neither easy nor difficult
# 5933                              Easy
# 7464                              Easy
# 8679                              Easy
# 9590                              Easy
# 9657                              Easy
# 10909                             Easy
# 13494                             Easy
# 13623                             Easy
# 13780                        Difficult
# 14013                             Easy
# 14918                             Easy
# 15096       Neither easy nor difficult
# 15445       Neither easy nor difficult
# 17822       Neither easy nor difficult
# 19861                             Easy
# 23808                             Easy
# 27617                             Easy
# 28147                             Easy
# 28399                             Easy
# 29693                             Easy
# 30436                             Easy
# 31561                             Easy
# 32966                             Easy
# 34021                             Easy
# 34214                             Easy
# 35026                             Easy
# 37311                        Difficult
# 37750                             Easy
# 38074       Neither easy nor difficult
# 38974                             Easy
# 42831       Neither easy nor difficult
# 42839                             Easy
# 43123       Neither easy nor difficult
# 46536                              NaN
# 47067                        Difficult
# 48586       Neither easy nor difficult
# 49832                             Easy
# 52685                             Easy
# 52824                             Easy
# 52855                             Easy
# 54612                             Easy
# 55308       Neither easy nor difficult
# 58996       Neither easy nor difficult
# 59330                             Easy
# 60063       Neither easy nor difficult
# 60365       Neither easy nor difficult
# 61831       Neither easy nor difficult
# 62191                             Easy
# 62834                             Easy
# 64615       Neither easy nor difficult
# 64990                             Easy
# 66632                             Easy
# 67712       Neither easy nor difficult
# 68956       Neither easy nor difficult
# 71132                             Easy
# 72347                             Easy
# 72502                             Easy
# 72794                              NaN
# 73096                             Easy
# 75985                             Easy
# 76170                             Easy
# 76780       Neither easy nor difficult
# 77272                              NaN
# 80032                              NaN
# 80433       Neither easy nor difficult
# 80621                        Difficult
# 81833       Neither easy nor difficult
# 82030                             Easy
# 82968                             Easy
# 83079                             Easy
# 83152                             Easy
# 84099       Neither easy nor difficult
# 87571       Neither easy nor difficult
# 43870       Neither easy nor difficult
# 46303                             Easy

# %%
df.ConvertedComp
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
filt2 = (df.ConvertedComp > 70000) & (df.Country=='Georgia')
df.loc[filt2]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 54612                          I am a developer by profession      Yes
# 82968       I am not primarily a developer, but I write co...      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 54612                              Once a month or more often
# 82968       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 54612       OSS is, on average, of HIGHER quality than pro...
# 82968       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  Country  \
# Respondent
# 54612       Independent contractor, freelancer, or self-em...  Georgia
# 82968                                      Employed full-time  Georgia
#
#            Student                                      EdLevel  \
# Respondent
# 54612           No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 82968           No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 54612       Computer science, computer engineering, or sof...
# 82968       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 54612       Taught yourself a new language, framework, or ...
# 82968       Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 54612       Just me - I am a freelancer, sole proprietor, ...
# 82968                                    100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 54612       Database administrator;Developer, back-end;Dev...        15
# 82968       Developer, front-end;Developer, mobile;Enginee...        15
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 54612              11           10                      Very satisfied
# 82968              19            8  Neither satisfied nor dissatisfied
#
#                         JobSat MgrIdiot MgrMoney MgrWant  \
# Respondent
# 54612           Very satisfied      NaN      NaN     NaN
# 82968       Slightly satisfied      NaN      NaN     NaN
#
#                                                       JobSeek  \
# Respondent
# 54612       I’m not actively looking, but I am open to new...
# 82968       I’m not actively looking, but I am open to new...
#
#                                                  LastHireDate  \
# Respondent
# 54612       NA - I am an independent contractor or self em...
# 82968                                    Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 54612       Interview with people in peer roles;Interview ...       No
# 82968       Interview with people in peer roles;Interview ...       No
#
#                                                    JobFactors  \
# Respondent
# 54612       Languages, frameworks, and other technologies ...
# 82968       Office environment or company culture;Diversit...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 54612       Something else changed (education, award, medi...            EUR
# 82968       Something else changed (education, award, medi...            GEL
#
#              CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 54612       European Euro   280000.0   Yearly       320810.0         40.0
# 82968       Georgian lari    57600.0   Weekly      1000000.0         50.0
#
#                                                      WorkPlan  \
# Respondent
# 54612       There is a schedule and/or spec (made by me or...
# 82968       There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 54612       Distracting work environment;Inadequate access...
# 82968       Being tasked with non-development work;Inadequ...
#
#                                        WorkRemote WorkLoc             ImpSyn  \
# Respondent
# 54612       More than half, but not all, the time    Home  Far above average
# 82968            Less than once per month / Never  Office  Far above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 54612       Yes, because I see value in code review         5.0
# 82968       Yes, because I see value in code review         8.0
#
#                             UnitTests  \
# Respondent
# 54612                             NaN
# 82968       No, but I think we should
#
#                                                   PurchaseHow  \
# Respondent
# 54612                                                     NaN
# 82968       Developers and management have nearly equal in...
#
#                              PurchaseWhat  \
# Respondent
# 54612                                 NaN
# 82968       I have little or no influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 54612       Bash/Shell/PowerShell;C;C++;Erlang;Go;HTML/CSS...
# 82968                                        Swift;TypeScript
#
#                                        LanguageDesireNextYear  \
# Respondent
# 54612       Bash/Shell/PowerShell;Erlang;Go;HTML/CSS;Java;...
# 82968                            Dart;Kotlin;Swift;TypeScript
#
#                                            DatabaseWorkedWith  \
# Respondent
# 54612       Elasticsearch;MariaDB;MongoDB;MySQL;Oracle;Pos...
# 82968                                  Firebase;MongoDB;MySQL
#
#                            DatabaseDesireNextYear  \
# Respondent
# 54612       Elasticsearch;PostgreSQL;Redis;SQLite
# 82968                      Firebase;MongoDB;MySQL
#
#                                            PlatformWorkedWith  \
# Respondent
# 54612       Android;AWS;Docker;Kubernetes;Linux;MacOS;Rasp...
# 82968                                                     iOS
#
#                                     PlatformDesireNextYear  \
# Respondent
# 54612       AWS;Docker;Kubernetes;Linux;Raspberry Pi;Slack
# 82968                                                  iOS
#
#                                      WebFrameWorkedWith  \
# Respondent
# 54612       Django;Express;Flask;React.js;Spring;Vue.js
# 82968                                               NaN
#
#            WebFrameDesireNextYear  \
# Respondent
# 54612                       Flask
# 82968                         NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 54612       Ansible;Node.js;TensorFlow;Torch/PyTorch;Unrea...
# 82968                                       Node.js;Other(s):
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 54612       Ansible;Pandas;TensorFlow;Torch/PyTorch;Unreal...
# 82968                                       Node.js;Other(s):
#
#                           DevEnviron        OpSys  \
# Respondent
# 54612                            Vim  Linux-based
# 82968       Visual Studio Code;Xcode        MacOS
#
#                                                    Containers  \
# Respondent
# 54612       Development;Testing;Production;Outside of work...
# 82968                                 I do not use containers
#
#                                                 BlockchainOrg  \
# Respondent
# 54612                                                     NaN
# 82968       Accepting Bitcoin or other coins and tokens as...
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 54612       Useful for immutable record keeping outside of...        Yes
# 82968       Useful across many domains and could change ma...        Yes
#
#             ITperson  OffOn SocialMedia              Extraversion ScreenName  \
# Respondent
# 54612           SIGH  What?      Reddit  In real life (in person)   Username
# 82968       Also Yes    Yes     YouTube  In real life (in person)      Login
#
#            SOVisit1st            SOVisitFreq  \
# Respondent
# 54612            2008   A few times per week
# 82968            2010  Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 54612                      Find answers to specific questions
# 82968       Find answers to specific questions;Learn how t...
#
#                        SOFindAnswer                     SOTimeSaved  \
# Respondent
# 54612            3-5 times per week  Stack Overflow was much faster
# 82968       Less than once per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                       SOPartFreq SOJobs  \
# Respondent
# 54612       11-30 minutes       Yes  A few times per month or weekly    Yes
# 82968       31-60 minutes       Yes  A few times per month or weekly    Yes
#
#                                        EntTeams         SOComm  \
# Respondent
# 54612       No, and I don't know what those are  Yes, somewhat
# 82968       No, and I don't know what those are  Yes, somewhat
#
#                                        WelcomeChange  \
# Respondent
# 54612       Somewhat less welcome now than last year
# 82968        Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 54612                     Tech meetups or events in your area  28.0    Man
# 82968       Tech articles written by other developers;Indu...  34.0    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 54612         No  Straight / Heterosexual  White or of European descent
# 82968         No  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength SurveyEase
# Respondent
# 54612             Yes  Appropriate in length       Easy
# 82968             Yes  Appropriate in length       Easy

# %%
filt3 = df.ConvertedComp > 70000

# %%
df.loc[filt3]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 6                                                       Never
# 9                                  Once a month or more often
# 13          Less than once a month but more than once per ...
# 16                                                      Never
# 22                                    Less than once per year
# ...                                                       ...
# 88876                                                   Never
# 88877                                 Less than once per year
# 88878                                 Less than once per year
# 88879                                                   Never
# 88882                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 6           The quality of OSS and closed source software ...
# 9           The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# 16          The quality of OSS and closed source software ...
# 22          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 88876       OSS is, on average, of HIGHER quality than pro...
# 88877       OSS is, on average, of HIGHER quality than pro...
# 88878       The quality of OSS and closed source software ...
# 88879       The quality of OSS and closed source software ...
# 88882       OSS is, on average, of LOWER quality than prop...
#
#                     Employment         Country         Student  \
# Respondent
# 6           Employed full-time          Canada              No
# 9           Employed full-time     New Zealand              No
# 13          Employed full-time   United States              No
# 16          Employed full-time  United Kingdom              No
# 22          Employed full-time   United States              No
# ...                        ...             ...             ...
# 88876       Employed full-time   United States              No
# 88877       Employed full-time   United States              No
# 88878       Employed full-time   United States              No
# 88879       Employed full-time         Finland              No
# 88882       Employed full-time     Netherlands  Yes, full-time
#
#                                                       EdLevel  \
# Respondent
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 13                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 16                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 22          Some college/university study without earning ...
# ...                                                       ...
# 88876                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88877                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88878                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88879             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88882             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 6                                   Mathematics or statistics
# 9           Computer science, computer engineering, or sof...
# 13          Computer science, computer engineering, or sof...
# 16                                                        NaN
# 22                                                        NaN
# ...                                                       ...
# 88876       Computer science, computer engineering, or sof...
# 88877       Computer science, computer engineering, or sof...
# 88878       Computer science, computer engineering, or sof...
# 88879       Computer science, computer engineering, or sof...
# 88882       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 6           Taken an online course in programming or softw...
# 9           Taken an online course in programming or softw...
# 13          Taken an online course in programming or softw...
# 16          Taken an online course in programming or softw...
# 22          Taken an online course in programming or softw...
# ...                                                       ...
# 88876       Received on-the-job training in software devel...
# 88877       Taken an online course in programming or softw...
# 88878       Taken an online course in programming or softw...
# 88879       Taught yourself a new language, framework, or ...
# 88882       Participated in online coding competitions (e....
#
#                              OrgSize  \
# Respondent
# 6                                NaN
# 9                 10 to 19 employees
# 13                10 to 19 employees
# 16              100 to 499 employees
# 22          10,000 or more employees
# ...                              ...
# 88876       10,000 or more employees
# 88877           500 to 999 employees
# 88878             20 to 99 employees
# 88879             20 to 99 employees
# 88882           100 to 499 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 6           Data or business analyst;Data scientist or mac...        13
# 9           Database administrator;Developer, back-end;Dev...        12
# 13          Data or business analyst;Database administrato...        17
# 16                                      Developer, full-stack        10
# 22          Data or business analyst;Designer;Developer, b...        35
# ...                                                       ...       ...
# 88876         Developer, back-end;Developer, game or graphics         8
# 88877       Data scientist or machine learning specialist;...        31
# 88878       Developer, back-end;Developer, front-end;Devel...        12
# 88879       Developer, desktop or enterprise applications;...        17
# 88882       Academic researcher;Database administrator;Dev...        10
#
#            Age1stCode YearsCodePro              CareerSat  \
# Respondent
# 6                  15            3         Very satisfied
# 9                  11            4     Slightly satisfied
# 13                 11            8         Very satisfied
# 16                 17            3         Very satisfied
# 22                 12           18     Slightly satisfied
# ...               ...          ...                    ...
# 88876              15            2         Very satisfied
# 88877              18           28         Very satisfied
# 88878              14            3         Very satisfied
# 88879              16            7     Slightly satisfied
# 88882              15            8  Slightly dissatisfied
#
#                                         JobSat              MgrIdiot  \
# Respondent
# 6                           Slightly satisfied        Very confident
# 9                           Slightly satisfied    Somewhat confident
# 13                              Very satisfied                   NaN
# 16                          Slightly satisfied    Somewhat confident
# 22                           Very dissatisfied    Somewhat confident
# ...                                        ...                   ...
# 88876                       Slightly satisfied    Somewhat confident
# 88877                           Very satisfied        Very confident
# 88878                           Very satisfied        Very confident
# 88879       Neither satisfied nor dissatisfied  Not at all confident
# 88882                        Very dissatisfied  Not at all confident
#
#             MgrMoney                 MgrWant  \
# Respondent
# 6                 No                     Yes
# 9                 No                Not sure
# 13               NaN                     NaN
# 16                No                      No
# 22                No                      No
# ...              ...                     ...
# 88876            Yes                Not sure
# 88877            Yes                     Yes
# 88878            Yes                     Yes
# 88879       Not sure  I am already a manager
# 88882            Yes                     Yes
#
#                                                       JobSeek  \
# Respondent
# 6                I am not interested in new job opportunities
# 9           I’m not actively looking, but I am open to new...
# 13               I am not interested in new job opportunities
# 16          I’m not actively looking, but I am open to new...
# 22          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 88876       I’m not actively looking, but I am open to new...
# 88877       I’m not actively looking, but I am open to new...
# 88878            I am not interested in new job opportunities
# 88879       I’m not actively looking, but I am open to new...
# 88882       I’m not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 6                   1-2 years ago
# 9            Less than a year ago
# 13                  3-4 years ago
# 16                  3-4 years ago
# 22          More than 4 years ago
# ...                           ...
# 88876               1-2 years ago
# 88877       More than 4 years ago
# 88878        Less than a year ago
# 88879       More than 4 years ago
# 88882        Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 6           Write any code;Complete a take-home project;In...       No
# 9           Write any code;Interview with people in peer r...      Yes
# 13          Complete a take-home project;Interview with pe...      Yes
# 16          Interview with people in senior / management r...      Yes
# 22          Interview with people in senior / management r...       No
# ...                                                       ...      ...
# 88876              Write code by hand (e.g., on a whiteboard)       No
# 88877       Interview with people in senior / management r...      Yes
# 88878       Write any code;Write code by hand (e.g., on a ...       No
# 88879       Complete a take-home project;Interview with pe...       No
# 88882       Write any code;Complete a take-home project;In...       No
#
#                                                    JobFactors  \
# Respondent
# 6           Financial performance or funding status of the...
# 9           Financial performance or funding status of the...
# 13          Languages, frameworks, and other technologies ...
# 16          Languages, frameworks, and other technologies ...
# 22          Industry that I'd be working in;Financial perf...
# ...                                                       ...
# 88876       Office environment or company culture;Remote w...
# 88877       Industry that I'd be working in;Languages, fra...
# 88878       Languages, frameworks, and other technologies ...
# 88879       Languages, frameworks, and other technologies ...
# 88882       Office environment or company culture;Remote w...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 6           I heard about a job opportunity (from a recrui...            CAD
# 9                            I was preparing for a job search            NZD
# 13                           I was preparing for a job search            USD
# 16          I heard about a job opportunity (from a recrui...            GBP
# 22          I had a negative experience or interaction at ...            USD
# ...                                                       ...            ...
# 88876        My job status changed (promotion, new job, etc.)            USD
# 88877       I heard about a job opportunity (from a recrui...            USD
# 88878                        I was preparing for a job search            USD
# 88879       I had a negative experience or interaction at ...            EUR
# 88882       I had a negative experience or interaction at ...            EUR
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 6                Canadian dollar    40000.0  Monthly       366420.0
# 9             New Zealand dollar   138000.0   Yearly        95179.0
# 13          United States dollar    90000.0   Yearly        90000.0
# 16                Pound sterling    29000.0  Monthly       455352.0
# 22          United States dollar   103000.0   Yearly       103000.0
# ...                          ...        ...      ...            ...
# 88876       United States dollar   180000.0   Yearly       180000.0
# 88877       United States dollar   239000.0   Weekly      2000000.0
# 88878       United States dollar   130000.0   Yearly       130000.0
# 88879              European Euro     6000.0  Monthly        82488.0
# 88882              European Euro    42768.0  Monthly       588012.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 6                 15.00  There's no schedule or spec; I work on what se...
# 9                 32.00  There is a schedule and/or spec (made by me or...
# 13                40.00  There is a schedule and/or spec (made by me or...
# 16                40.00  There is a schedule and/or spec (made by me or...
# 22                40.00  There is a schedule and/or spec (made by me or...
# ...                 ...                                                ...
# 88876             40.00  There is a schedule and/or spec (made by me or...
# 88877             45.00  There is a schedule and/or spec (made by me or...
# 88878             40.00  There is a schedule and/or spec (made by me or...
# 88879             37.75  There is a schedule and/or spec (made by me or...
# 88882             40.00  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 6                                                         NaN
# 9           Being tasked with non-development work;Inadequ...
# 13          Meetings;Non-work commitments (parenting, scho...
# 16          Being tasked with non-development work;Distrac...
# 22          Being tasked with non-development work;Meeting...
# ...                                                       ...
# 88876       Distracting work environment;Meetings;Time spe...
# 88877             Meetings;Not enough people for the workload
# 88878       Non-work commitments (parenting, school work, ...
# 88879       Being tasked with non-development work;Distrac...
# 88882       Distracting work environment;Lack of support f...
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 6                                       A few days each month    Home
# 9                            Less than once per month / Never  Office
# 13          All or almost all the time (I'm full-time remote)    Home
# 16                                      A few days each month    Home
# 22          Less than half the time, but at least one day ...    Home
# ...                                                       ...     ...
# 88876       Less than half the time, but at least one day ...  Office
# 88877                        Less than once per month / Never  Office
# 88878                                   A few days each month  Office
# 88879                        Less than once per month / Never    Home
# 88882                        Less than once per month / Never    Home
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 6           A little above average                                       No
# 9           A little above average  Yes, because I see value in code review
# 13          A little above average  Yes, because I see value in code review
# 16                         Average                                       No
# 22                         Average                                       No
# ...                            ...                                      ...
# 88876                      Average  Yes, because I see value in code review
# 88877            Far above average  Yes, because I see value in code review
# 88878            Far above average  Yes, because I see value in code review
# 88879            Far above average  Yes, because I see value in code review
# 88882            Far above average  Yes, because I see value in code review
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 6                  NaN  Yes, it's not part of our process but the deve...
# 9                 12.0  Yes, it's not part of our process but the deve...
# 13                 5.0                          No, but I think we should
# 16                 NaN                          No, but I think we should
# 22                 NaN                          No, but I think we should
# ...                ...                                                ...
# 88876              3.0                      Yes, it's part of our process
# 88877              5.0                          No, but I think we should
# 88878              3.0                          No, and I'm glad we don't
# 88879             10.0                      Yes, it's part of our process
# 88882              5.0                      Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 6                                                    Not sure
# 9                                                    Not sure
# 13          Developers and management have nearly equal in...
# 16          Developers and management have nearly equal in...
# 22          The CTO, CIO, or other management purchase new...
# ...                                                       ...
# 88876                                                Not sure
# 88877       Developers and management have nearly equal in...
# 88878       Developers and management have nearly equal in...
# 88879       Developers and management have nearly equal in...
# 88882                                                Not sure
#
#                                 PurchaseWhat  \
# Respondent
# 6              I have little or no influence
# 9                      I have some influence
# 13          I have a great deal of influence
# 16                     I have some influence
# 22             I have little or no influence
# ...                                      ...
# 88876          I have little or no influence
# 88877                  I have some influence
# 88878                  I have some influence
# 88879          I have little or no influence
# 88882          I have little or no influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 6                                                  Java;R;SQL
# 9           Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                       ...
# 88876       Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877       Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878                    HTML/CSS;JavaScript;Scala;TypeScript
# 88879                        Bash/Shell/PowerShell;C++;Python
# 88882                  C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#                                        LanguageDesireNextYear  \
# Respondent
# 6                                            Python;Scala;SQL
# 9           Bash/Shell/PowerShell;C;HTML/CSS;JavaScript;Ru...
# 13          Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...
# 16          C#;HTML/CSS;JavaScript;TypeScript;WebAssembly;...
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                       ...
# 88876                                    C#;Java;Kotlin;Scala
# 88877       Bash/Shell/PowerShell;Clojure;HTML/CSS;Java;Ja...
# 88878                        JavaScript;Rust;Scala;TypeScript
# 88879                                                     C++
# 88882                                  C#;Java;JavaScript;PHP
#
#                             DatabaseWorkedWith  \
# Respondent
# 6                           MongoDB;PostgreSQL
# 9                   DynamoDB;PostgreSQL;SQLite
# 13           Couchbase;DynamoDB;Firebase;MySQL
# 16          MongoDB;Microsoft SQL Server;MySQL
# 22            Elasticsearch;MySQL;Oracle;Redis
# ...                                        ...
# 88876                           DynamoDB;MySQL
# 88877                                   Oracle
# 88878                               PostgreSQL
# 88879                                      NaN
# 88882                       MariaDB;PostgreSQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 6                                                  PostgreSQL
# 9                                     PostgreSQL;Redis;SQLite
# 13                                       Firebase;MySQL;Redis
# 16          Elasticsearch;MongoDB;Microsoft SQL Server;SQLite
# 22                           Elasticsearch;MySQL;Oracle;Redis
# ...                                                       ...
# 88876                                                DynamoDB
# 88877                                                  Oracle
# 88878                                              PostgreSQL
# 88879                                                     NaN
# 88882                                      MariaDB;PostgreSQL
#
#                                            PlatformWorkedWith  \
# Respondent
# 6                 Android;Google Cloud Platform;Linux;Windows
# 9                         AWS;Docker;Heroku;Linux;MacOS;Slack
# 13          Android;AWS;Docker;IBM Cloud or Watson;iOS;Lin...
# 16                                                        NaN
# 22                          Docker;Linux;Raspberry Pi;Windows
# ...                                                       ...
# 88876                                 AWS;Linux;MacOS;Windows
# 88877       Docker;iOS;Kubernetes;Linux;Slack;Windows;Othe...
# 88878                                                   Slack
# 88879                                   Android;Linux;Windows
# 88882            Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                        PlatformDesireNextYear  \
# Respondent
# 6                 Android;Google Cloud Platform;Linux;Windows
# 9               AWS;Docker;Heroku;Linux;MacOS;Slack;Other(s):
# 13          Android;AWS;Docker;IBM Cloud or Watson;Linux;S...
# 16                  AWS;Google Cloud Platform;Microsoft Azure
# 22                          Docker;Linux;Raspberry Pi;Windows
# ...                                                       ...
# 88876                     Android;AWS;iOS;Linux;MacOS;Windows
# 88877                                               Other(s):
# 88878                                                   Slack
# 88879                                           Linux;Windows
# 88882            Android;Arduino;Linux;Raspberry Pi;WordPress
#
#                                           WebFrameWorkedWith  \
# Respondent
# 6                                                        NaN
# 9                            Express;Ruby on Rails;Other(s):
# 13          Angular/Angular.js;ASP.NET;Express;jQuery;Vue.js
# 16                         Angular/Angular.js;ASP.NET;jQuery
# 22                          Angular/Angular.js;Ruby on Rails
# ...                                                      ...
# 88876                                                    NaN
# 88877                                              Other(s):
# 88878                                     React.js;Other(s):
# 88879                                                    NaN
# 88882                                        jQuery;React.js
#
#                          WebFrameDesireNextYear  \
# Respondent
# 6                                           NaN
# 9               Express;Ruby on Rails;Other(s):
# 13                               Express;Vue.js
# 16          Angular/Angular.js;ASP.NET;React.js
# 22             Angular/Angular.js;Ruby on Rails
# ...                                         ...
# 88876                                       NaN
# 88877                                 Other(s):
# 88878                        React.js;Other(s):
# 88879                                       NaN
# 88882                           jQuery;React.js
#
#                                 MiscTechWorkedWith  \
# Respondent
# 6                                           Hadoop
# 9                                 Node.js;Unity 3D
# 13                                 Node.js;Xamarin
# 16                          .NET;.NET Core;Node.js
# 22                                         Node.js
# ...                                            ...
# 88876       Apache Spark;Hadoop;.NET Core;Unity 3D
# 88877                                 Apache Spark
# 88878                                      Node.js
# 88879                                          NaN
# 88882                                     Unity 3D
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 6                           Hadoop;Pandas;TensorFlow;Unity 3D
# 9                                                     Node.js
# 13                                         Node.js;TensorFlow
# 16                             .NET Core;Node.js;React Native
# 22                                                    Node.js
# ...                                                       ...
# 88876       Apache Spark;CryEngine;Hadoop;.NET;.NET Core;T...
# 88877                                            Apache Spark
# 88878                                                 Node.js
# 88879                       TensorFlow;Unity 3D;Unreal Engine
# 88882                                                Unity 3D
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 6           Android Studio;Eclipse;PyCharm;RStudio;Visual ...      Windows
# 9                                                         Vim        MacOS
# 13                 Vim;Visual Studio;Visual Studio Code;Xcode      Windows
# 16                           Visual Studio;Visual Studio Code      Windows
# 22              Sublime Text;Visual Studio;Visual Studio Code      Windows
# ...                                                       ...          ...
# 88876       IntelliJ;Notepad++;PyCharm;Sublime Text;Vim;Vi...        MacOS
# 88877       Atom;Emacs;IntelliJ;IPython / Jupyter;PyCharm;...      Windows
# 88878                IntelliJ;Sublime Text;Visual Studio Code        MacOS
# 88879              Android Studio;Notepad++;Vim;Visual Studio      Windows
# 88882       Android Studio;IntelliJ;Notepad++;Vim;Visual S...  Linux-based
#
#                                         Containers  \
# Respondent
# 6                          I do not use containers
# 9                   Development;Testing;Production
# 13                  Development;Testing;Production
# 16                         I do not use containers
# 22          Outside of work, for personal projects
# ...                                            ...
# 88876                      I do not use containers
# 88877               Development;Testing;Production
# 88878                                   Production
# 88879                      I do not use containers
# 88882                      I do not use containers
#
#                                          BlockchainOrg  \
# Respondent
# 6                                           Not at all
# 9                                           Not at all
# 13                                          Not at all
# 16                                          Not at all
# 22                                          Not at all
# ...                                                ...
# 88876                                              NaN
# 88877       Implementing cryptocurrency-based products
# 88878                                       Not at all
# 88879                                       Not at all
# 88882                                       Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 6                                                         NaN         No
# 9                           An irresponsible use of resources         No
# 13          Useful for decentralized currency (i.e., Bitcoin)        Yes
# 16                                              A passing fad         No
# 22                                                        NaN        Yes
# ...                                                       ...        ...
# 88876                                           A passing fad        Yes
# 88877                       An irresponsible use of resources        Yes
# 88878       Useful for decentralized currency (i.e., Bitcoin)        Yes
# 88879                                           A passing fad        Yes
# 88882                                           A passing fad        Yes
#
#            ITperson OffOn SocialMedia              Extraversion   ScreenName  \
# Respondent
# 6               Yes    No     YouTube  In real life (in person)        Login
# 9              SIGH   Yes     Twitter  In real life (in person)     Username
# 13              Yes   Yes     Twitter  In real life (in person)     Username
# 16             SIGH    No     YouTube                    Online     Username
# 22              Yes   Yes   Instagram                    Online     Username
# ...             ...   ...         ...                       ...          ...
# 88876          SIGH   Yes      Reddit                   Neither       UserID
# 88877           Yes    No    Facebook                    Online  Screen Name
# 88878           Yes   Yes     Twitter                    Online     Username
# 88879           NaN   NaN     YouTube                   Neither     Username
# 88882           Yes   Yes   Instagram                   Neither     Username
#
#                   SOVisit1st                      SOVisitFreq  \
# Respondent
# 6                       2011  A few times per month or weekly
# 9                       2013            Daily or almost daily
# 13                      2011           Multiple times per day
# 16                      2010           Multiple times per day
# 22          I don't remember            Daily or almost daily
# ...                      ...                              ...
# 88876                   2011  A few times per month or weekly
# 88877                    NaN  A few times per month or weekly
# 88878                   2010           Multiple times per day
# 88879       I don't remember  A few times per month or weekly
# 88882                   2009             A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 6                          Find answers to specific questions
# 9           Find answers to specific questions;Contribute ...
# 13                         Find answers to specific questions
# 16          Find answers to specific questions;Learn how t...
# 22                         Find answers to specific questions
# ...                                                       ...
# 88876                      Find answers to specific questions
# 88877                      Find answers to specific questions
# 88878       Find answers to specific questions;Learn how t...
# 88879                      Find answers to specific questions
# 88882                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 6               Less than once per week  Stack Overflow was slightly faster
# 9                    3-5 times per week            They were about the same
# 13          More than 10 times per week      Stack Overflow was much faster
# 16              Less than once per week      Stack Overflow was much faster
# 22                   3-5 times per week      Stack Overflow was much faster
# ...                                 ...                                 ...
# 88876                1-2 times per week      Stack Overflow was much faster
# 88877           Less than once per week      Stack Overflow was much faster
# 88878                3-5 times per week      Stack Overflow was much faster
# 88879           Less than once per week  Stack Overflow was slightly faster
# 88882                3-5 times per week  Stack Overflow was slightly faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 6             60+ minutes       Yes
# 9                     NaN       Yes
# 13          11-30 minutes       Yes
# 16          11-30 minutes       Yes
# 22           0-10 minutes       Yes
# ...                   ...       ...
# 88876         60+ minutes       Yes
# 88877       11-30 minutes       Yes
# 88878        0-10 minutes       Yes
# 88879         60+ minutes        No
# 88882       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 6           I have never participated in Q&A on Stack Over...
# 9                         Less than once per month or monthly
# 13                        Less than once per month or monthly
# 16                        Less than once per month or monthly
# 22                                       A few times per week
# ...                                                       ...
# 88876                     Less than once per month or monthly
# 88877       I have never participated in Q&A on Stack Over...
# 88878                                    A few times per week
# 88879                                                     NaN
# 88882                     Less than once per month or monthly
#
#                                                        SOJobs  \
# Respondent
# 6           No, I knew that Stack Overflow had a job board...
# 9           No, I knew that Stack Overflow had a job board...
# 13                                                        Yes
# 16                                                        Yes
# 22                                                        Yes
# ...                                                       ...
# 88876       No, I didn't know that Stack Overflow had a jo...
# 88877       No, I knew that Stack Overflow had a job board...
# 88878                                                     Yes
# 88879       No, I didn't know that Stack Overflow had a jo...
# 88882       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams          SOComm  \
# Respondent
# 6                         No, and I don't know what those are  No, not really
# 9                         No, and I don't know what those are   Yes, somewhat
# 13          No, I've heard of them, but I am not part of a...         Neutral
# 16          No, I've heard of them, but I am not part of a...   Yes, somewhat
# 22                        No, and I don't know what those are   Yes, somewhat
# ...                                                       ...             ...
# 88876                     No, and I don't know what those are   Yes, somewhat
# 88877                     No, and I don't know what those are   Yes, somewhat
# 88878       No, I've heard of them, but I am not part of a...   Yes, somewhat
# 88879                     No, and I don't know what those are  No, not at all
# 88882                     No, and I don't know what those are  No, not really
#
#                                                 WelcomeChange  \
# Respondent
# 6                     Just as welcome now as I felt last year
# 9                     Just as welcome now as I felt last year
# 13                   Somewhat more welcome now than last year
# 16                    Just as welcome now as I felt last year
# 22                    Just as welcome now as I felt last year
# ...                                                       ...
# 88876                   A lot less welcome now than last year
# 88877                Somewhat more welcome now than last year
# 88878                 Just as welcome now as I felt last year
# 88879       Not applicable - I did not use Stack Overflow ...
# 88882                 Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 6           Tech articles written by other developers;Indu...  28.0    Man
# 9                                                         NaN  23.0    Man
# 13          Tech articles written by other developers;Cour...  28.0    Man
# 16          Tech articles written by other developers;Indu...  26.0    Man
# 22          Tech articles written by other developers;Indu...  47.0    Man
# ...                                                       ...   ...    ...
# 88876                                                     NaN  23.0    Man
# 88877       Tech articles written by other developers;Cour...  48.0    Man
# 88878       Tech articles written by other developers;Indu...  26.0    Man
# 88879                                                     NaN  34.0    Man
# 88882                                                     NaN   NaN    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 6             No  Straight / Heterosexual                    East Asian
# 9             No                 Bisexual  White or of European descent
# 13            No  Straight / Heterosexual  White or of European descent
# 16            No  Straight / Heterosexual  White or of European descent
# 22            No  Straight / Heterosexual  White or of European descent
# ...          ...                      ...                           ...
# 88876         No  Straight / Heterosexual  White or of European descent
# 88877         No  Straight / Heterosexual                   South Asian
# 88878         No  Straight / Heterosexual                   South Asian
# 88879         No  Straight / Heterosexual  White or of European descent
# 88882         No  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 6                  No               Too long  Neither easy nor difficult
# 9                  No  Appropriate in length  Neither easy nor difficult
# 13                Yes  Appropriate in length                        Easy
# 16                 No  Appropriate in length  Neither easy nor difficult
# 22                Yes  Appropriate in length                        Easy
# ...               ...                    ...                         ...
# 88876              No  Appropriate in length                        Easy
# 88877             Yes               Too long  Neither easy nor difficult
# 88878              No  Appropriate in length                        Easy
# 88879              No  Appropriate in length                        Easy
# 88882             Yes               Too long                        Easy
#
# [22289 rows x 84 columns]

# %%
df.loc[filt3, 'Country'].value_counts()
# Out:
# United States                           12192
# United Kingdom                           1962
# Germany                                  1386
# Canada                                   1062
# Australia                                 765
#                                         ...
# Liechtenstein                               1
# Venezuela, Bolivarian Republic of...        1
# Somalia                                     1
# Bahrain                                     1
# Pakistan                                    1
# Name: Country, Length: 116, dtype: int64

# %%
df.loc[filt3, ['Country', 'Student']].value_counts()
# Out:
# Country         Student
# United States   No                11414
# United Kingdom  No                 1864
# Germany         No                 1281
# Canada          No                  996
# Australia       No                  728
#                                   ...
# Afghanistan     Yes, full-time        1
# Japan           Yes, part-time        1
# Iraq            No                    1
# Iran            Yes, part-time        1
# Zimbabwe        Yes, part-time        1
# Length: 211, dtype: int64

# %%
df.sort_values(by=['Country', 'Hobbyist'], ascending=[False, True])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 22363       I am not primarily a developer, but I write co...       No
# 22975                          I am a developer by profession       No
# 47247       I am not primarily a developer, but I write co...       No
# 51356                  I am a student who is learning to code       No
# 69495       I used to be a developer by profession, but no...       No
# ...                                                       ...      ...
# 88062                                                     NaN       No
# 88076                                                     NaN       No
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 22363                                 Less than once per year
# 22975                              Once a month or more often
# 47247                              Once a month or more often
# 51356                                                   Never
# 69495       Less than once a month but more than once per ...
# ...                                                       ...
# 88062                                                   Never
# 88076                                                   Never
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 22363       OSS is, on average, of LOWER quality than prop...
# 22975       The quality of OSS and closed source software ...
# 47247       The quality of OSS and closed source software ...
# 51356       OSS is, on average, of HIGHER quality than pro...
# 69495       OSS is, on average, of LOWER quality than prop...
# ...                                                       ...
# 88062       OSS is, on average, of LOWER quality than prop...
# 88076       OSS is, on average, of HIGHER quality than pro...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment   Country  \
# Respondent
# 22363                                      Employed full-time  Zimbabwe
# 22975                      Not employed, but looking for work  Zimbabwe
# 47247       Independent contractor, freelancer, or self-em...  Zimbabwe
# 51356                      Not employed, but looking for work  Zimbabwe
# 69495       Independent contractor, freelancer, or self-em...  Zimbabwe
# ...                                                       ...       ...
# 88062                                                     NaN       NaN
# 88076                                      Employed full-time       NaN
# 88601                                                     NaN       NaN
# 88802                                      Employed full-time       NaN
# 88816       Independent contractor, freelancer, or self-em...       NaN
#
#                    Student                                            EdLevel  \
# Respondent
# 22363                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22975                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47247       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 51356       Yes, full-time  Secondary school (e.g. American high school, G...
# 69495                   No  Some college/university study without earning ...
# ...                    ...                                                ...
# 88062                  NaN                                                NaN
# 88076                  NaN                                                NaN
# 88601                  NaN                                                NaN
# 88802                  NaN                                                NaN
# 88816                  NaN                                                NaN
#
#                                                UndergradMajor  \
# Respondent
# 22363       Information systems, information technology, o...
# 22975       Computer science, computer engineering, or sof...
# 47247       Computer science, computer engineering, or sof...
# 51356                                                     NaN
# 69495       Information systems, information technology, o...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                      EduOther  \
# Respondent
# 22363       Received on-the-job training in software devel...
# 22975       Taken an online course in programming or softw...
# 47247       Taken an online course in programming or softw...
# 51356       Taught yourself a new language, framework, or ...
# 69495       Taken an online course in programming or softw...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                          OrgSize  \
# Respondent
# 22363              2-9 employees
# 22975                        NaN
# 47247       500 to 999 employees
# 51356                        NaN
# 69495              2-9 employees
# ...                          ...
# 88062                        NaN
# 88076                        NaN
# 88601                        NaN
# 88802                        NaN
# 88816                        NaN
#
#                                                       DevType YearsCode  \
# Respondent
# 22363                                    System administrator         8
# 22975       Academic researcher;Data or business analyst;D...         4
# 47247       Designer;Developer, front-end;Developer, full-...         4
# 51356                             Academic researcher;Student         2
# 69495       Developer, back-end;Developer, front-end;Devel...         5
# ...                                                       ...       ...
# 88062                                                     NaN       NaN
# 88076                                                     NaN       NaN
# 88601                                                     NaN       NaN
# 88802                                                     NaN       NaN
# 88816                                                     NaN       NaN
#
#            Age1stCode YearsCodePro           CareerSat              JobSat  \
# Respondent
# 22363              20            2   Very dissatisfied   Very dissatisfied
# 22975              18            3  Slightly satisfied                 NaN
# 47247              24            3      Very satisfied  Slightly satisfied
# 51356              25          NaN                 NaN                 NaN
# 69495              15            3                 NaN                 NaN
# ...               ...          ...                 ...                 ...
# 88062             NaN          NaN                 NaN                 NaN
# 88076             NaN          NaN                 NaN                 NaN
# 88601             NaN          NaN                 NaN                 NaN
# 88802             NaN          NaN                 NaN                 NaN
# 88816             NaN          NaN                 NaN                 NaN
#
#                         MgrIdiot MgrMoney MgrWant  \
# Respondent
# 22363       Not at all confident       No     Yes
# 22975                        NaN      NaN     NaN
# 47247                        NaN      NaN     NaN
# 51356                        NaN      NaN     NaN
# 69495                        NaN      NaN     NaN
# ...                          ...      ...     ...
# 88062                        NaN      NaN     NaN
# 88076                        NaN      NaN     NaN
# 88601                        NaN      NaN     NaN
# 88802                        NaN      NaN     NaN
# 88816                        NaN      NaN     NaN
#
#                                                       JobSeek  \
# Respondent
# 22363                         I am actively looking for a job
# 22975                         I am actively looking for a job
# 47247                         I am actively looking for a job
# 51356       I’m not actively looking, but I am open to new...
# 69495                                                     NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                     LastHireDate  \
# Respondent
# 22363              1-2 years ago
# 22975       Less than a year ago
# 47247              1-2 years ago
# 51356       I've never had a job
# 69495                        NaN
# ...                          ...
# 88062                        NaN
# 88076                        NaN
# 88601                        NaN
# 88802                        NaN
# 88816                        NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 22363                                                     NaN       No
# 22975       Write any code;Write code by hand (e.g., on a ...      NaN
# 47247       Write any code;Write code by hand (e.g., on a ...       No
# 51356                                                     NaN      NaN
# 69495                                                     NaN      NaN
# ...                                                       ...      ...
# 88062                                                     NaN      NaN
# 88076                                                     NaN      NaN
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 22363       Office environment or company culture;Opportun...
# 22975       Office environment or company culture;Opportun...
# 47247       Remote work options;Opportunities for professi...
# 51356       Languages, frameworks, and other technologies ...
# 69495                                                     NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 22363                             Re-entry into the workforce            USD
# 22975                        I was preparing for a job search            NaN
# 47247       Something else changed (education, award, medi...            USD
# 51356       Something else changed (education, award, medi...            NaN
# 69495                                                     NaN            NaN
# ...                                                       ...            ...
# 88062                                                     NaN            NaN
# 88076                                                     NaN            NaN
# 88601                                                     NaN            NaN
# 88802                                                     NaN            NaN
# 88816                                                     NaN            NaN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 22363       United States dollar        NaN   Yearly            NaN
# 22975                        NaN        NaN      NaN            NaN
# 47247       United States dollar       75.0  Monthly          900.0
# 51356                        NaN        NaN      NaN            NaN
# 69495                        NaN        NaN      NaN            NaN
# ...                          ...        ...      ...            ...
# 88062                        NaN        NaN      NaN            NaN
# 88076                        NaN        NaN      NaN            NaN
# 88601                        NaN        NaN      NaN            NaN
# 88802                        NaN        NaN      NaN            NaN
# 88816                        NaN        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 22363               8.0  There is a schedule and/or spec (made by me or...
# 22975               NaN                                                NaN
# 47247               8.0  There's no schedule or spec; I work on what se...
# 51356               NaN                                                NaN
# 69495               NaN                                                NaN
# ...                 ...                                                ...
# 88062               NaN                                                NaN
# 88076               NaN                                                NaN
# 88601               NaN                                                NaN
# 88802               NaN                                                NaN
# 88816               NaN                                                NaN
#
#                                                 WorkChallenge  \
# Respondent
# 22363                            Distracting work environment
# 22975                                                     NaN
# 47247       Inadequate access to necessary tools;Lack of s...
# 51356                                                     NaN
# 69495                                                     NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                   WorkRemote  \
# Respondent
# 22363                    About half the time
# 22975                                    NaN
# 47247       Less than once per month / Never
# 51356                                    NaN
# 69495                                    NaN
# ...                                      ...
# 88062                                    NaN
# 88076                                    NaN
# 88601                                    NaN
# 88802                                    NaN
# 88816                                    NaN
#
#                                                    WorkLoc  \
# Respondent
# 22363       Other place, such as a coworking space or cafe
# 22975                                                  NaN
# 47247                                                 Home
# 51356                                                  NaN
# 69495                                                  NaN
# ...                                                    ...
# 88062                                                  NaN
# 88076                                                  NaN
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 22363                      Average  Yes, because I see value in code review
# 22975            Far above average                                      NaN
# 47247       A little above average  Yes, because I see value in code review
# 51356                          NaN                                      NaN
# 69495                          NaN                                      NaN
# ...                            ...                                      ...
# 88062                          NaN                                      NaN
# 88076                          NaN                                      NaN
# 88601                          NaN                                      NaN
# 88802                          NaN                                      NaN
# 88816                          NaN                                      NaN
#
#             CodeRevHrs                  UnitTests  \
# Respondent
# 22363              9.0  No, but I think we should
# 22975              NaN                        NaN
# 47247              2.0                        NaN
# 51356              NaN                        NaN
# 69495              NaN                        NaN
# ...                ...                        ...
# 88062              NaN                        NaN
# 88076              NaN                        NaN
# 88601              NaN                        NaN
# 88802              NaN                        NaN
# 88816              NaN                        NaN
#
#                                                   PurchaseHow  \
# Respondent
# 22363       Developers typically have the most influence o...
# 22975                                                     NaN
# 47247                                                     NaN
# 51356                                                     NaN
# 69495                                                     NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                              PurchaseWhat  \
# Respondent
# 22363       I have little or no influence
# 22975                                 NaN
# 47247                                 NaN
# 51356                                 NaN
# 69495                                 NaN
# ...                                   ...
# 88062                                 NaN
# 88076                                 NaN
# 88601                                 NaN
# 88802                                 NaN
# 88816                                 NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 22363                                 HTML/CSS;JavaScript;PHP
# 22975       Elixir;Erlang;HTML/CSS;Java;JavaScript;PHP;Pyt...
# 47247           C;C++;C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA
# 51356                                        HTML/CSS;PHP;VBA
# 69495                          C#;HTML/CSS;JavaScript;PHP;SQL
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 22363                                                     NaN
# 22975       Elixir;Erlang;HTML/CSS;Java;JavaScript;PHP;Pyt...
# 47247                          Assembly;Go;Objective-C;Python
# 51356                                     Assembly;JavaScript
# 69495       C#;Go;HTML/CSS;JavaScript;PHP;Python;SQL;TypeS...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                            DatabaseWorkedWith  \
# Respondent
# 22363                              Microsoft SQL Server;MySQL
# 22975       Couchbase;MariaDB;MongoDB;Microsoft SQL Server...
# 47247                                    MariaDB;MySQL;SQLite
# 51356                                                   MySQL
# 69495                                                   MySQL
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 22363                                   MariaDB;Oracle;SQLite
# 22975       Cassandra;Couchbase;DynamoDB;MariaDB;MongoDB;M...
# 47247                    DynamoDB;Microsoft SQL Server;Oracle
# 51356                                                     NaN
# 69495                        Elasticsearch;MySQL;Redis;SQLite
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                PlatformWorkedWith  \
# Respondent
# 22363                                         NaN
# 22975              Android;Arduino;Heroku;Windows
# 47247       Android;Google Cloud Platform;Windows
# 51356                                     Windows
# 69495                             Android;Arduino
# ...                                           ...
# 88062                                         NaN
# 88076                                         NaN
# 88601                                         NaN
# 88802                                         NaN
# 88816                                         NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 22363         Android;Docker;iOS;Microsoft Azure;Raspberry Pi
# 22975       Android;Docker;Google Cloud Platform;Heroku;Wi...
# 47247                                    Arduino;Raspberry Pi
# 51356                                                     NaN
# 69495       Android;Arduino;Kubernetes;Linux;Microsoft Azu...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                             WebFrameWorkedWith  \
# Respondent
# 22363                                      NaN
# 22975       Express;Flask;jQuery;Spring;Vue.js
# 47247                                   jQuery
# 51356                                      NaN
# 69495                    jQuery;Laravel;Vue.js
# ...                                        ...
# 88062                                      NaN
# 88076                                      NaN
# 88601                                      NaN
# 88802                                      NaN
# 88816                                      NaN
#
#                                WebFrameDesireNextYear  \
# Respondent
# 22363       Angular/Angular.js;ASP.NET;jQuery;Laravel
# 22975              Flask;jQuery;Laravel;Spring;Vue.js
# 47247                Angular/Angular.js;Django;Drupal
# 51356                                             NaN
# 69495                   Express;jQuery;Laravel;Vue.js
# ...                                               ...
# 88062                                             NaN
# 88076                                             NaN
# 88601                                             NaN
# 88802                                             NaN
# 88816                                             NaN
#
#                           MiscTechWorkedWith  \
# Respondent
# 22363       Apache Spark;Hadoop;.NET;Xamarin
# 22975                                Flutter
# 47247          Cordova;.NET;Unity 3D;Xamarin
# 51356                           Apache Spark
# 69495                        Cordova;Xamarin
# ...                                      ...
# 88062                                    NaN
# 88076                                    NaN
# 88601                                    NaN
# 88802                                    NaN
# 88816                                    NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 22363                                                     NaN
# 22975                                    Apache Spark;Flutter
# 47247                    Apache Spark;CryEngine;Unreal Engine
# 51356                                                     NaN
# 69495       .NET Core;Node.js;Pandas;TensorFlow;Torch/PyTo...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 22363                                 Notepad++;Visual Studio      Windows
# 22975       Android Studio;Atom;IntelliJ;IPython / Jupyter...      Windows
# 47247       Android Studio;Notepad++;PHPStorm;Sublime Text...      Windows
# 51356       Android Studio;Notepad++;PHPStorm;RStudio;Subl...      Windows
# 69495                             PHPStorm;Visual Studio Code  Linux-based
# ...                                                       ...          ...
# 88062                                                     NaN          NaN
# 88076                                                     NaN          NaN
# 88601                                                     NaN          NaN
# 88802                                                     NaN          NaN
# 88816                                                     NaN          NaN
#
#                                         Containers  \
# Respondent
# 22363                                  Development
# 22975               Development;Testing;Production
# 47247       Outside of work, for personal projects
# 51356                                  Development
# 69495                      I do not use containers
# ...                                            ...
# 88062                                          NaN
# 88076                                          NaN
# 88601                                          NaN
# 88802                                          NaN
# 88816                                          NaN
#
#                                          BlockchainOrg  \
# Respondent
# 22363       Implementing cryptocurrency-based products
# 22975                                              NaN
# 47247                                              NaN
# 51356                                              NaN
# 69495                                              NaN
# ...                                                ...
# 88062                                              NaN
# 88076                                              NaN
# 88601                                              NaN
# 88802                                              NaN
# 88816                                              NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 22363                                                     NaN        Yes
# 22975       Useful across many domains and could change ma...        Yes
# 47247       Useful for decentralized currency (i.e., Bitcoin)        Yes
# 51356       Useful across many domains and could change ma...        Yes
# 69495                                                     NaN        Yes
# ...                                                       ...        ...
# 88062                                                     NaN        NaN
# 88076                                                     NaN        NaN
# 88601                                                     NaN        NaN
# 88802                                                     NaN        NaN
# 88816                                                     NaN        NaN
#
#            ITperson  OffOn SocialMedia              Extraversion ScreenName  \
# Respondent
# 22363           Yes    Yes     Twitter                    Online     Handle
# 22975           Yes     No     Twitter  In real life (in person)   Username
# 47247           Yes    Yes     YouTube  In real life (in person)   Username
# 51356           Yes  What?    Facebook                    Online   Username
# 69495           Yes    Yes    WhatsApp                    Online   Username
# ...             ...    ...         ...                       ...        ...
# 88062           NaN    NaN         NaN                       NaN        NaN
# 88076           NaN    NaN         NaN                       NaN        NaN
# 88601           NaN    NaN         NaN                       NaN        NaN
# 88802           NaN    NaN         NaN                       NaN        NaN
# 88816           NaN    NaN         NaN                       NaN        NaN
#
#            SOVisit1st                      SOVisitFreq  \
# Respondent
# 22363             NaN           Multiple times per day
# 22975            2013            Daily or almost daily
# 47247            2016            Daily or almost daily
# 51356            2018  A few times per month or weekly
# 69495            2014           Multiple times per day
# ...               ...                              ...
# 88062             NaN                              NaN
# 88076             NaN                              NaN
# 88601             NaN                              NaN
# 88802             NaN                              NaN
# 88816             NaN                              NaN
#
#                                                     SOVisitTo  \
# Respondent
# 22363                      Find answers to specific questions
# 22975       Find answers to specific questions;Learn how t...
# 47247       Find answers to specific questions;Contribute ...
# 51356       Learn how to do things I didn’t necessarily lo...
# 69495       Find answers to specific questions;Learn how t...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 22363       More than 10 times per week      Stack Overflow was much faster
# 22975                1-2 times per week      Stack Overflow was much faster
# 47247                3-5 times per week  Stack Overflow was slightly faster
# 51356           Less than once per week      Stack Overflow was much faster
# 69495       More than 10 times per week      Stack Overflow was much faster
# ...                                 ...                                 ...
# 88062                               NaN                                 NaN
# 88076                               NaN                                 NaN
# 88601                               NaN                                 NaN
# 88802                               NaN                                 NaN
# 88816                               NaN                                 NaN
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 22363         60+ minutes                        Yes
# 22975         60+ minutes                        Yes
# 47247         60+ minutes                        Yes
# 51356       11-30 minutes  Not sure / can't remember
# 69495       11-30 minutes                        Yes
# ...                   ...                        ...
# 88062                 NaN                        NaN
# 88076                 NaN                        NaN
# 88601                 NaN                        NaN
# 88802                 NaN                        NaN
# 88816                 NaN                        NaN
#
#                                      SOPartFreq  \
# Respondent
# 22363           A few times per month or weekly
# 22975           A few times per month or weekly
# 47247       Less than once per month or monthly
# 51356                                       NaN
# 69495       Less than once per month or monthly
# ...                                         ...
# 88062                                       NaN
# 88076                                       NaN
# 88601                                       NaN
# 88802                                       NaN
# 88816                                       NaN
#
#                                                        SOJobs  \
# Respondent
# 22363       No, I didn't know that Stack Overflow had a jo...
# 22975                                                     Yes
# 47247       No, I didn't know that Stack Overflow had a jo...
# 51356       No, I didn't know that Stack Overflow had a jo...
# 69495                                                     Yes
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                        EntTeams           SOComm  \
# Respondent
# 22363       No, and I don't know what those are         Not sure
# 22975       No, and I don't know what those are  Yes, definitely
# 47247       No, and I don't know what those are  Yes, definitely
# 51356       No, and I don't know what those are    Yes, somewhat
# 69495       No, and I don't know what those are    Yes, somewhat
# ...                                         ...              ...
# 88062                                       NaN              NaN
# 88076                                       NaN              NaN
# 88601                                       NaN              NaN
# 88802                                       NaN              NaN
# 88816                                       NaN              NaN
#
#                                        WelcomeChange  \
# Respondent
# 22363        Just as welcome now as I felt last year
# 22975          A lot more welcome now than last year
# 47247        Just as welcome now as I felt last year
# 51356        Just as welcome now as I felt last year
# 69495       Somewhat more welcome now than last year
# ...                                              ...
# 88062                                            NaN
# 88076                                            NaN
# 88601                                            NaN
# 88802                                            NaN
# 88816                                            NaN
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 22363               Tech articles written by other developers  30.0    Man
# 22975       Tech articles written by other developers;Indu...  25.0    Man
# 47247       Tech articles written by other developers;Indu...  26.0    Man
# 51356       Tech articles written by other developers;Indu...   NaN    Man
# 69495       Tech articles written by other developers;Indu...  21.0    Man
# ...                                                       ...   ...    ...
# 88062                                                     NaN   NaN    NaN
# 88076                                                     NaN   NaN    NaN
# 88601                                                     NaN   NaN    NaN
# 88802                                                     NaN   NaN    NaN
# 88816                                                     NaN   NaN    NaN
#
#            Trans                Sexuality                    Ethnicity  \
# Respondent
# 22363         No  Straight / Heterosexual  Black or of African descent
# 22975         No  Straight / Heterosexual  Black or of African descent
# 47247         No  Straight / Heterosexual  Black or of African descent
# 51356         No                 Bisexual  Black or of African descent
# 69495         No  Straight / Heterosexual  Black or of African descent
# ...          ...                      ...                          ...
# 88062        NaN                      NaN                          NaN
# 88076        NaN                      NaN                          NaN
# 88601        NaN                      NaN                          NaN
# 88802        NaN                      NaN                          NaN
# 88816        NaN                      NaN                          NaN
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 22363             Yes               Too long                        Easy
# 22975              No  Appropriate in length  Neither easy nor difficult
# 47247             Yes               Too long  Neither easy nor difficult
# 51356             NaN               Too long  Neither easy nor difficult
# 69495              No  Appropriate in length                        Easy
# ...               ...                    ...                         ...
# 88062             NaN                    NaN                         NaN
# 88076             NaN                    NaN                         NaN
# 88601             NaN                    NaN                         NaN
# 88802             NaN                    NaN                         NaN
# 88816             NaN                    NaN                         NaN
#
# [88883 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.JobSat.unique()
# Out:
# array([nan, 'Slightly satisfied', 'Slightly dissatisfied',
#        'Neither satisfied nor dissatisfied', 'Very satisfied',
#        'Very dissatisfied'], dtype=object)

# %%
df.JobSat.value_counts()
# Out:
# Slightly satisfied                    24207
# Very satisfied                        22452
# Slightly dissatisfied                 10752
# Neither satisfied nor dissatisfied     8720
# Very dissatisfied                      4857
# Name: JobSat, dtype: int64

# %%
df['JobSat'] == 'Very dissatisfied'
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: JobSat, Length: 88883, dtype: bool

# %%
filt = (df['JobSat'] == 'Very dissatisfied') & (df['Age'] >20) & (df['Age'] <30)

# %%
df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 35          I am a developer by profession       No
# 90          I am a developer by profession      Yes
# 91          I am a developer by profession      Yes
# 104         I am a developer by profession      Yes
# 172         I am a developer by profession      Yes
# ...                                    ...      ...
# 88828       I am a developer by profession      Yes
# 88848       I am a developer by profession      Yes
# 88858       I am a developer by profession      Yes
# 88869       I am a developer by profession       No
# 88871       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 35                                                      Never
# 90          Less than once a month but more than once per ...
# 91                                 Once a month or more often
# 104                                                     Never
# 172                                   Less than once per year
# ...                                                       ...
# 88828                                                   Never
# 88848       Less than once a month but more than once per ...
# 88858       Less than once a month but more than once per ...
# 88869                                                   Never
# 88871                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 35          OSS is, on average, of HIGHER quality than pro...
# 90          The quality of OSS and closed source software ...
# 91          OSS is, on average, of HIGHER quality than pro...
# 104         OSS is, on average, of LOWER quality than prop...
# 172         OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 88828       OSS is, on average, of LOWER quality than prop...
# 88848       The quality of OSS and closed source software ...
# 88858       The quality of OSS and closed source software ...
# 88869       OSS is, on average, of LOWER quality than prop...
# 88871       The quality of OSS and closed source software ...
#
#                                                    Employment        Country  \
# Respondent
# 35                                         Employed full-time  United States
# 90                                         Employed full-time          India
# 91          Independent contractor, freelancer, or self-em...     Azerbaijan
# 104                                        Employed full-time          India
# 172                                        Employed full-time          Spain
# ...                                                       ...            ...
# 88828                                      Employed full-time         Brazil
# 88848                                      Employed full-time         Brazil
# 88858                                      Employed full-time         Canada
# 88869                                      Employed full-time          India
# 88871                                      Employed full-time         Poland
#
#                    Student                                            EdLevel  \
# Respondent
# 35                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 90                      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 91                      No                                   Associate degree
# 104         Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 172                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 88828       Yes, part-time  Some college/university study without earning ...
# 88848                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88858                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88869                  NaN                                                NaN
# 88871       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 35          Information systems, information technology, o...
# 90          Computer science, computer engineering, or sof...
# 91          Information systems, information technology, o...
# 104         Computer science, computer engineering, or sof...
# 172         Computer science, computer engineering, or sof...
# ...                                                       ...
# 88828       Computer science, computer engineering, or sof...
# 88848       Computer science, computer engineering, or sof...
# 88858       Computer science, computer engineering, or sof...
# 88869                                                     NaN
# 88871       Information systems, information technology, o...
#
#                                                      EduOther  \
# Respondent
# 35          Taken a part-time in-person course in programm...
# 90          Taught yourself a new language, framework, or ...
# 91          Taken an online course in programming or softw...
# 104         Taken a part-time in-person course in programm...
# 172         Taken an online course in programming or softw...
# ...                                                       ...
# 88828       Taken an online course in programming or softw...
# 88848       Taken an online course in programming or softw...
# 88858       Received on-the-job training in software devel...
# 88869                                                     NaN
# 88871       Taught yourself a new language, framework, or ...
#
#                                                       OrgSize  \
# Respondent
# 35                                         20 to 99 employees
# 90                                         20 to 99 employees
# 91                                         10 to 19 employees
# 104                                  1,000 to 4,999 employees
# 172         Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# 88828                                10,000 or more employees
# 88848                                      20 to 99 employees
# 88858                                10,000 or more employees
# 88869                                                     NaN
# 88871                                      20 to 99 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 35                                       Developer, front-end        14
# 90          Developer, front-end;Developer, full-stack;Sys...         6
# 91                 Developer, front-end;Developer, full-stack         5
# 104                Developer, front-end;Developer, full-stack         7
# 172                  Developer, back-end;Developer, front-end         8
# ...                                                       ...       ...
# 88828                                       Developer, mobile         7
# 88848               Developer, back-end;Developer, full-stack        12
# 88858             Developer, embedded applications or devices         7
# 88869                                                     NaN       NaN
# 88871       Developer, back-end;Developer, embedded applic...         5
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 35                 21           14                  Slightly satisfied
# 90                 17            2               Slightly dissatisfied
# 91                 13            2                   Very dissatisfied
# 104                21            7                  Slightly satisfied
# 172                23            4                   Very dissatisfied
# ...               ...          ...                                 ...
# 88828              19            5  Neither satisfied nor dissatisfied
# 88848              16            8                  Slightly satisfied
# 88858              11            3               Slightly dissatisfied
# 88869             NaN          NaN                   Very dissatisfied
# 88871              15            2                   Very dissatisfied
#
#                        JobSat                MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 35          Very dissatisfied          Very confident        No        No
# 90          Very dissatisfied  I don't have a manager       Yes        No
# 91          Very dissatisfied                     NaN       NaN       NaN
# 104         Very dissatisfied      Somewhat confident        No        No
# 172         Very dissatisfied          Very confident       Yes       Yes
# ...                       ...                     ...       ...       ...
# 88828       Very dissatisfied          Very confident  Not sure  Not sure
# 88848       Very dissatisfied    Not at all confident        No  Not sure
# 88858       Very dissatisfied      Somewhat confident        No  Not sure
# 88869       Very dissatisfied          Very confident       Yes       Yes
# 88871       Very dissatisfied          Very confident  Not sure  Not sure
#
#                                                       JobSeek  \
# Respondent
# 35               I am not interested in new job opportunities
# 90          I’m not actively looking, but I am open to new...
# 91                            I am actively looking for a job
# 104                           I am actively looking for a job
# 172         I’m not actively looking, but I am open to new...
# ...                                                       ...
# 88828            I am not interested in new job opportunities
# 88848                         I am actively looking for a job
# 88858                         I am actively looking for a job
# 88869       I’m not actively looking, but I am open to new...
# 88871            I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 35                 1-2 years ago
# 90                 1-2 years ago
# 91          Less than a year ago
# 104                1-2 years ago
# 172                1-2 years ago
# ...                          ...
# 88828       Less than a year ago
# 88848       Less than a year ago
# 88858              1-2 years ago
# 88869       Less than a year ago
# 88871       Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 35          Write code by hand (e.g., on a whiteboard);Com...       No
# 90          Interview with people in senior / management r...       No
# 91          Interview with people in senior / management r...       No
# 104         Write code by hand (e.g., on a whiteboard);Int...       No
# 172                Write code by hand (e.g., on a whiteboard)       No
# ...                                                       ...      ...
# 88828       Write any code;Interview with people in senior...       No
# 88848       Write any code;Complete a take-home project;In...       No
# 88858       Write any code;Interview with people in peer r...       No
# 88869       Write any code;Write code by hand (e.g., on a ...       No
# 88871                       Solve a brain-teaser style puzzle       No
#
#                                                    JobFactors  \
# Respondent
# 35          Office environment or company culture;Diversit...
# 90          Languages, frameworks, and other technologies ...
# 91          Industry that I'd be working in;Office environ...
# 104         Languages, frameworks, and other technologies ...
# 172         Financial performance or funding status of the...
# ...                                                       ...
# 88828       Languages, frameworks, and other technologies ...
# 88848       Languages, frameworks, and other technologies ...
# 88858       Financial performance or funding status of the...
# 88869       Remote work options;Opportunities for professi...
# 88871       Languages, frameworks, and other technologies ...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 35                           I was preparing for a job search            USD
# 90                           I was preparing for a job search            INR
# 91                           I was preparing for a job search            AZN
# 104                          I was preparing for a job search            INR
# 172         I heard about a job opportunity (from a recrui...            GBP
# ...                                                       ...            ...
# 88828                        I was preparing for a job search            BRL
# 88848                        I was preparing for a job search            BRL
# 88858       I had a negative experience or interaction at ...            CAD
# 88869       I heard about a job opportunity (from a recrui...            INR
# 88871        My job status changed (promotion, new job, etc.)            PLN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 35          United States dollar    80000.0   Yearly        80000.0
# 90                  Indian rupee   100000.0  Monthly        16788.0
# 91              Azerbaijan manat        NaN      NaN            NaN
# 104                 Indian rupee   155000.0   Yearly         2169.0
# 172               Pound sterling    50000.0   Yearly        65424.0
# ...                          ...        ...      ...            ...
# 88828             Brazilian real        NaN  Monthly            NaN
# 88848             Brazilian real     4050.0  Monthly        13272.0
# 88858            Canadian dollar    80000.0   Yearly        61071.0
# 88869               Indian rupee        NaN      NaN            NaN
# 88871               Polish zloty     5000.0  Monthly        16032.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 35                 40.0  There is a schedule and/or spec (made by me or...
# 90                 50.0  There is a schedule and/or spec (made by me or...
# 91                  NaN  There's no schedule or spec; I work on what se...
# 104                 6.0  There is a schedule and/or spec (made by me or...
# 172                40.0  There's no schedule or spec; I work on what se...
# ...                 ...                                                ...
# 88828              40.0  There is a schedule and/or spec (made by me or...
# 88848              40.0  There is a schedule and/or spec (made by me or...
# 88858              40.0  There is a schedule and/or spec (made by me or...
# 88869               NaN                                                NaN
# 88871             168.0  There's no schedule or spec; I work on what se...
#
#                                                 WorkChallenge  \
# Respondent
# 35          Inadequate access to necessary tools;Non-work ...
# 90          Distracting work environment;Inadequate access...
# 91          Distracting work environment;Meetings;Non-work...
# 104         Being tasked with non-development work;Lack of...
# 172         Distracting work environment;Lack of support f...
# ...                                                       ...
# 88828                            Distracting work environment
# 88848       Being tasked with non-development work;Lack of...
# 88858       Lack of support from management;Non-work commi...
# 88869       Being tasked with non-development work;Distrac...
# 88871       Being tasked with non-development work;Distrac...
#
#                                                    WorkRemote  \
# Respondent
# 35                           Less than once per month / Never
# 90                                      A few days each month
# 91                           Less than once per month / Never
# 104                                     A few days each month
# 172                                     A few days each month
# ...                                                       ...
# 88828       Less than half the time, but at least one day ...
# 88848                        Less than once per month / Never
# 88858                                        It's complicated
# 88869       All or almost all the time (I'm full-time remote)
# 88871                                   A few days each month
#
#                                                    WorkLoc  \
# Respondent
# 35                                                    Home
# 90                                                    Home
# 91                                                  Office
# 104                                                   Home
# 172                                                 Office
# ...                                                    ...
# 88828                                                 Home
# 88848       Other place, such as a coworking space or cafe
# 88858                                               Office
# 88869                                                 Home
# 88871                                               Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 35                         Average  Yes, because I see value in code review
# 90          A little above average  Yes, because I see value in code review
# 91          A little above average                                       No
# 104         A little above average  Yes, because I see value in code review
# 172                        Average                                       No
# ...                            ...                                      ...
# 88828       A little above average  Yes, because I see value in code review
# 88848       A little below average  Yes, because I see value in code review
# 88858                      Average  Yes, because I see value in code review
# 88869       A little below average  Yes, because I see value in code review
# 88871       A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                      UnitTests  \
# Respondent
# 35                 0.5  Yes, it's part of our process
# 90                 3.0      No, but I think we should
# 91                 NaN                            NaN
# 104                4.0      No, but I think we should
# 172                NaN                            NaN
# ...                ...                            ...
# 88828              2.0  Yes, it's part of our process
# 88848              4.0  Yes, it's part of our process
# 88858              1.0  Yes, it's part of our process
# 88869              3.0  Yes, it's part of our process
# 88871              4.0      No, but I think we should
#
#                                                   PurchaseHow  \
# Respondent
# 35          Developers and management have nearly equal in...
# 90          The CTO, CIO, or other management purchase new...
# 91                                                        NaN
# 104                                                  Not sure
# 172                                                       NaN
# ...                                                       ...
# 88828                                                Not sure
# 88848       The CTO, CIO, or other management purchase new...
# 88858                                                Not sure
# 88869                                                     NaN
# 88871                                                Not sure
#
#                                 PurchaseWhat  \
# Respondent
# 35                     I have some influence
# 90                     I have some influence
# 91                                       NaN
# 104            I have little or no influence
# 172                                      NaN
# ...                                      ...
# 88828          I have little or no influence
# 88848                  I have some influence
# 88858          I have little or no influence
# 88869                                    NaN
# 88871       I have a great deal of influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 35                                        HTML/CSS;JavaScript
# 90          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 91                             HTML/CSS;JavaScript;TypeScript
# 104                                    C#;HTML/CSS;TypeScript
# 172                       HTML/CSS;JavaScript;Objective-C;SQL
# ...                                                       ...
# 88828                             C;C++;C#;JavaScript;SQL;VBA
# 88848                   C#;HTML/CSS;JavaScript;SQL;TypeScript
# 88858         C;Go;HTML/CSS;JavaScript;Python;Rust;TypeScript
# 88869                             HTML/CSS;JavaScript;PHP;SQL
# 88871       C++;C#;HTML/CSS;Java;JavaScript;Python;SQL;Typ...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 35                                                        NaN
# 90          Bash/Shell/PowerShell;C#;JavaScript;Objective-...
# 91                                                        NaN
# 104                                                TypeScript
# 172                                   HTML/CSS;JavaScript;SQL
# ...                                                       ...
# 88828                                     Java;JavaScript;SQL
# 88848         C#;Go;HTML/CSS;JavaScript;Kotlin;SQL;TypeScript
# 88858       C;Go;HTML/CSS;JavaScript;Python;Ruby;Rust;Type...
# 88869                                         Kotlin;Python;R
# 88871       Bash/Shell/PowerShell;C++;C#;HTML/CSS;Java;Jav...
#
#                                      DatabaseWorkedWith  \
# Respondent
# 35                                                  NaN
# 90                       DynamoDB;Firebase;MySQL;SQLite
# 91                                              MongoDB
# 104                                Microsoft SQL Server
# 172                                               MySQL
# ...                                                 ...
# 88828                 MySQL;PostgreSQL;SQLite;Other(s):
# 88848       Microsoft SQL Server;MySQL;Oracle;Other(s):
# 88858                                  PostgreSQL;Redis
# 88869                                     MariaDB;MySQL
# 88871             Microsoft SQL Server;MySQL;PostgreSQL
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 35                                                        NaN
# 90                       Elasticsearch;MySQL;PostgreSQL;Redis
# 91                                                        NaN
# 104                                                 Couchbase
# 172                                                     MySQL
# ...                                                       ...
# 88828                                                     NaN
# 88848       Cassandra;Elasticsearch;Firebase;MongoDB;Micro...
# 88858                                        PostgreSQL;Redis
# 88869                    Elasticsearch;Firebase;MongoDB;Redis
# 88871       Elasticsearch;Firebase;MongoDB;MySQL;PostgreSQ...
#
#                                   PlatformWorkedWith  \
# Respondent
# 35                       Linux;MacOS;Slack;WordPress
# 90          Android;Docker;Google Cloud Platform;iOS
# 91                                           Windows
# 104                                          Windows
# 172                                        WordPress
# ...                                              ...
# 88828                        Android;Arduino;Windows
# 88848                        Microsoft Azure;Windows
# 88858                            Docker;Heroku;Linux
# 88869                             AWS;Heroku;Windows
# 88871                   Android;Docker;Linux;Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 35                                                        NaN
# 90                              Android;Docker;iOS;Kubernetes
# 91                                                      MacOS
# 104                                AWS;Docker;Microsoft Azure
# 172                                                 WordPress
# ...                                                       ...
# 88828                                         Android;Windows
# 88848       Android;AWS;Docker;Microsoft Azure;Raspberry P...
# 88858                                 AWS;Docker;Heroku;Linux
# 88869                    IBM Cloud or Watson;Kubernetes;Linux
# 88871       AWS;Docker;Google Cloud Platform;Kubernetes;Li...
#
#                                   WebFrameWorkedWith  \
# Respondent
# 35                                Angular/Angular.js
# 90                            React.js;Ruby on Rails
# 91                                   jQuery;React.js
# 104                Angular/Angular.js;ASP.NET;jQuery
# 172                                           jQuery
# ...                                              ...
# 88828                                            NaN
# 88848                                 ASP.NET;jQuery
# 88858                                       React.js
# 88869         Express;Laravel;React.js;Ruby on Rails
# 88871       Angular/Angular.js;ASP.NET;Spring;Vue.js
#
#                               WebFrameDesireNextYear  \
# Respondent
# 35                                               NaN
# 90                            React.js;Ruby on Rails
# 91                                          React.js
# 104                               Angular/Angular.js
# 172                                           jQuery
# ...                                              ...
# 88828                                         Spring
# 88848              Angular/Angular.js;ASP.NET;Vue.js
# 88858                                       React.js
# 88869                 Laravel;React.js;Ruby on Rails
# 88871       Angular/Angular.js;ASP.NET;Spring;Vue.js
#
#                        MiscTechWorkedWith           MiscTechDesireNextYear  \
# Respondent
# 35                                    NaN                              NaN
# 90                 .NET;.NET Core;Node.js  .NET Core;Node.js;Unreal Engine
# 91                                    NaN                              NaN
# 104                                  .NET                        .NET Core
# 172                             Other(s):                        Other(s):
# ...                                   ...                              ...
# 88828       React Native;Unity 3D;Xamarin            React Native;Unity 3D
# 88848                      .NET;.NET Core        .NET Core;Node.js;Xamarin
# 88858                     Ansible;Node.js                          Node.js
# 88869                             Node.js      Hadoop;Node.js;React Native
# 88871                   .NET Core;Node.js        Ansible;.NET Core;Node.js
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 35                                    Atom;Visual Studio Code        MacOS
# 90          Android Studio;IntelliJ;RubyMine;Vim;Visual St...        MacOS
# 91                            Sublime Text;Visual Studio Code      Windows
# 104                Notepad++;Visual Studio;Visual Studio Code      Windows
# 172                                     PHPStorm;Sublime Text        MacOS
# ...                                                       ...          ...
# 88828                    Eclipse;Notepad++;Visual Studio Code      Windows
# 88848              Notepad++;Visual Studio;Visual Studio Code      Windows
# 88858                                  Vim;Visual Studio Code        MacOS
# 88869                             NetBeans;Notepad++;PHPStorm  Linux-based
# 88871           IntelliJ;Notepad++;PyCharm;Visual Studio Code      Windows
#
#                                                    Containers  \
# Respondent
# 35                                                Development
# 90          Development;Production;Outside of work, for pe...
# 91                                    I do not use containers
# 104                                               Development
# 172                                   I do not use containers
# ...                                                       ...
# 88828                                 I do not use containers
# 88848                                 I do not use containers
# 88858       Development;Testing;Outside of work, for perso...
# 88869                                 I do not use containers
# 88871       Development;Testing;Production;Outside of work...
#
#                                          BlockchainOrg  \
# Respondent
# 35                                                 NaN
# 90          Implementing cryptocurrency-based products
# 91                                                 NaN
# 104            Non-currency applications of blockchain
# 172                                         Not at all
# ...                                                ...
# 88828                                              NaN
# 88848                                       Not at all
# 88858          Non-currency applications of blockchain
# 88869                                       Not at all
# 88871                                       Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 35                                                        NaN        Yes
# 90                                                        NaN         No
# 91                                                        NaN        Yes
# 104         Useful across many domains and could change ma...         No
# 172                                                       NaN         No
# ...                                                       ...        ...
# 88828       Useful across many domains and could change ma...        Yes
# 88848                                                     NaN        Yes
# 88858       Useful for immutable record keeping outside of...        NaN
# 88869       Useful for decentralized currency (i.e., Bitcoin)         No
# 88871                                                     NaN        Yes
#
#                                             ITperson  OffOn SocialMedia  \
# Respondent
# 35          Fortunately, someone else has that title    Yes   Instagram
# 90                                              SIGH    Yes     Twitter
# 91                                              SIGH    Yes     Twitter
# 104                                         Also Yes  What?     YouTube
# 172                                              Yes    Yes    WhatsApp
# ...                                              ...    ...         ...
# 88828                                            Yes    Yes   Instagram
# 88848                                            Yes    Yes   Instagram
# 88858                                            NaN    NaN     Twitter
# 88869                                           SIGH  What?    WhatsApp
# 88871                                           SIGH    Yes      Reddit
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 35                            Online   Username              2014
# 90                            Online   Username              2014
# 91          In real life (in person)      Login              2010
# 104                           Online     UserID              2013
# 172         In real life (in person)   Username              2015
# ...                              ...        ...               ...
# 88828       In real life (in person)   Username              2009
# 88848       In real life (in person)      Login              2010
# 88858       In real life (in person)   Username  I don't remember
# 88869                         Online     UserID              2011
# 88871       In real life (in person)   Username              2018
#
#                                 SOVisitFreq  \
# Respondent
# 35          A few times per month or weekly
# 90                   Multiple times per day
# 91                    Daily or almost daily
# 104                  Multiple times per day
# 172                    A few times per week
# ...                                     ...
# 88828                Multiple times per day
# 88848                 Daily or almost daily
# 88858                  A few times per week
# 88869                Multiple times per day
# 88871                 Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 35                         Find answers to specific questions
# 90          Find answers to specific questions;Learn how t...
# 91          Find answers to specific questions;Learn how t...
# 104         Find answers to specific questions;Contribute ...
# 172         Find answers to specific questions;Learn how t...
# ...                                                       ...
# 88828       Find answers to specific questions;Learn how t...
# 88848                      Find answers to specific questions
# 88858                      Find answers to specific questions
# 88869       Find answers to specific questions;Learn how t...
# 88871       Find answers to specific questions;Learn how t...
#
#                        SOFindAnswer                         SOTimeSaved  \
# Respondent
# 35               1-2 times per week  Stack Overflow was slightly faster
# 90              6-10 times per week      Stack Overflow was much faster
# 91          Less than once per week      Stack Overflow was much faster
# 104         Less than once per week      Stack Overflow was much faster
# 172              3-5 times per week            They were about the same
# ...                             ...                                 ...
# 88828            1-2 times per week  Stack Overflow was slightly faster
# 88848            3-5 times per week      Stack Overflow was much faster
# 88858            3-5 times per week  Stack Overflow was slightly faster
# 88869            1-2 times per week            They were about the same
# 88871           6-10 times per week  Stack Overflow was slightly faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 35          11-30 minutes        No
# 90          11-30 minutes       Yes
# 91          11-30 minutes       Yes
# 104         11-30 minutes       Yes
# 172                   NaN       Yes
# ...                   ...       ...
# 88828       11-30 minutes       Yes
# 88848       11-30 minutes       Yes
# 88858       11-30 minutes        No
# 88869                 NaN       Yes
# 88871       31-60 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 35                                                        NaN
# 90          I have never participated in Q&A on Stack Over...
# 91                        Less than once per month or monthly
# 104                                    Multiple times per day
# 172                       Less than once per month or monthly
# ...                                                       ...
# 88828                                   Daily or almost daily
# 88848                     Less than once per month or monthly
# 88858                                                     NaN
# 88869                     Less than once per month or monthly
# 88871       I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 35          No, I knew that Stack Overflow had a job board...
# 90          No, I didn't know that Stack Overflow had a jo...
# 91                                                        Yes
# 104                                                       Yes
# 172                                                       Yes
# ...                                                       ...
# 88828       No, I knew that Stack Overflow had a job board...
# 88848                                                     Yes
# 88858                                                     Yes
# 88869                                                     Yes
# 88871       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 35                        No, and I don't know what those are
# 90                        No, and I don't know what those are
# 91          No, I've heard of them, but I am not part of a...
# 104                                                       Yes
# 172                       No, and I don't know what those are
# ...                                                       ...
# 88828                     No, and I don't know what those are
# 88848                     No, and I don't know what those are
# 88858       No, I've heard of them, but I am not part of a...
# 88869                     No, and I don't know what those are
# 88871       No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 35                 Not sure  Just as welcome now as I felt last year
# 90           No, not really  Just as welcome now as I felt last year
# 91            Yes, somewhat  Just as welcome now as I felt last year
# 104         Yes, definitely  Just as welcome now as I felt last year
# 172          No, not really  Just as welcome now as I felt last year
# ...                     ...                                      ...
# 88828       Yes, definitely    A lot more welcome now than last year
# 88848        No, not really  Just as welcome now as I felt last year
# 88858        No, not really  Just as welcome now as I felt last year
# 88869               Neutral    A lot more welcome now than last year
# 88871        No, not at all  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 35          Tech articles written by other developers;Indu...  35.0  Woman
# 90          Tech articles written by other developers;Indu...  25.0    Man
# 91          Tech articles written by other developers;Tech...  25.0    Man
# 104         Tech articles written by other developers;Indu...  29.0    Man
# 172         Tech meetups or events in your area;Courses on...  31.0    Man
# ...                                                       ...   ...    ...
# 88828       Tech articles written by other developers;Indu...  27.0    Man
# 88848                                                     NaN  28.0    Man
# 88858       Industry news about technologies you're intere...  24.0    Man
# 88869               Tech articles written by other developers  30.0    Man
# 88871       Tech articles written by other developers;Cour...  22.0    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 35            No  Straight / Heterosexual   Black or of African descent
# 90            No  Straight / Heterosexual                           NaN
# 91            No  Straight / Heterosexual  White or of European descent
# 104           No  Straight / Heterosexual                   South Asian
# 172           No  Straight / Heterosexual  White or of European descent
# ...          ...                      ...                           ...
# 88828         No  Straight / Heterosexual  White or of European descent
# 88848         No  Straight / Heterosexual     Hispanic or Latino/Latina
# 88858         No                      NaN  White or of European descent
# 88869         No                      NaN                   South Asian
# 88871         No  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 35                 No  Appropriate in length                        Easy
# 90                Yes  Appropriate in length                        Easy
# 91                 No  Appropriate in length  Neither easy nor difficult
# 104               Yes  Appropriate in length                        Easy
# 172                No               Too long                        Easy
# ...               ...                    ...                         ...
# 88828              No  Appropriate in length                        Easy
# 88848              No               Too long  Neither easy nor difficult
# 88858              No               Too long  Neither easy nor difficult
# 88869              No               Too long  Neither easy nor difficult
# 88871              No               Too long  Neither easy nor difficult
#
# [3523 rows x 84 columns]

# %%
countries = ['Germany', 'Spain', 'Georgia']
filt = df['Country'].isin(countries)
df.loc[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 14          I am a developer by profession      Yes
# 36          I am a developer by profession      Yes
# 43          I am a developer by profession      Yes
# 44          I am a developer by profession      Yes
# 66          I am a developer by profession      Yes
# ...                                    ...      ...
# 75974                                  NaN      Yes
# 80319                                  NaN      Yes
# 83786                                  NaN       No
# 88212                                  NaN       No
# 88863                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 14                                    Less than once per year
# 36          Less than once a month but more than once per ...
# 43                                    Less than once per year
# 44                                 Once a month or more often
# 66                                 Once a month or more often
# ...                                                       ...
# 75974                              Once a month or more often
# 80319                                                   Never
# 83786                              Once a month or more often
# 88212                                 Less than once per year
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 14          The quality of OSS and closed source software ...
# 36          The quality of OSS and closed source software ...
# 43          OSS is, on average, of HIGHER quality than pro...
# 44          The quality of OSS and closed source software ...
# 66          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 75974       OSS is, on average, of HIGHER quality than pro...
# 80319       OSS is, on average, of HIGHER quality than pro...
# 83786       The quality of OSS and closed source software ...
# 88212       OSS is, on average, of HIGHER quality than pro...
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  Country  \
# Respondent
# 14                                         Employed full-time  Germany
# 36                                         Employed full-time  Germany
# 43                                         Employed full-time    Spain
# 44                                         Employed full-time  Germany
# 66                                         Employed full-time  Germany
# ...                                                       ...      ...
# 75974                                      Employed full-time  Germany
# 80319       Independent contractor, freelancer, or self-em...  Germany
# 83786                                      Employed full-time  Germany
# 88212                                      Employed full-time    Spain
# 88863                  Not employed, and not looking for work    Spain
#
#                    Student                                            EdLevel  \
# Respondent
# 14                      No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 36          Yes, full-time  Secondary school (e.g. American high school, G...
# 43                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 44                      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 66                      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...                    ...                                                ...
# 75974                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 80319                   No  Secondary school (e.g. American high school, G...
# 83786                   No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 88212                   No  Secondary school (e.g. American high school, G...
# 88863       Yes, full-time                 Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 14          Computer science, computer engineering, or sof...
# 36                                                        NaN
# 43          Computer science, computer engineering, or sof...
# 44          Information systems, information technology, o...
# 66          Computer science, computer engineering, or sof...
# ...                                                       ...
# 75974       Another engineering discipline (ex. civil, ele...
# 80319                                                     NaN
# 83786       Computer science, computer engineering, or sof...
# 88212                                                     NaN
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 14          Completed an industry certification program (e...
# 36          Taken an online course in programming or softw...
# 43          Taken an online course in programming or softw...
# 44          Taken an online course in programming or softw...
# 66          Taken an online course in programming or softw...
# ...                                                       ...
# 75974       Taught yourself a new language, framework, or ...
# 80319       Taught yourself a new language, framework, or ...
# 83786       Taught yourself a new language, framework, or ...
# 88212       Taught yourself a new language, framework, or ...
# 88863       Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 14                                       100 to 499 employees
# 36                                   1,000 to 4,999 employees
# 43                                   10,000 or more employees
# 44                                   10,000 or more employees
# 66                                              2-9 employees
# ...                                                       ...
# 75974                                1,000 to 4,999 employees
# 80319       Just me - I am a freelancer, sole proprietor, ...
# 83786                                    500 to 999 employees
# 88212                                      10 to 19 employees
# 88863                                                     NaN
#
#                                                       DevType YearsCode  \
# Respondent
# 14              Developer, desktop or enterprise applications        13
# 36                                  Developer, mobile;Student        10
# 43          Developer, front-end;Developer, game or graphi...         9
# 44          Developer, back-end;Developer, desktop or ente...        26
# 66          Data scientist or machine learning specialist;...        30
# ...                                                       ...       ...
# 75974       Developer, full-stack;DevOps specialist;Engine...        20
# 80319       Database administrator;Designer;Developer, bac...         5
# 83786                                     Academic researcher        36
# 88212       Designer;Developer, front-end;Developer, full-...        18
# 88863                                                     NaN         8
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 14                 16                 2      Very satisfied
# 36                 10  Less than 1 year      Very satisfied
# 43                 15                 2   Very dissatisfied
# 44                 12                19  Slightly satisfied
# 66                  7                25      Very satisfied
# ...               ...               ...                 ...
# 75974              14                15                 NaN
# 80319              13                 1                 NaN
# 83786              21                29                 NaN
# 88212               7                15                 NaN
# 88863              11                 3                 NaN
#
#                                         JobSat              MgrIdiot  \
# Respondent
# 14                              Very satisfied        Very confident
# 36                              Very satisfied        Very confident
# 43                       Slightly dissatisfied        Very confident
# 44          Neither satisfied nor dissatisfied  Not at all confident
# 66                              Very satisfied                   NaN
# ...                                        ...                   ...
# 75974                                      NaN                   NaN
# 80319                                      NaN                   NaN
# 83786                                      NaN  Not at all confident
# 88212                                      NaN    Somewhat confident
# 88863                                      NaN                   NaN
#
#             MgrMoney                 MgrWant  \
# Respondent
# 14                No                      No
# 36          Not sure                Not sure
# 43                No                     Yes
# 44                No                Not sure
# 66               NaN                     NaN
# ...              ...                     ...
# 75974            NaN                     NaN
# 80319            NaN                     NaN
# 83786             No                      No
# 88212            Yes  I am already a manager
# 88863            NaN                     NaN
#
#                                                       JobSeek  \
# Respondent
# 14               I am not interested in new job opportunities
# 36          I’m not actively looking, but I am open to new...
# 43          I’m not actively looking, but I am open to new...
# 44          I’m not actively looking, but I am open to new...
# 66          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                                  LastHireDate  \
# Respondent
# 14                                              1-2 years ago
# 36                                       Less than a year ago
# 43                                       Less than a year ago
# 44                                      More than 4 years ago
# 66          NA - I am an independent contractor or self em...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 14          Interview with people in senior / management r...       No
# 36          Interview with people in senior / management r...       No
# 43          Write any code;Interview with people in peer r...       No
# 44          Interview with people in peer roles;Interview ...       No
# 66          Write any code;Write code by hand (e.g., on a ...       No
# ...                                                       ...      ...
# 75974                                                     NaN      NaN
# 80319                                                     NaN      NaN
# 83786                                                     NaN      NaN
# 88212                                                     NaN      NaN
# 88863                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 14          Languages, frameworks, and other technologies ...
# 36          Languages, frameworks, and other technologies ...
# 43          Specific department or team I'd be working on;...
# 44          Specific department or team I'd be working on;...
# 66          Financial performance or funding status of the...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 14          Something else changed (education, award, medi...            EUR
# 36                           I was preparing for a job search            EUR
# 43                           I was preparing for a job search            EUR
# 44           My job status changed (promotion, new job, etc.)            EUR
# 66                           I was preparing for a job search            EUR
# ...                                                       ...            ...
# 75974                                                     NaN            NaN
# 80319                                                     NaN            NaN
# 83786                                                     NaN            NaN
# 88212                                                     NaN            NaN
# 88863                                                     NaN            NaN
#
#              CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# Respondent
# 14          European Euro     4150.0  Monthly        57060.0         40.0
# 36          European Euro     1500.0  Monthly        20628.0         38.0
# 43          European Euro    18000.0   Yearly        20623.0         40.0
# 44          European Euro     6400.0  Monthly        87996.0         39.0
# 66          European Euro   120000.0   Yearly       137490.0          NaN
# ...                   ...        ...      ...            ...          ...
# 75974                 NaN        NaN      NaN            NaN          NaN
# 80319                 NaN        NaN      NaN            NaN          NaN
# 83786                 NaN        NaN      NaN            NaN          NaN
# 88212                 NaN        NaN      NaN            NaN          NaN
# 88863                 NaN        NaN      NaN            NaN          NaN
#
#                                                      WorkPlan  \
# Respondent
# 14          There is a schedule and/or spec (made by me or...
# 36          There is a schedule and/or spec (made by me or...
# 43          There is a schedule and/or spec (made by me or...
# 44          There's no schedule or spec; I work on what se...
# 66          There is a schedule and/or spec (made by me or...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                                 WorkChallenge  \
# Respondent
# 14          Being tasked with non-development work;Not eno...
# 36          Being tasked with non-development work;Not eno...
# 43          Being tasked with non-development work;Meeting...
# 44          Distracting work environment;Inadequate access...
# 66          Being tasked with non-development work;Not eno...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 14                           Less than once per month / Never  Office
# 36                           Less than once per month / Never  Office
# 43                           Less than once per month / Never    Home
# 44                           Less than once per month / Never    Home
# 66          All or almost all the time (I'm full-time remote)    Home
# ...                                                       ...     ...
# 75974                                                     NaN     NaN
# 80319                                                     NaN     NaN
# 83786                                                     NaN     NaN
# 88212                                                     NaN     NaN
# 88863                                                     NaN     NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 14          A little above average  Yes, because I see value in code review
# 36                         Average  Yes, because I see value in code review
# 43               Far above average  Yes, because I see value in code review
# 44               Far above average  Yes, because I see value in code review
# 66                         Average  Yes, because I see value in code review
# ...                            ...                                      ...
# 75974                          NaN                                      NaN
# 80319                          NaN                                      NaN
# 83786                          NaN                                      NaN
# 88212                          NaN                                      NaN
# 88863                          NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 14                 4.0                      Yes, it's part of our process
# 36                 3.0  Yes, it's not part of our process but the deve...
# 43                 8.0                      Yes, it's part of our process
# 44                10.0                      Yes, it's part of our process
# 66                 NaN                      Yes, it's part of our process
# ...                ...                                                ...
# 75974              NaN                                                NaN
# 80319              NaN                                                NaN
# 83786              NaN                                                NaN
# 88212              NaN                                                NaN
# 88863              NaN                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 14          Developers typically have the most influence o...
# 36                                                   Not sure
# 43          Developers and management have nearly equal in...
# 44          The CTO, CIO, or other management purchase new...
# 66          Developers and management have nearly equal in...
# ...                                                       ...
# 75974                                                     NaN
# 80319                                                     NaN
# 83786                                                     NaN
# 88212                                                     NaN
# 88863                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 14                     I have some influence
# 36             I have little or no influence
# 43                     I have some influence
# 44                     I have some influence
# 66          I have a great deal of influence
# ...                                      ...
# 75974                                    NaN
# 80319                                    NaN
# 83786                                    NaN
# 88212                                    NaN
# 88863                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 14                                                        C++
# 36                                         Java;Kotlin;Python
# 43            C++;C#;HTML/CSS;Java;JavaScript;Objective-C;SQL
# 44          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 66                  Clojure;Go;HTML/CSS;Java;JavaScript;R;SQL
# ...                                                       ...
# 75974       Go;HTML/CSS;Java;JavaScript;Kotlin;Python;Swif...
# 80319       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 83786                   HTML/CSS;JavaScript;Kotlin;TypeScript
# 88212                              HTML/CSS;JavaScript;Python
# 88863       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 14                                                        C++
# 36                                              Kotlin;Python
# 43                                    C#;HTML/CSS;Objective-C
# 44                                                         C#
# 66                                                Clojure;SQL
# ...                                                       ...
# 75974         Go;HTML/CSS;JavaScript;Kotlin;Python;TypeScript
# 80319       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 83786                   HTML/CSS;JavaScript;Kotlin;TypeScript
# 88212                                              JavaScript
# 88863            C;C++;C#;HTML/CSS;Java;Objective-C;SQL;Swift
#
#                                          DatabaseWorkedWith  \
# Respondent
# 14                                                      NaN
# 36                                                      NaN
# 43                             Firebase;MySQL;Oracle;SQLite
# 44                                         Oracle;Other(s):
# 66                   Elasticsearch;MariaDB;MySQL;PostgreSQL
# ...                                                     ...
# 75974       Cassandra;DynamoDB;Elasticsearch;Firebase;MySQL
# 80319                                         MariaDB;MySQL
# 83786                                               MongoDB
# 88212                                      MySQL;PostgreSQL
# 88863           DynamoDB;MariaDB;Microsoft SQL Server;MySQL
#
#                      DatabaseDesireNextYear  \
# Respondent
# 14                                      NaN
# 36                                      NaN
# 43                                 Firebase
# 44                                Other(s):
# 66                               PostgreSQL
# ...                                     ...
# 75974                    Cassandra;Firebase
# 80319       MariaDB;MySQL;PostgreSQL;SQLite
# 83786                               MongoDB
# 88212                            PostgreSQL
# 88863           MariaDB;MySQL;Oracle;SQLite
#
#                                            PlatformWorkedWith  \
# Respondent
# 14                                                    Windows
# 36                                                    Android
# 43          Android;Arduino;iOS;MacOS;Raspberry Pi;Slack;W...
# 44                                              Linux;Windows
# 66                                     AWS;Docker;Linux;Slack
# ...                                                       ...
# 75974       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 80319                              Arduino;Linux;Raspberry Pi
# 83786                                         Android;Windows
# 88212                                                     NaN
# 88863                               iOS;Linux;MacOS;WordPress
#
#                                        PlatformDesireNextYear  \
# Respondent
# 14                                                    Windows
# 36                                         Android;AWS;Docker
# 43          Android;iOS;MacOS;Raspberry Pi;Slack;Windows;W...
# 44                       Docker;Linux;Microsoft Azure;Windows
# 66                                    Docker;Kubernetes;Linux
# ...                                                       ...
# 75974       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 80319                                            Docker;Linux
# 83786                Android;Docker;Heroku;Kubernetes;Windows
# 88212                                                 Arduino
# 88863       Android;AWS;Google Cloud Platform;IBM Cloud or...
#
#                                     WebFrameWorkedWith  \
# Respondent
# 14                                                 NaN
# 36                                                 NaN
# 43                               ASP.NET;Django;Spring
# 44                                       Spring;Vue.js
# 66                                       Django;Spring
# ...                                                ...
# 75974                           Express;Flask;React.js
# 80319                        Angular/Angular.js;jQuery
# 83786       Angular/Angular.js;Express;React.js;Spring
# 88212                                  Django;React.js
# 88863                           Django;jQuery;React.js
#
#                         WebFrameDesireNextYear  \
# Respondent
# 14                                         NaN
# 36                                         NaN
# 43                              ASP.NET;Spring
# 44                     Spring;Vue.js;Other(s):
# 66                                      Spring
# ...                                        ...
# 75974                   Express;Flask;React.js
# 80319         Angular/Angular.js;jQuery;Spring
# 83786       Angular/Angular.js;React.js;Spring
# 88212                          Django;React.js
# 88863                                   Django
#
#                                  MiscTechWorkedWith  \
# Respondent
# 14                                              NaN
# 36                                              NaN
# 43          .NET;.NET Core;Node.js;Unity 3D;Xamarin
# 44                                   .NET;.NET Core
# 66                                        Other(s):
# ...                                             ...
# 75974                               Ansible;Node.js
# 80319                               Cordova;Node.js
# 83786                                       Node.js
# 88212                                           NaN
# 88863                        Unity 3D;Unreal Engine
#
#                              MiscTechDesireNextYear  \
# Respondent
# 14                                    Unreal Engine
# 36                                          Ansible
# 43          .NET;.NET Core;Node.js;Unity 3D;Xamarin
# 44                                   .NET;.NET Core
# 66                                        Other(s):
# ...                                             ...
# 75974                                       Node.js
# 80319                    Cordova;Node.js;TensorFlow
# 83786                          Node.js;React Native
# 88212                                           NaN
# 88863                                           NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 14                                              Visual Studio      Windows
# 36          Android Studio;IntelliJ;Notepad++;PyCharm;RStu...        MacOS
# 43            Android Studio;Visual Studio;Visual Studio Code        MacOS
# 44                  IntelliJ;Visual Studio;Visual Studio Code      Windows
# 66               Atom;Eclipse;IntelliJ;Vim;Visual Studio Code  Linux-based
# ...                                                       ...          ...
# 75974       Android Studio;Emacs;Vim;Visual Studio Code;Xcode        MacOS
# 80319       Atom;IntelliJ;NetBeans;PHPStorm;PyCharm;Visual...  Linux-based
# 83786       Android Studio;IntelliJ;Notepad++;Visual Studi...      Windows
# 88212                                 Atom;Visual Studio Code        MacOS
# 88863       Android Studio;Atom;Eclipse;NetBeans;Notepad++...  Linux-based
#
#                                                    Containers  \
# Respondent
# 14                                    I do not use containers
# 36                     Outside of work, for personal projects
# 43                                                 Production
# 44                     Outside of work, for personal projects
# 66                             Development;Testing;Production
# ...                                                       ...
# 75974       Development;Testing;Production;Outside of work...
# 80319                                 I do not use containers
# 83786                                 I do not use containers
# 88212                                 I do not use containers
# 88863                                              Production
#
#                                       BlockchainOrg  \
# Respondent
# 14                                       Not at all
# 36              Implementing our own cryptocurrency
# 43                                              NaN
# 44          Non-currency applications of blockchain
# 66          Non-currency applications of blockchain
# ...                                             ...
# 75974                                    Not at all
# 80319                                           NaN
# 83786                                           NaN
# 88212       Non-currency applications of blockchain
# 88863                                           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 14                                                        NaN        Yes
# 36          Useful for immutable record keeping outside of...        Yes
# 43          Useful for decentralized currency (i.e., Bitcoin)         No
# 44          Useful for immutable record keeping outside of...        Yes
# 66          Useful for immutable record keeping outside of...        Yes
# ...                                                       ...        ...
# 75974       Useful across many domains and could change ma...        Yes
# 80319       Useful for decentralized currency (i.e., Bitcoin)         No
# 83786                                                     NaN         No
# 88212       Useful for immutable record keeping outside of...         No
# 88863       Useful for decentralized currency (i.e., Bitcoin)        Yes
#
#             ITperson OffOn               SocialMedia  \
# Respondent
# 14               Yes   Yes                    Reddit
# 36              SIGH   Yes                    Reddit
# 43              SIGH   Yes                  WhatsApp
# 44          Also Yes   Yes                   Twitter
# 66          Also Yes    No  I don't use social media
# ...              ...   ...                       ...
# 75974           SIGH   Yes                   Twitter
# 80319           SIGH   Yes                  WhatsApp
# 83786            Yes    No                   Twitter
# 88212           SIGH    No                  WhatsApp
# 88863       Also Yes   Yes                  WhatsApp
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 14                            Online   Username              2010
# 36                            Online   Username              2013
# 43          In real life (in person)      Login              2013
# 44          In real life (in person)      Login              2010
# 66          In real life (in person)        NaN              2008
# ...                              ...        ...               ...
# 75974       In real life (in person)        NaN  I don't remember
# 80319       In real life (in person)   Username              2014
# 83786                        Neither        NaN              2008
# 88212       In real life (in person)   Username              2008
# 88863       In real life (in person)        NaN              2012
#
#                                     SOVisitFreq  \
# Respondent
# 14                       Multiple times per day
# 36                        Daily or almost daily
# 43                       Multiple times per day
# 44                         A few times per week
# 66              A few times per month or weekly
# ...                                         ...
# 75974       Less than once per month or monthly
# 80319                    Multiple times per day
# 83786                     Daily or almost daily
# 88212                      A few times per week
# 88863                     Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 14                         Find answers to specific questions
# 36                         Find answers to specific questions
# 43          Find answers to specific questions;Learn how t...
# 44          Find answers to specific questions;Contribute ...
# 66          Find answers to specific questions;Contribute ...
# ...                                                       ...
# 75974                      Find answers to specific questions
# 80319       Find answers to specific questions;Learn how t...
# 83786       Find answers to specific questions;Contribute ...
# 88212                      Find answers to specific questions
# 88863       Find answers to specific questions;Learn how t...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 14                   3-5 times per week            They were about the same
# 36                   3-5 times per week  Stack Overflow was slightly faster
# 43                   3-5 times per week      Stack Overflow was much faster
# 44                   3-5 times per week  Stack Overflow was slightly faster
# 66                   1-2 times per week  Stack Overflow was slightly faster
# ...                                 ...                                 ...
# 75974           Less than once per week  Stack Overflow was slightly faster
# 80319       More than 10 times per week      Stack Overflow was much faster
# 83786           Less than once per week            They were about the same
# 88212               6-10 times per week  Stack Overflow was slightly faster
# 88863               6-10 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 14                    NaN       Yes
# 36            60+ minutes       Yes
# 43            60+ minutes       Yes
# 44          11-30 minutes       Yes
# 66           0-10 minutes       Yes
# ...                   ...       ...
# 75974        0-10 minutes       Yes
# 80319       11-30 minutes       Yes
# 83786                 NaN       Yes
# 88212        0-10 minutes       Yes
# 88863       11-30 minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 14                        Less than once per month or monthly
# 36                                      Daily or almost daily
# 43                            A few times per month or weekly
# 44                        Less than once per month or monthly
# 66                        Less than once per month or monthly
# ...                                                       ...
# 75974                         A few times per month or weekly
# 80319                     Less than once per month or monthly
# 83786                         A few times per month or weekly
# 88212       I have never participated in Q&A on Stack Over...
# 88863                         A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 14                                                        Yes
# 36                                                        Yes
# 43                                                        Yes
# 44                                                        Yes
# 66          No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 75974                                                     Yes
# 80319                                                     Yes
# 83786       No, I didn't know that Stack Overflow had a jo...
# 88212       No, I didn't know that Stack Overflow had a jo...
# 88863                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 14                        No, and I don't know what those are
# 36          No, I've heard of them, but I am not part of a...
# 43          No, I've heard of them, but I am not part of a...
# 44          No, I've heard of them, but I am not part of a...
# 66                        No, and I don't know what those are
# ...                                                       ...
# 75974       No, I've heard of them, but I am not part of a...
# 80319                     No, and I don't know what those are
# 83786                     No, and I don't know what those are
# 88212                     No, and I don't know what those are
# 88863       No, I've heard of them, but I am not part of a...
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 14           No, not really   Just as welcome now as I felt last year
# 36                  Neutral  Somewhat less welcome now than last year
# 43          Yes, definitely   Just as welcome now as I felt last year
# 44            Yes, somewhat   Just as welcome now as I felt last year
# 66            Yes, somewhat   Just as welcome now as I felt last year
# ...                     ...                                       ...
# 75974         Yes, somewhat   Just as welcome now as I felt last year
# 80319         Yes, somewhat  Somewhat more welcome now than last year
# 83786       Yes, definitely   Just as welcome now as I felt last year
# 88212        No, not at all                                       NaN
# 88863         Yes, somewhat  Somewhat less welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 14          Tech articles written by other developers;Cour...  31.0    Man
# 36                                                        NaN  21.0    Man
# 43          Tech articles written by other developers;Tech...  27.0    Man
# 44          Tech articles written by other developers;Indu...  43.0    Man
# 66                                                        NaN   NaN    NaN
# ...                                                       ...   ...    ...
# 75974       Industry news about technologies you're intere...   NaN    Man
# 80319       Tech articles written by other developers;Tech...  18.0    Man
# 83786       Tech articles written by other developers;Indu...  57.0    Man
# 88212       Tech articles written by other developers;Indu...  40.0    Man
# 88863       Tech articles written by other developers;Indu...  18.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 14            No  Straight / Heterosexual
# 36            No  Straight / Heterosexual
# 43            No  Straight / Heterosexual
# 44            No  Straight / Heterosexual
# 66           NaN                      NaN
# ...          ...                      ...
# 75974         No                      NaN
# 80319         No  Straight / Heterosexual
# 83786         No                      NaN
# 88212         No  Straight / Heterosexual
# 88863         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 14                               White or of European descent         No
# 36                               White or of European descent         No
# 43                                  Hispanic or Latino/Latina         No
# 44                               White or of European descent        Yes
# 66                                                        NaN        Yes
# ...                                                       ...        ...
# 75974                                          Middle Eastern        Yes
# 80319                                                     NaN         No
# 83786                            White or of European descent        Yes
# 88212                            White or of European descent         No
# 88863       Hispanic or Latino/Latina;White or of European...         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 14                      Too short                        Easy
# 36                       Too long  Neither easy nor difficult
# 43                       Too long                        Easy
# 44          Appropriate in length                        Easy
# 66                       Too long  Neither easy nor difficult
# ...                           ...                         ...
# 75974       Appropriate in length                        Easy
# 80319       Appropriate in length                        Easy
# 83786                    Too long  Neither easy nor difficult
# 88212       Appropriate in length                        Easy
# 88863       Appropriate in length                        Easy
#
# [7550 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
df.LanguageWorkedWith
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt].LanguageWorkedWith[8]
# Out:
# 'Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;JavaScript;Python;SQL'

# %% [markdown]
# # 4. Add/Remove Rows and Columns

# %%
people = {
    'first': ['Tony', 'Steve'], 
    'last': ['Stark', 'Rogers'], 
    'email': ['IronMan@avenge.com', 'Cap@avenge.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df2['fullname'] = df2['first'] + ' ' + df2['last']

# %%
df2
# Out:
#    first    last               email      fullname
# 0   Tony   Stark  IronMan@avenge.com    Tony Stark
# 1  Steve  Rogers      Cap@avenge.com  Steve Rogers

# %%
 df2.drop(columns=['first', 'last'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df2.drop(columns=['first', 'last'], inplace=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['first', 'last'] not found in axis"

# %%
df2
# Out:
#                 email      fullname
# 0  IronMan@avenge.com    Tony Stark
# 1      Cap@avenge.com  Steve Rogers

# %%
df2.fullname.str.split(expand=True)
# Out:
#        0       1
# 0   Tony   Stark
# 1  Steve  Rogers

# %%
df2[['firsname', 'lastname']] = df2.fullname.str.split(expand=True)

# %%
df2
# Out:
#                 email      fullname firsname lastname
# 0  IronMan@avenge.com    Tony Stark     Tony    Stark
# 1      Cap@avenge.com  Steve Rogers    Steve   Rogers

# %%
df2.drop(index=1, inplace=True)

# %%
df2
# Out:
#                 email    fullname firsname lastname
# 0  IronMan@avenge.com  Tony Stark     Tony    Stark

# %% [markdown]
# # 5. Sorting Data

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase',
#        'fullname'],
#       dtype='object')

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 63129                          I am a developer by profession      Yes
# 50499       I am not primarily a developer, but I write co...      Yes
# 39258                          I am a developer by profession      Yes
# 58450                          I am a developer by profession      Yes
# 7085                           I am a developer by profession      Yes
# ...                                                       ...      ...
# 88062                                                     NaN       No
# 88076                                                     NaN       No
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
#
#                         OpenSourcer  \
# Respondent
# 63129                         Never
# 50499       Less than once per year
# 39258       Less than once per year
# 58450                         Never
# 7085        Less than once per year
# ...                             ...
# 88062                         Never
# 88076                         Never
# 88601                         Never
# 88802                         Never
# 88816                         Never
#
#                                                    OpenSource  \
# Respondent
# 63129       OSS is, on average, of HIGHER quality than pro...
# 50499       OSS is, on average, of LOWER quality than prop...
# 39258       OSS is, on average, of LOWER quality than prop...
# 58450       OSS is, on average, of HIGHER quality than pro...
# 7085        The quality of OSS and closed source software ...
# ...                                                       ...
# 88062       OSS is, on average, of LOWER quality than prop...
# 88076       OSS is, on average, of HIGHER quality than pro...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment      Country  \
# Respondent
# 63129                                      Employed full-time  Afghanistan
# 50499                                      Employed full-time  Afghanistan
# 39258                                      Employed full-time  Afghanistan
# 58450                                      Employed full-time  Afghanistan
# 7085        Independent contractor, freelancer, or self-em...  Afghanistan
# ...                                                       ...          ...
# 88062                                                     NaN          NaN
# 88076                                      Employed full-time          NaN
# 88601                                                     NaN          NaN
# 88802                                      Employed full-time          NaN
# 88816       Independent contractor, freelancer, or self-em...          NaN
#
#                    Student                                   EdLevel  \
# Respondent
# 63129       Yes, full-time    I never completed any formal education
# 50499                   No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 39258                   No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 58450                   No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7085                    No  Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                       ...
# 88062                  NaN                                       NaN
# 88076                  NaN                                       NaN
# 88601                  NaN                                       NaN
# 88802                  NaN                                       NaN
# 88816                  NaN                                       NaN
#
#                                                UndergradMajor  \
# Respondent
# 63129                                                     NaN
# 50499       A health science (ex. nursing, pharmacy, radio...
# 39258       Computer science, computer engineering, or sof...
# 58450       Computer science, computer engineering, or sof...
# 7085        Computer science, computer engineering, or sof...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                      EduOther  \
# Respondent
# 63129       Taken an online course in programming or softw...
# 50499       Participated in a full-time developer training...
# 39258       Taken an online course in programming or softw...
# 58450       Taken an online course in programming or softw...
# 7085        Taught yourself a new language, framework, or ...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                       OrgSize  \
# Respondent
# 63129       Just me - I am a freelancer, sole proprietor, ...
# 50499                                10,000 or more employees
# 39258                                    100 to 499 employees
# 58450                                10,000 or more employees
# 7085                                            2-9 employees
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                       DevType  \
# Respondent
# 63129                                                     NaN
# 50499       Data or business analyst;Database administrato...
# 39258       Database administrator;Designer;Developer, bac...
# 58450       Developer, back-end;Developer, desktop or ente...
# 7085                                    Developer, full-stack
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                    YearsCode            Age1stCode YearsCodePro  \
# Respondent
# 63129       Less than 1 year  Younger than 5 years            1
# 50499                      7                    27            7
# 39258                      2                    22            1
# 58450                      6                    20            2
# 7085                       7                    19            6
# ...                      ...                   ...          ...
# 88062                    NaN                   NaN          NaN
# 88076                    NaN                   NaN          NaN
# 88601                    NaN                   NaN          NaN
# 88802                    NaN                   NaN          NaN
# 88816                    NaN                   NaN          NaN
#
#                                      CareerSat  \
# Respondent
# 63129                        Very dissatisfied
# 50499                        Very dissatisfied
# 39258                           Very satisfied
# 58450       Neither satisfied nor dissatisfied
# 7085                     Slightly dissatisfied
# ...                                        ...
# 88062                                      NaN
# 88076                                      NaN
# 88601                                      NaN
# 88802                                      NaN
# 88816                                      NaN
#
#                                         JobSat            MgrIdiot MgrMoney  \
# Respondent
# 63129                        Very dissatisfied      Very confident      Yes
# 50499                        Very dissatisfied  Somewhat confident      Yes
# 39258                           Very satisfied      Very confident       No
# 58450                       Slightly satisfied      Very confident      Yes
# 7085        Neither satisfied nor dissatisfied                 NaN      NaN
# ...                                        ...                 ...      ...
# 88062                                      NaN                 NaN      NaN
# 88076                                      NaN                 NaN      NaN
# 88601                                      NaN                 NaN      NaN
# 88802                                      NaN                 NaN      NaN
# 88816                                      NaN                 NaN      NaN
#
#            MgrWant                                            JobSeek  \
# Respondent
# 63129          Yes                    I am actively looking for a job
# 50499          Yes  I’m not actively looking, but I am open to new...
# 39258          Yes  I’m not actively looking, but I am open to new...
# 58450          Yes                    I am actively looking for a job
# 7085           NaN  I’m not actively looking, but I am open to new...
# ...            ...                                                ...
# 88062          NaN                                                NaN
# 88076          NaN                                                NaN
# 88601          NaN                                                NaN
# 88802          NaN                                                NaN
# 88816          NaN                                                NaN
#
#                      LastHireDate  \
# Respondent
# 63129        I've never had a job
# 50499       More than 4 years ago
# 39258               1-2 years ago
# 58450               1-2 years ago
# 7085         Less than a year ago
# ...                           ...
# 88062                         NaN
# 88076                         NaN
# 88601                         NaN
# 88802                         NaN
# 88816                         NaN
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 63129                                          Write any code      Yes
# 50499       Write code by hand (e.g., on a whiteboard);Int...       No
# 39258       Write code by hand (e.g., on a whiteboard);Int...       No
# 58450       Write code by hand (e.g., on a whiteboard);Com...       No
# 7085        Interview with people in peer roles;Interview ...       No
# ...                                                       ...      ...
# 88062                                                     NaN      NaN
# 88076                                                     NaN      NaN
# 88601                                                     NaN      NaN
# 88802                                                     NaN      NaN
# 88816                                                     NaN      NaN
#
#                                                    JobFactors  \
# Respondent
# 63129       How widely used or impactful my work output wo...
# 50499       Opportunities for professional development;Div...
# 39258       Languages, frameworks, and other technologies ...
# 58450       Languages, frameworks, and other technologies ...
# 7085        Languages, frameworks, and other technologies ...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 63129       I had a negative experience or interaction at ...            AED
# 50499       Something else changed (education, award, medi...            AFN
# 39258       Something else changed (education, award, medi...            AFN
# 58450       I had a negative experience or interaction at ...            AFN
# 7085                         I was preparing for a job search            AFN
# ...                                                       ...            ...
# 88062                                                     NaN            NaN
# 88076                                                     NaN            NaN
# 88601                                                     NaN            NaN
# 88802                                                     NaN            NaN
# 88816                                                     NaN            NaN
#
#                            CurrencyDesc    CompTotal CompFreq  ConvertedComp  \
# Respondent
# 63129       United Arab Emirates dirham  648838511.0  Monthly      1000000.0
# 50499                    Afghan afghani     960000.0  Monthly       153216.0
# 39258                    Afghan afghani     120000.0  Monthly        19152.0
# 58450                    Afghan afghani     110000.0  Monthly        17556.0
# 7085                     Afghan afghani      90000.0  Monthly        14364.0
# ...                                 ...          ...      ...            ...
# 88062                               NaN          NaN      NaN            NaN
# 88076                               NaN          NaN      NaN            NaN
# 88601                               NaN          NaN      NaN            NaN
# 88802                               NaN          NaN      NaN            NaN
# 88816                               NaN          NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 63129             168.0  There is a schedule and/or spec (made by me or...
# 50499              40.0  There is a schedule and/or spec (made by me or...
# 39258              49.0  There is a schedule and/or spec (made by me or...
# 58450              40.0  There is a schedule and/or spec (made by me or...
# 7085               30.0  There's no schedule or spec; I work on what se...
# ...                 ...                                                ...
# 88062               NaN                                                NaN
# 88076               NaN                                                NaN
# 88601               NaN                                                NaN
# 88802               NaN                                                NaN
# 88816               NaN                                                NaN
#
#                                                 WorkChallenge  \
# Respondent
# 63129                  Being tasked with non-development work
# 50499       Lack of support from management;Time spent com...
# 39258       Not enough people for the workload;Time spent ...
# 58450                            Distracting work environment
# 7085        Inadequate access to necessary tools;Lack of s...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                   WorkRemote  \
# Respondent
# 63129                       It's complicated
# 50499       Less than once per month / Never
# 39258       Less than once per month / Never
# 58450                       It's complicated
# 7085                     About half the time
# ...                                      ...
# 88062                                    NaN
# 88076                                    NaN
# 88601                                    NaN
# 88802                                    NaN
# 88816                                    NaN
#
#                                                    WorkLoc  \
# Respondent
# 63129       Other place, such as a coworking space or cafe
# 50499                                               Office
# 39258                                               Office
# 58450                                               Office
# 7085                                                Office
# ...                                                    ...
# 88062                                                  NaN
# 88076                                                  NaN
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 63129            Far below average                                       No
# 50499       A little above average  Yes, because I see value in code review
# 39258            Far above average  Yes, because I see value in code review
# 58450                      Average  Yes, because I see value in code review
# 7085                       Average  Yes, because I see value in code review
# ...                            ...                                      ...
# 88062                          NaN                                      NaN
# 88076                          NaN                                      NaN
# 88601                          NaN                                      NaN
# 88802                          NaN                                      NaN
# 88816                          NaN                                      NaN
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 63129              NaN                                                NaN
# 50499              8.0  Yes, it's not part of our process but the deve...
# 39258             10.0  Yes, it's not part of our process but the deve...
# 58450              8.0                      Yes, it's part of our process
# 7085               3.0                                                NaN
# ...                ...                                                ...
# 88062              NaN                                                NaN
# 88076              NaN                                                NaN
# 88601              NaN                                                NaN
# 88802              NaN                                                NaN
# 88816              NaN                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 63129                                                     NaN
# 50499       Developers typically have the most influence o...
# 39258       Developers typically have the most influence o...
# 58450       Developers typically have the most influence o...
# 7085                                                      NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 63129                                    NaN
# 50499       I have a great deal of influence
# 39258                  I have some influence
# 58450          I have little or no influence
# 7085                                     NaN
# ...                                      ...
# 88062                                    NaN
# 88076                                    NaN
# 88601                                    NaN
# 88802                                    NaN
# 88816                                    NaN
#
#                                   LanguageWorkedWith  \
# Respondent
# 63129       Assembly;Bash/Shell/PowerShell;Other(s):
# 50499                 C#;HTML/CSS;JavaScript;SQL;VBA
# 39258         HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 58450           Assembly;C;C++;HTML/CSS;Java;PHP;SQL
# 7085                         HTML/CSS;JavaScript;PHP
# ...                                              ...
# 88062                                            NaN
# 88076                                            NaN
# 88601                                            NaN
# 88802                                            NaN
# 88816                                            NaN
#
#                                    LanguageDesireNextYear  \
# Respondent
# 63129                    Bash/Shell/PowerShell;TypeScript
# 50499         C#;HTML/CSS;JavaScript;R;SQL;TypeScript;VBA
# 39258                   C#;Dart;JavaScript;SQL;TypeScript
# 58450       C;C++;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 7085                                JavaScript;Kotlin;PHP
# ...                                                   ...
# 88062                                                 NaN
# 88076                                                 NaN
# 88601                                                 NaN
# 88802                                                 NaN
# 88816                                                 NaN
#
#                                 DatabaseWorkedWith  \
# Respondent
# 63129                                        MySQL
# 50499       Microsoft SQL Server;PostgreSQL;SQLite
# 39258             MariaDB;MongoDB;MySQL;PostgreSQL
# 58450                             MySQL;PostgreSQL
# 7085                                         MySQL
# ...                                            ...
# 88062                                          NaN
# 88076                                          NaN
# 88601                                          NaN
# 88802                                          NaN
# 88816                                          NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 63129                                                   MySQL
# 50499       MariaDB;MongoDB;Microsoft SQL Server;PostgreSQ...
# 39258                Couchbase;Firebase;MariaDB;MongoDB;Redis
# 58450                                        MySQL;PostgreSQL
# 7085                                      MongoDB;MySQL;Redis
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                  PlatformWorkedWith  \
# Respondent
# 63129       Android;iOS;Windows;WordPress;Other(s):
# 50499                                           NaN
# 39258           Android;AWS;Linux;Windows;WordPress
# 58450                                 Linux;Windows
# 7085                          Linux;MacOS;Other(s):
# ...                                             ...
# 88062                                           NaN
# 88076                                           NaN
# 88601                                           NaN
# 88802                                           NaN
# 88816                                           NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 63129                 Android;iOS;Windows;WordPress;Other(s):
# 50499                                                 Android
# 39258       Android;AWS;Docker;Heroku;iOS;Linux;Raspberry ...
# 58450                                                 Windows
# 7085                                    Linux;MacOS;Other(s):
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                            WebFrameWorkedWith  \
# Respondent
# 63129       Angular/Angular.js;Express;jQuery;Laravel;Othe...
# 50499                                          ASP.NET;jQuery
# 39258               Angular/Angular.js;Drupal;Express;Laravel
# 58450                                                     NaN
# 7085                                    jQuery;Laravel;Vue.js
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 63129       Angular/Angular.js;Express;jQuery;Laravel;Othe...
# 50499       Angular/Angular.js;ASP.NET;jQuery;React.js;Vue.js
# 39258                       Angular/Angular.js;Drupal;Express
# 58450                                                  Spring
# 7085                            ASP.NET;jQuery;Laravel;Vue.js
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                             MiscTechWorkedWith  \
# Respondent
# 63129       Ansible;Apache Spark;Torch/PyTorch
# 50499                                     .NET
# 39258                          Cordova;Node.js
# 58450                                      NaN
# 7085                                       NaN
# ...                                        ...
# 88062                                      NaN
# 88076                                      NaN
# 88601                                      NaN
# 88802                                      NaN
# 88816                                      NaN
#
#                     MiscTechDesireNextYear  \
# Respondent
# 63129           Apache Spark;Torch/PyTorch
# 50499       .NET;.NET Core;Node.js;Xamarin
# 39258                       Hadoop;Node.js
# 58450                              Node.js
# 7085                          React Native
# ...                                    ...
# 88062                                  NaN
# 88076                                  NaN
# 88601                                  NaN
# 88802                                  NaN
# 88816                                  NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 63129       Android Studio;Atom;Coda;Eclipse;Emacs;IPython...      Windows
# 50499                                           Visual Studio      Windows
# 39258               Notepad++;PHPStorm;Vim;Visual Studio Code  Linux-based
# 58450                                      IntelliJ;Notepad++      Windows
# 7085                          Sublime Text;Visual Studio Code        MacOS
# ...                                                       ...          ...
# 88062                                                     NaN          NaN
# 88076                                                     NaN          NaN
# 88601                                                     NaN          NaN
# 88802                                                     NaN          NaN
# 88816                                                     NaN          NaN
#
#                                                    Containers  \
# Respondent
# 63129                  Outside of work, for personal projects
# 50499                                 I do not use containers
# 39258                                              Production
# 58450                                             Development
# 7085        Development;Outside of work, for personal proj...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                 BlockchainOrg  \
# Respondent
# 63129       Accepting Bitcoin or other coins and tokens as...
# 50499                     Implementing our own cryptocurrency
# 39258                                                     NaN
# 58450       Accepting Bitcoin or other coins and tokens as...
# 7085                                                      NaN
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 63129       Useful across many domains and could change ma...        Yes
# 50499                                                     NaN        Yes
# 39258                                                     NaN        Yes
# 58450       Useful for immutable record keeping outside of...        Yes
# 7085                                                      NaN        Yes
# ...                                                       ...        ...
# 88062                                                     NaN        NaN
# 88076                                                     NaN        NaN
# 88601                                                     NaN        NaN
# 88802                                                     NaN        NaN
# 88816                                                     NaN        NaN
#
#             ITperson OffOn               SocialMedia Extraversion ScreenName  \
# Respondent
# 63129            Yes   Yes  I don't use social media       Online     UserID
# 50499            Yes   Yes                  WhatsApp       Online      Login
# 39258            Yes    No                  Facebook       Online      Login
# 58450            Yes   Yes                  Facebook       Online     Handle
# 7085        Also Yes   Yes                 Instagram       Online     UserID
# ...              ...   ...                       ...          ...        ...
# 88062            NaN   NaN                       NaN          NaN        NaN
# 88076            NaN   NaN                       NaN          NaN        NaN
# 88601            NaN   NaN                       NaN          NaN        NaN
# 88802            NaN   NaN                       NaN          NaN        NaN
# 88816            NaN   NaN                       NaN          NaN        NaN
#
#            SOVisit1st                                        SOVisitFreq  \
# Respondent
# 63129             NaN  I have never visited Stack Overflow (before to...
# 50499            2013                    A few times per month or weekly
# 39258            2016                               A few times per week
# 58450             NaN                              Daily or almost daily
# 7085             2016                             Multiple times per day
# ...               ...                                                ...
# 88062             NaN                                                NaN
# 88076             NaN                                                NaN
# 88601             NaN                                                NaN
# 88802             NaN                                                NaN
# 88816             NaN                                                NaN
#
#                                                     SOVisitTo  \
# Respondent
# 63129                      Find answers to specific questions
# 50499                      Find answers to specific questions
# 39258       Find answers to specific questions;Learn how t...
# 58450       Find answers to specific questions;Learn how t...
# 7085        Find answers to specific questions;Learn how t...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                        SOFindAnswer                         SOTimeSaved  \
# Respondent
# 63129       Less than once per week      Stack Overflow was much faster
# 50499       Less than once per week  Stack Overflow was slightly faster
# 39258            1-2 times per week      Stack Overflow was much faster
# 58450           6-10 times per week      Stack Overflow was much faster
# 7085            6-10 times per week      Stack Overflow was much faster
# ...                             ...                                 ...
# 88062                           NaN                                 NaN
# 88076                           NaN                                 NaN
# 88601                           NaN                                 NaN
# 88802                           NaN                                 NaN
# 88816                           NaN                                 NaN
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 63129        0-10 minutes       NaN                                  NaN
# 50499       11-30 minutes       Yes  Less than once per month or monthly
# 39258        0-10 minutes       Yes  Less than once per month or monthly
# 58450       11-30 minutes       Yes      A few times per month or weekly
# 7085          60+ minutes       Yes                 A few times per week
# ...                   ...       ...                                  ...
# 88062                 NaN       NaN                                  NaN
# 88076                 NaN       NaN                                  NaN
# 88601                 NaN       NaN                                  NaN
# 88802                 NaN       NaN                                  NaN
# 88816                 NaN       NaN                                  NaN
#
#                                                        SOJobs  \
# Respondent
# 63129       No, I didn't know that Stack Overflow had a jo...
# 50499                                                     Yes
# 39258                                                     Yes
# 58450       No, I didn't know that Stack Overflow had a jo...
# 7085        No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                                                      EntTeams  \
# Respondent
# 63129                                                     NaN
# 50499                     No, and I don't know what those are
# 39258                                                     NaN
# 58450                     No, and I don't know what those are
# 7085        No, I've heard of them, but I am not part of a...
# ...                                                       ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 63129        No, not at all                                      NaN
# 50499         Yes, somewhat  Just as welcome now as I felt last year
# 39258         Yes, somewhat                                      NaN
# 58450       Yes, definitely    A lot less welcome now than last year
# 7085          Yes, somewhat  Just as welcome now as I felt last year
# ...                     ...                                      ...
# 88062                   NaN                                      NaN
# 88076                   NaN                                      NaN
# 88601                   NaN                                      NaN
# 88802                   NaN                                      NaN
# 88816                   NaN                                      NaN
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 63129               Tech articles written by other developers   NaN    NaN
# 50499       Tech articles written by other developers;Indu...  34.0    NaN
# 39258       Tech articles written by other developers;Indu...  26.0    Man
# 58450               Tech articles written by other developers  26.0    Man
# 7085        Industry news about technologies you're intere...  26.0    Man
# ...                                                       ...   ...    ...
# 88062                                                     NaN   NaN    NaN
# 88076                                                     NaN   NaN    NaN
# 88601                                                     NaN   NaN    NaN
# 88802                                                     NaN   NaN    NaN
# 88816                                                     NaN   NaN    NaN
#
#            Trans                Sexuality               Ethnicity Dependents  \
# Respondent
# 63129        NaN                      NaN                     NaN        Yes
# 50499         No  Straight / Heterosexual                     NaN        Yes
# 39258         No  Straight / Heterosexual  East Asian;South Asian        Yes
# 58450         No  Straight / Heterosexual             South Asian         No
# 7085         NaN  Straight / Heterosexual              East Asian        Yes
# ...          ...                      ...                     ...        ...
# 88062        NaN                      NaN                     NaN        NaN
# 88076        NaN                      NaN                     NaN        NaN
# 88601        NaN                      NaN                     NaN        NaN
# 88802        NaN                      NaN                     NaN        NaN
# 88816        NaN                      NaN                     NaN        NaN
#
#                      SurveyLength                  SurveyEase fullname
# Respondent
# 63129                   Too short                        Easy      NaN
# 50499                    Too long  Neither easy nor difficult      NaN
# 39258                    Too long                        Easy      NaN
# 58450                    Too long  Neither easy nor difficult      NaN
# 7085        Appropriate in length  Neither easy nor difficult      NaN
# ...                           ...                         ...      ...
# 88062                         NaN                         NaN      NaN
# 88076                         NaN                         NaN      NaN
# 88601                         NaN                         NaN      NaN
# 88802                         NaN                         NaN      NaN
# 88816                         NaN                         NaN      NaN
#
# [88883 rows x 85 columns]

# %%
df.ConvertedComp.nlargest(20)
# Out:
# Respondent
# 58      2000000.0
# 102     2000000.0
# 166     2000000.0
# 436     2000000.0
# 452     2000000.0
# 491     2000000.0
# 539     2000000.0
# 770     2000000.0
# 789     2000000.0
# 1232    2000000.0
# 1381    2000000.0
# 1382    2000000.0
# 1411    2000000.0
# 1452    2000000.0
# 1573    2000000.0
# 1758    2000000.0
# 2113    2000000.0
# 2115    2000000.0
# 2164    2000000.0
# 2217    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.ConvertedComp.nsmallest(20)
# Out:
# Respondent
# 280     0.0
# 293     0.0
# 722     0.0
# 1105    0.0
# 1501    0.0
# 1685    0.0
# 1782    0.0
# 2019    0.0
# 2095    0.0
# 2665    0.0
# 3048    0.0
# 4073    0.0
# 4144    0.0
# 4477    0.0
# 4770    0.0
# 5252    0.0
# 5615    0.0
# 5633    0.0
# 6338    0.0
# 7124    0.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(20, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 58          I am a developer by profession      Yes
# 102         I am a developer by profession       No
# 166         I am a developer by profession      Yes
# 436         I am a developer by profession      Yes
# 452         I am a developer by profession      Yes
# 491         I am a developer by profession      Yes
# 539         I am a developer by profession       No
# 770         I am a developer by profession      Yes
# 789         I am a developer by profession      Yes
# 1232        I am a developer by profession       No
# 1381        I am a developer by profession      Yes
# 1382        I am a developer by profession      Yes
# 1411        I am a developer by profession      Yes
# 1452        I am a developer by profession       No
# 1573        I am a developer by profession      Yes
# 1758        I am a developer by profession      Yes
# 2113        I am a developer by profession      Yes
# 2115        I am a developer by profession      Yes
# 2164        I am a developer by profession       No
# 2217        I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 58                                 Once a month or more often
# 102                                                     Never
# 166                                   Less than once per year
# 436                                   Less than once per year
# 452                                                     Never
# 491                                   Less than once per year
# 539         Less than once a month but more than once per ...
# 770                                   Less than once per year
# 789                                   Less than once per year
# 1232                                                    Never
# 1381                                  Less than once per year
# 1382        Less than once a month but more than once per ...
# 1411                                  Less than once per year
# 1452                                                    Never
# 1573                                  Less than once per year
# 1758                                  Less than once per year
# 2113                                  Less than once per year
# 2115        Less than once a month but more than once per ...
# 2164                                                    Never
# 2217                                  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 58          OSS is, on average, of LOWER quality than prop...
# 102         The quality of OSS and closed source software ...
# 166         The quality of OSS and closed source software ...
# 436         The quality of OSS and closed source software ...
# 452         The quality of OSS and closed source software ...
# 491                                                       NaN
# 539         OSS is, on average, of HIGHER quality than pro...
# 770         The quality of OSS and closed source software ...
# 789         The quality of OSS and closed source software ...
# 1232        OSS is, on average, of HIGHER quality than pro...
# 1381        The quality of OSS and closed source software ...
# 1382        OSS is, on average, of HIGHER quality than pro...
# 1411        The quality of OSS and closed source software ...
# 1452        OSS is, on average, of HIGHER quality than pro...
# 1573        The quality of OSS and closed source software ...
# 1758        The quality of OSS and closed source software ...
# 2113        OSS is, on average, of HIGHER quality than pro...
# 2115        OSS is, on average, of HIGHER quality than pro...
# 2164        The quality of OSS and closed source software ...
# 2217        OSS is, on average, of HIGHER quality than pro...
#
#                     Employment        Country         Student  \
# Respondent
# 58          Employed full-time  United States              No
# 102         Employed full-time  United States              No
# 166         Employed full-time  United States              No
# 436         Employed full-time  United States              No
# 452         Employed full-time  United States  Yes, full-time
# 491         Employed full-time  United States              No
# 539         Employed full-time  United States              No
# 770         Employed full-time  United States              No
# 789         Employed full-time  United States  Yes, full-time
# 1232        Employed full-time  United States              No
# 1381        Employed full-time  United States              No
# 1382        Employed full-time  United States  Yes, full-time
# 1411        Employed full-time  United States              No
# 1452        Employed full-time  United States              No
# 1573        Employed full-time  United States  Yes, full-time
# 1758        Employed full-time  United States              No
# 2113        Employed full-time  United States              No
# 2115        Employed full-time  United States  Yes, full-time
# 2164        Employed full-time  United States              No
# 2217        Employed full-time  United States              No
#
#                                                       EdLevel  \
# Respondent
# 58                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 102                  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 166                  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 436                  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 452                    I never completed any formal education
# 491                  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 539         Some college/university study without earning ...
# 770               Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 789               Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1232                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1381              Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1382                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1411        Some college/university study without earning ...
# 1452                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1573                                         Associate degree
# 1758        Some college/university study without earning ...
# 2113        Some college/university study without earning ...
# 2115              Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 2164                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2217                 Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 58          Computer science, computer engineering, or sof...
# 102         Computer science, computer engineering, or sof...
# 166         A social science (ex. anthropology, psychology...
# 436         Computer science, computer engineering, or sof...
# 452                                                       NaN
# 491         Computer science, computer engineering, or sof...
# 539                                 Mathematics or statistics
# 770         A humanities discipline (ex. literature, histo...
# 789         Computer science, computer engineering, or sof...
# 1232        Computer science, computer engineering, or sof...
# 1381        A social science (ex. anthropology, psychology...
# 1382                            Web development or web design
# 1411        Information systems, information technology, o...
# 1452        Computer science, computer engineering, or sof...
# 1573        Computer science, computer engineering, or sof...
# 1758        A humanities discipline (ex. literature, histo...
# 2113        Fine arts or performing arts (ex. graphic desi...
# 2115        Computer science, computer engineering, or sof...
# 2164                            Web development or web design
# 2217        Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 58          Received on-the-job training in software devel...
# 102         Taught yourself a new language, framework, or ...
# 166         Participated in a full-time developer training...
# 436         Taken an online course in programming or softw...
# 452         Taken an online course in programming or softw...
# 491         Taken an online course in programming or softw...
# 539         Taken an online course in programming or softw...
# 770         Taken an online course in programming or softw...
# 789         Taken an online course in programming or softw...
# 1232        Taken an online course in programming or softw...
# 1381        Taken an online course in programming or softw...
# 1382        Taken an online course in programming or softw...
# 1411                                                      NaN
# 1452        Taken an online course in programming or softw...
# 1573        Taken an online course in programming or softw...
# 1758        Taught yourself a new language, framework, or ...
# 2113        Taken an online course in programming or softw...
# 2115        Taught yourself a new language, framework, or ...
# 2164        Taken an online course in programming or softw...
# 2217        Received on-the-job training in software devel...
#
#                              OrgSize  \
# Respondent
# 58                               NaN
# 102         5,000 to 9,999 employees
# 166               20 to 99 employees
# 436               20 to 99 employees
# 452             100 to 499 employees
# 491         10,000 or more employees
# 539         10,000 or more employees
# 770         1,000 to 4,999 employees
# 789         10,000 or more employees
# 1232                   2-9 employees
# 1381              10 to 19 employees
# 1382            100 to 499 employees
# 1411              20 to 99 employees
# 1452        10,000 or more employees
# 1573        1,000 to 4,999 employees
# 1758              20 to 99 employees
# 2113        1,000 to 4,999 employees
# 2115              10 to 19 employees
# 2164            100 to 499 employees
# 2217        10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 58          Developer, back-end;Developer, desktop or ente...        28
# 102                                     Developer, full-stack         8
# 166         Developer, back-end;Developer, front-end;Devel...         7
# 436         Database administrator;Developer, back-end;Dev...        20
# 452                Database administrator;Developer, back-end         7
# 491                   Developer, full-stack;Developer, mobile         4
# 539         Data scientist or machine learning specialist;...        22
# 770                                     Developer, full-stack         5
# 789            Developer, back-end;Engineer, site reliability        12
# 1232        Developer, front-end;Developer, game or graphi...         4
# 1381               Developer, front-end;Developer, full-stack         2
# 1382        Database administrator;Developer, back-end;Dev...        20
# 1411                                      Senior executive/VP        25
# 1452        Developer, back-end;Developer, front-end;Devel...         8
# 1573        Developer, back-end;Developer, front-end;Devel...         2
# 1758               Developer, front-end;Developer, QA or test         4
# 2113                       Developer, back-end;Engineer, data         7
# 2115        Developer, back-end;Developer, embedded applic...         2
# 2164                                    Developer, full-stack         6
# 2217        Developer, back-end;Developer, front-end;Devel...        13
#
#            Age1stCode      YearsCodePro              CareerSat  \
# Respondent
# 58                 19                23         Very satisfied
# 102                29                 5     Slightly satisfied
# 166                15                 6     Slightly satisfied
# 436                18                17     Slightly satisfied
# 452                28                 7         Very satisfied
# 491                18  Less than 1 year         Very satisfied
# 539                14                20         Very satisfied
# 770                17                 3         Very satisfied
# 789                 9                 6  Slightly dissatisfied
# 1232               15                 2     Slightly satisfied
# 1381               31                 1         Very satisfied
# 1382                5                 1     Slightly satisfied
# 1411                5                20         Very satisfied
# 1452               12                 2         Very satisfied
# 1573               23  Less than 1 year     Slightly satisfied
# 1758               16                 3      Very dissatisfied
# 2113               12                 4         Very satisfied
# 2115               21                 1         Very satisfied
# 2164               20                 3         Very satisfied
# 2217               12                 2         Very satisfied
#
#                                         JobSat              MgrIdiot MgrMoney  \
# Respondent
# 58                              Very satisfied        Very confident      Yes
# 102                         Slightly satisfied    Somewhat confident       No
# 166                         Slightly satisfied        Very confident       No
# 436                         Slightly satisfied    Somewhat confident      Yes
# 452                             Very satisfied        Very confident       No
# 491                             Very satisfied        Very confident       No
# 539                         Slightly satisfied        Very confident      Yes
# 770                             Very satisfied    Somewhat confident       No
# 789         Neither satisfied nor dissatisfied  Not at all confident      Yes
# 1232                     Slightly dissatisfied    Somewhat confident      Yes
# 1381                     Slightly dissatisfied    Somewhat confident       No
# 1382                            Very satisfied    Somewhat confident       No
# 1411                            Very satisfied                   NaN      NaN
# 1452                            Very satisfied        Very confident       No
# 1573                        Slightly satisfied        Very confident       No
# 1758                         Very dissatisfied        Very confident       No
# 2113                        Slightly satisfied        Very confident       No
# 2115                            Very satisfied        Very confident       No
# 2164                            Very satisfied        Very confident       No
# 2217                     Slightly dissatisfied        Very confident      Yes
#
#                            MgrWant  \
# Respondent
# 58                              No
# 102                             No
# 166                       Not sure
# 436         I am already a manager
# 452                             No
# 491                       Not sure
# 539                             No
# 770                       Not sure
# 789                       Not sure
# 1232                           Yes
# 1381                      Not sure
# 1382                           Yes
# 1411                           NaN
# 1452                            No
# 1573                           Yes
# 1758                      Not sure
# 2113                      Not sure
# 2115                            No
# 2164                            No
# 2217                           Yes
#
#                                                       JobSeek  \
# Respondent
# 58               I am not interested in new job opportunities
# 102         I’m not actively looking, but I am open to new...
# 166         I’m not actively looking, but I am open to new...
# 436         I’m not actively looking, but I am open to new...
# 452         I’m not actively looking, but I am open to new...
# 491              I am not interested in new job opportunities
# 539         I’m not actively looking, but I am open to new...
# 770              I am not interested in new job opportunities
# 789         I’m not actively looking, but I am open to new...
# 1232        I’m not actively looking, but I am open to new...
# 1381                          I am actively looking for a job
# 1382             I am not interested in new job opportunities
# 1411             I am not interested in new job opportunities
# 1452             I am not interested in new job opportunities
# 1573        I’m not actively looking, but I am open to new...
# 1758             I am not interested in new job opportunities
# 2113        I’m not actively looking, but I am open to new...
# 2115        I’m not actively looking, but I am open to new...
# 2164             I am not interested in new job opportunities
# 2217        I’m not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 58                  1-2 years ago
# 102                 1-2 years ago
# 166                 3-4 years ago
# 436                 3-4 years ago
# 452          Less than a year ago
# 491          Less than a year ago
# 539                 1-2 years ago
# 770                 1-2 years ago
# 789                 3-4 years ago
# 1232                1-2 years ago
# 1381                1-2 years ago
# 1382         Less than a year ago
# 1411        More than 4 years ago
# 1452                3-4 years ago
# 1573                1-2 years ago
# 1758                1-2 years ago
# 2113                3-4 years ago
# 2115         Less than a year ago
# 2164                3-4 years ago
# 2217                1-2 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 58                                                        NaN      Yes
# 102         Write any code;Write code by hand (e.g., on a ...      Yes
# 166         Write any code;Complete a take-home project;So...       No
# 436         Write any code;Write code by hand (e.g., on a ...       No
# 452         Solve a brain-teaser style puzzle;Interview wi...       No
# 491         Write any code;Write code by hand (e.g., on a ...       No
# 539         Write any code;Complete a take-home project;In...      Yes
# 770         Interview with people in peer roles;Interview ...       No
# 789         Write any code;Write code by hand (e.g., on a ...       No
# 1232        Write code by hand (e.g., on a whiteboard);Sol...       No
# 1381        Write any code;Complete a take-home project;So...       No
# 1382        Interview with people in peer roles;Interview ...       No
# 1411                                                      NaN       No
# 1452        Interview with people in peer roles;Interview ...       No
# 1573        Write code by hand (e.g., on a whiteboard);Sol...      Yes
# 1758        Interview with people in peer roles;Interview ...      Yes
# 2113        Complete a take-home project;Interview with pe...       No
# 2115        Interview with people in senior / management r...       No
# 2164        Interview with people in peer roles;Interview ...       No
# 2217        Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 58          Office environment or company culture;Remote w...
# 102         Office environment or company culture;Opportun...
# 166         Financial performance or funding status of the...
# 436         Specific department or team I'd be working on;...
# 452         Specific department or team I'd be working on;...
# 491         Specific department or team I'd be working on;...
# 539         Languages, frameworks, and other technologies ...
# 770         Office environment or company culture;Remote w...
# 789         Specific department or team I'd be working on;...
# 1232        Industry that I'd be working in;Specific depar...
# 1381        Office environment or company culture;Remote w...
# 1382        Office environment or company culture;Opportun...
# 1411        Remote work options;Opportunities for professi...
# 1452        Languages, frameworks, and other technologies ...
# 1573        Industry that I'd be working in;Languages, fra...
# 1758        Office environment or company culture;Diversit...
# 2113        Office environment or company culture;Remote w...
# 2115        Languages, frameworks, and other technologies ...
# 2164        Specific department or team I'd be working on;...
# 2217        Specific department or team I'd be working on;...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 58                                Re-entry into the workforce            USD
# 102         Something else changed (education, award, medi...            USD
# 166         I had a negative experience or interaction at ...            USD
# 436          My job status changed (promotion, new job, etc.)            USD
# 452         Something else changed (education, award, medi...            USD
# 491                          I was preparing for a job search            USD
# 539                          I was preparing for a job search            USD
# 770         Something else changed (education, award, medi...            USD
# 789         I had a negative experience or interaction at ...            USD
# 1232        Something else changed (education, award, medi...            USD
# 1381        I heard about a job opportunity (from a recrui...            USD
# 1382                         I was preparing for a job search            USD
# 1411        I had a negative experience or interaction at ...            USD
# 1452                         I was preparing for a job search            USD
# 1573                         I was preparing for a job search            USD
# 1758                         I was preparing for a job search            USD
# 2113         My job status changed (promotion, new job, etc.)            USD
# 2115        I heard about a job opportunity (from a recrui...            USD
# 2164         My job status changed (promotion, new job, etc.)            USD
# 2217        I had a negative experience or interaction at ...            USD
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 58          United States dollar   113000.0   Weekly      2000000.0
# 102         United States dollar    67800.0   Weekly      2000000.0
# 166         United States dollar   137000.0   Weekly      2000000.0
# 436         United States dollar    85000.0   Weekly      2000000.0
# 452         United States dollar    75000.0   Weekly      2000000.0
# 491         United States dollar   160000.0   Weekly      2000000.0
# 539         United States dollar   140000.0   Weekly      2000000.0
# 770         United States dollar    68000.0   Weekly      2000000.0
# 789         United States dollar   180000.0  Monthly      2000000.0
# 1232        United States dollar   800000.0   Weekly      2000000.0
# 1381        United States dollar    55000.0   Weekly      2000000.0
# 1382        United States dollar    66000.0   Weekly      2000000.0
# 1411        United States dollar   170000.0   Weekly      2000000.0
# 1452        United States dollar    98000.0   Weekly      2000000.0
# 1573        United States dollar    55000.0   Weekly      2000000.0
# 1758        United States dollar   130000.0   Weekly      2000000.0
# 2113        United States dollar   130000.0   Weekly      2000000.0
# 2115        United States dollar    72000.0   Weekly      2000000.0
# 2164        United States dollar    65000.0   Weekly      2000000.0
# 2217        United States dollar   200000.0   Weekly      2000000.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 58                 40.0  There's no schedule or spec; I work on what se...
# 102                40.0  There is a schedule and/or spec (made by me or...
# 166                45.0  There is a schedule and/or spec (made by me or...
# 436                45.0  There is a schedule and/or spec (made by me or...
# 452                40.0  There is a schedule and/or spec (made by me or...
# 491                45.0  There is a schedule and/or spec (made by me or...
# 539                50.0  There is a schedule and/or spec (made by me or...
# 770                38.0  There is a schedule and/or spec (made by me or...
# 789                40.0  There is a schedule and/or spec (made by me or...
# 1232               40.0  There is a schedule and/or spec (made by me or...
# 1381               40.0  There is a schedule and/or spec (made by me or...
# 1382               40.0  There is a schedule and/or spec (made by me or...
# 1411               50.0  There's no schedule or spec; I work on what se...
# 1452               40.0  There's no schedule or spec; I work on what se...
# 1573               40.0  There is a schedule and/or spec (made by me or...
# 1758               35.0  There is a schedule and/or spec (made by me or...
# 2113               50.0  There is a schedule and/or spec (made by me or...
# 2115               40.0  There's no schedule or spec; I work on what se...
# 2164               45.0  There is a schedule and/or spec (made by me or...
# 2217               40.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 58          Being tasked with non-development work;Non-wor...
# 102         Being tasked with non-development work;Distrac...
# 166         Distracting work environment;Not enough people...
# 436         Lack of support from management;Meetings;Not e...
# 452         Being tasked with non-development work;Meeting...
# 491         Distracting work environment;Inadequate access...
# 539         Being tasked with non-development work;Non-wor...
# 770         Being tasked with non-development work;Non-wor...
# 789         Lack of support from management;Toxic work env...
# 1232        Distracting work environment;Non-work commitme...
# 1381        Being tasked with non-development work;Time sp...
# 1382        Being tasked with non-development work;Meeting...
# 1411        Distracting work environment;Meetings;Not enou...
# 1452        Distracting work environment;Meetings;Time spe...
# 1573        Being tasked with non-development work;Inadequ...
# 1758        Meetings;Non-work commitments (parenting, scho...
# 2113        Distracting work environment;Meetings;Not enou...
# 2115                          Lack of support from management
# 2164        Being tasked with non-development work;Meeting...
# 2217        Inadequate access to necessary tools;Lack of s...
#
#                                                    WorkRemote  \
# Respondent
# 58          Less than half the time, but at least one day ...
# 102                          Less than once per month / Never
# 166                          Less than once per month / Never
# 436                                     A few days each month
# 452                                     A few days each month
# 491                          Less than once per month / Never
# 539                                     A few days each month
# 770         All or almost all the time (I'm full-time remote)
# 789                                     A few days each month
# 1232                                    A few days each month
# 1381                         Less than once per month / Never
# 1382                         Less than once per month / Never
# 1411        Less than half the time, but at least one day ...
# 1452                                    A few days each month
# 1573                         Less than once per month / Never
# 1758        All or almost all the time (I'm full-time remote)
# 2113        All or almost all the time (I'm full-time remote)
# 2115                         Less than once per month / Never
# 2164                                    A few days each month
# 2217                                    A few days each month
#
#                                                    WorkLoc  \
# Respondent
# 58                                                    Home
# 102                                                 Office
# 166                                                   Home
# 436                                                 Office
# 452                                                   Home
# 491                                                 Office
# 539                                                 Office
# 770                                                   Home
# 789                                                 Office
# 1232                                                Office
# 1381                                                Office
# 1382                                                Office
# 1411        Other place, such as a coworking space or cafe
# 1452                                                Office
# 1573                                                Office
# 1758                                                  Home
# 2113                                                Office
# 2115                                                  Home
# 2164                                                  Home
# 2217                                                  Home
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 58          A little above average  Yes, because I see value in code review
# 102                        Average                                       No
# 166         A little above average  Yes, because I see value in code review
# 436              Far above average  Yes, because I see value in code review
# 452                        Average  Yes, because I see value in code review
# 491                        Average  Yes, because I see value in code review
# 539         A little above average  Yes, because I see value in code review
# 770                        Average  Yes, because I see value in code review
# 789         A little above average  Yes, because I see value in code review
# 1232        A little below average  Yes, because I see value in code review
# 1381        A little above average                                       No
# 1382        A little above average                                       No
# 1411             Far above average  Yes, because I see value in code review
# 1452        A little above average  Yes, because I see value in code review
# 1573        A little above average  Yes, because I see value in code review
# 1758        A little above average  Yes, because I see value in code review
# 2113                       Average  Yes, because I see value in code review
# 2115             Far above average  Yes, because I see value in code review
# 2164        A little above average                                       No
# 2217        A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 58                 1.0                          No, but I think we should
# 102                NaN                          No, but I think we should
# 166                8.0                      Yes, it's part of our process
# 436                NaN                          No, but I think we should
# 452                5.0                      Yes, it's part of our process
# 491                2.0                      Yes, it's part of our process
# 539               10.0  Yes, it's not part of our process but the deve...
# 770                6.0                      Yes, it's part of our process
# 789                2.0  Yes, it's not part of our process but the deve...
# 1232               5.0                          No, but I think we should
# 1381               NaN                          No, but I think we should
# 1382               NaN                          No, but I think we should
# 1411               5.0                      Yes, it's part of our process
# 1452               1.0                      Yes, it's part of our process
# 1573               5.0                      Yes, it's part of our process
# 1758               3.0                      Yes, it's part of our process
# 2113               3.0                      Yes, it's part of our process
# 2115               1.0  Yes, it's not part of our process but the deve...
# 2164               NaN                          No, but I think we should
# 2217               2.0                      Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 58          Developers and management have nearly equal in...
# 102                                                  Not sure
# 166         The CTO, CIO, or other management purchase new...
# 436         The CTO, CIO, or other management purchase new...
# 452         Developers and management have nearly equal in...
# 491                                                  Not sure
# 539         The CTO, CIO, or other management purchase new...
# 770         Developers and management have nearly equal in...
# 789         Developers and management have nearly equal in...
# 1232        Developers and management have nearly equal in...
# 1381        Developers and management have nearly equal in...
# 1382        The CTO, CIO, or other management purchase new...
# 1411        The CTO, CIO, or other management purchase new...
# 1452        Developers and management have nearly equal in...
# 1573                                                 Not sure
# 1758                                                 Not sure
# 2113        Developers and management have nearly equal in...
# 2115        The CTO, CIO, or other management purchase new...
# 2164        Developers and management have nearly equal in...
# 2217        The CTO, CIO, or other management purchase new...
#
#                                 PurchaseWhat  \
# Respondent
# 58          I have a great deal of influence
# 102                    I have some influence
# 166                    I have some influence
# 436                    I have some influence
# 452            I have little or no influence
# 491            I have little or no influence
# 539            I have little or no influence
# 770            I have little or no influence
# 789            I have little or no influence
# 1232           I have little or no influence
# 1381                   I have some influence
# 1382           I have little or no influence
# 1411        I have a great deal of influence
# 1452           I have little or no influence
# 1573           I have little or no influence
# 1758                   I have some influence
# 2113                   I have some influence
# 2115                   I have some influence
# 2164        I have a great deal of influence
# 2217           I have little or no influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 58                                                C#;Java;SQL
# 102                     C#;HTML/CSS;JavaScript;SQL;TypeScript
# 166         Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 436         Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 452                                                   SQL;VBA
# 491                                          Java;Objective-C
# 539               Bash/Shell/PowerShell;JavaScript;Python;SQL
# 770                    Go;HTML/CSS;JavaScript;Python;Ruby;SQL
# 789                                              C#;F#;Python
# 1232                                  HTML/CSS;JavaScript;SQL
# 1381        Bash/Shell/PowerShell;Dart;HTML/CSS;JavaScript...
# 1382        Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 1411                      Elixir;HTML/CSS;JavaScript;Ruby;SQL
# 1452        Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 1573                                  Java;JavaScript;PHP;SQL
# 1758                                      HTML/CSS;JavaScript
# 2113        Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 2115                             C;C++;JavaScript;Python;Rust
# 2164               C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 2217        Bash/Shell/PowerShell;C++;Dart;HTML/CSS;Java;J...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 58                                      C#;F#;Java;Kotlin;SQL
# 102                          C;C++;Elixir;Go;Ruby;WebAssembly
# 166         Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 436         Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 452                                                Python;SQL
# 491                                    Java;Objective-C;Swift
# 539                           Go;JavaScript;Python;TypeScript
# 770            Go;HTML/CSS;Python;Ruby;TypeScript;WebAssembly
# 789                                         F#;Go;Python;Rust
# 1232        Java;Kotlin;Objective-C;Python;Swift;TypeScrip...
# 1381        Bash/Shell/PowerShell;C#;Dart;HTML/CSS;Java;Ja...
# 1382        Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 1411                      Elixir;HTML/CSS;JavaScript;Ruby;SQL
# 1452        Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 1573          Java;JavaScript;PHP;Python;SQL;Swift;TypeScript
# 1758                                      HTML/CSS;JavaScript
# 2113                             Elixir;Python;SQL;TypeScript
# 2115                                 C;JavaScript;Python;Rust
# 2164                HTML/CSS;JavaScript;Python;SQL;TypeScript
# 2217            Bash/Shell/PowerShell;Dart;Java;Kotlin;Python
#
#                                            DatabaseWorkedWith  \
# Respondent
# 58                         Microsoft SQL Server;Oracle;SQLite
# 102                                      Microsoft SQL Server
# 166         DynamoDB;Elasticsearch;MongoDB;PostgreSQL;Redi...
# 436                   Microsoft SQL Server;MySQL;Redis;SQLite
# 452                                      Microsoft SQL Server
# 491                                                       NaN
# 539                                         PostgreSQL;SQLite
# 770                                      MariaDB;MySQL;SQLite
# 789                                   Elasticsearch;Other(s):
# 1232                                                    MySQL
# 1381                                   Firebase;MongoDB;MySQL
# 1382                                             MySQL;SQLite
# 1411        DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQ...
# 1452                                          DynamoDB;Oracle
# 1573                               Microsoft SQL Server;MySQL
# 1758                                                   SQLite
# 2113                               PostgreSQL;Redis;Other(s):
# 2115                                                  MongoDB
# 2164                        Microsoft SQL Server;MySQL;Oracle
# 2217                                                      NaN
#
#                                     DatabaseDesireNextYear  \
# Respondent
# 58                      Microsoft SQL Server;Oracle;SQLite
# 102                              MongoDB;PostgreSQL;SQLite
# 166                                PostgreSQL;Redis;SQLite
# 436                           Couchbase;MySQL;Oracle;Redis
# 452         MongoDB;Microsoft SQL Server;Oracle;PostgreSQL
# 491                                                    NaN
# 539              Couchbase;MongoDB;PostgreSQL;Redis;SQLite
# 770                       Elasticsearch;MariaDB;PostgreSQL
# 789                                              Other(s):
# 1232                                               MongoDB
# 1381                               Firebase;MongoDB;SQLite
# 1382            Elasticsearch;Firebase;MongoDB;MySQL;Redis
# 1411               DynamoDB;Elasticsearch;PostgreSQL;Redis
# 1452                                       DynamoDB;Oracle
# 1573                                                   NaN
# 1758                                     PostgreSQL;SQLite
# 2113                                  PostgreSQL;Other(s):
# 2115                              Elasticsearch;PostgreSQL
# 2164                                  Microsoft SQL Server
# 2217                                                   NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 58                                            Android;Windows
# 102                                           Microsoft Azure
# 166                                          AWS;Docker;Linux
# 436         Android;AWS;Docker;Google Cloud Platform;Linux...
# 452                                                   Windows
# 491                                               Android;iOS
# 539                              AWS;Docker;Linux;MacOS;Slack
# 770                       AWS;Docker;Linux;Raspberry Pi;Slack
# 789                                    Docker;Microsoft Azure
# 1232                                                      NaN
# 1381                                      MacOS;Slack;Windows
# 1382        AWS;Google Cloud Platform;Linux;Slack;Windows;...
# 1411        Arduino;AWS;Docker;Google Cloud Platform;Herok...
# 1452                           AWS;Docker;Linux;MacOS;Windows
# 1573                                              AWS;Windows
# 1758                                    Google Cloud Platform
# 2113                                  AWS;Docker;Heroku;Slack
# 2115                                  Docker;Kubernetes;Linux
# 2164                                          Android;Windows
# 2217                          Android;iOS;Linux;MacOS;Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 58                               Android;Raspberry Pi;Windows
# 102                            AWS;Kubernetes;Microsoft Azure
# 166                           AWS;Docker;iOS;Kubernetes;Linux
# 436         Android;Arduino;Docker;Google Cloud Platform;L...
# 452                         AWS;Linux;Microsoft Azure;Windows
# 491                                               Android;iOS
# 539              AWS;Docker;Google Cloud Platform;Linux;MacOS
# 770               Arduino;AWS;Docker;Linux;Raspberry Pi;Slack
# 789                                                    Docker
# 1232                            Android;AWS;iOS;MacOS;Windows
# 1381                              Android;MacOS;Slack;Windows
# 1382        Android;AWS;Docker;Google Cloud Platform;iOS;L...
# 1411        Arduino;AWS;Docker;Google Cloud Platform;Herok...
# 1452                           AWS;Docker;Linux;MacOS;Windows
# 1573                                             Raspberry Pi
# 1758                                AWS;Google Cloud Platform
# 2113                             Arduino;AWS;Kubernetes;Slack
# 2115                   AWS;Docker;Google Cloud Platform;Linux
# 2164                                 Docker;Windows;WordPress
# 2217                          Android;iOS;Linux;MacOS;Windows
#
#                                    WebFrameWorkedWith  \
# Respondent
# 58                                     ASP.NET;jQuery
# 102                 ASP.NET;jQuery;React.js;Other(s):
# 166                     jQuery;React.js;Ruby on Rails
# 436                    jQuery;Laravel;React.js;Vue.js
# 452                                               NaN
# 491                                               NaN
# 539                            Express;Flask;React.js
# 770           Angular/Angular.js;jQuery;Ruby on Rails
# 789                                           ASP.NET
# 1232                                         React.js
# 1381                           Drupal;jQuery;React.js
# 1382                    Express;jQuery;Laravel;Vue.js
# 1411                             jQuery;Ruby on Rails
# 1452                 Angular/Angular.js;jQuery;Spring
# 1573                           jQuery;React.js;Spring
# 1758                                         React.js
# 2113        Angular/Angular.js;React.js;Ruby on Rails
# 2115                                          Express
# 2164                Angular/Angular.js;ASP.NET;jQuery
# 2217                                              NaN
#
#                                WebFrameDesireNextYear  \
# Respondent
# 58                  Angular/Angular.js;ASP.NET;jQuery
# 102                         Angular/Angular.js;Vue.js
# 166                            React.js;Ruby on Rails
# 436                           Laravel;React.js;Vue.js
# 452                                           ASP.NET
# 491                                               NaN
# 539                                    Flask;React.js
# 770           Angular/Angular.js;Django;Ruby on Rails
# 789                                               NaN
# 1232                                         React.js
# 1381                           Drupal;React.js;Vue.js
# 1382                  Express;Laravel;React.js;Vue.js
# 1411                                    Ruby on Rails
# 1452                 Angular/Angular.js;jQuery;Spring
# 1573                    Django;jQuery;React.js;Spring
# 1758                                         React.js
# 2113                                            Flask
# 2115                                   Flask;React.js
# 2164        Angular/Angular.js;jQuery;React.js;Vue.js
# 2217                                              NaN
#
#                                  MiscTechWorkedWith  \
# ...
# 436         Find answers to specific questions;Contribute ...
# 452         Find answers to specific questions;Learn how t...
# 491         Find answers to specific questions;Learn how t...
# 539         Find answers to specific questions;Learn how t...
# 770         Find answers to specific questions;Learn how t...
# 789                        Find answers to specific questions
# 1232                       Find answers to specific questions
# 1381        Find answers to specific questions;Learn how t...
# 1382        Find answers to specific questions;Get a sense...
# 1411                       Find answers to specific questions
# 1452                       Find answers to specific questions
# 1573        Find answers to specific questions;Contribute ...
# 1758                       Find answers to specific questions
# 2113                       Find answers to specific questions
# 2115                       Find answers to specific questions
# 2164                       Find answers to specific questions
# 2217        Find answers to specific questions;Contribute ...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 58          More than 10 times per week      Stack Overflow was much faster
# 102                  1-2 times per week      Stack Overflow was much faster
# 166             Less than once per week  Stack Overflow was slightly faster
# 436                  3-5 times per week            They were about the same
# 452                  1-2 times per week  Stack Overflow was slightly faster
# 491                  1-2 times per week            They were about the same
# 539                  3-5 times per week      Stack Overflow was much faster
# 770                  1-2 times per week  Stack Overflow was slightly faster
# 789             Less than once per week  Stack Overflow was slightly faster
# 1232                 1-2 times per week  Stack Overflow was slightly faster
# 1381                 3-5 times per week  Stack Overflow was slightly faster
# 1382                 3-5 times per week  Stack Overflow was slightly faster
# 1411                 1-2 times per week      Stack Overflow was much faster
# 1452        More than 10 times per week      Stack Overflow was much faster
# 1573                 1-2 times per week  Stack Overflow was slightly faster
# 1758                6-10 times per week            They were about the same
# 2113                6-10 times per week      Stack Overflow was much faster
# 2115                 3-5 times per week      Stack Overflow was much faster
# 2164                 3-5 times per week  Stack Overflow was slightly faster
# 2217                6-10 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 58                    NaN                        Yes
# 102           60+ minutes                        Yes
# 166         11-30 minutes                        Yes
# 436                   NaN                        Yes
# 452          0-10 minutes                        Yes
# 491                   NaN                         No
# 539          0-10 minutes                        Yes
# 770         31-60 minutes                        Yes
# 789         31-60 minutes                        Yes
# 1232        11-30 minutes                        Yes
# 1381         0-10 minutes                        Yes
# 1382        11-30 minutes                        Yes
# 1411        11-30 minutes                        Yes
# 1452          60+ minutes  Not sure / can't remember
# 1573        11-30 minutes                        Yes
# 1758                  NaN  Not sure / can't remember
# 2113        11-30 minutes                        Yes
# 2115        11-30 minutes                        Yes
# 2164        11-30 minutes                        Yes
# 2217         0-10 minutes                        Yes
#
#                                                    SOPartFreq  \
# Respondent
# 58                        Less than once per month or monthly
# 102                       Less than once per month or monthly
# 166                       Less than once per month or monthly
# 436                           A few times per month or weekly
# 452                                    Multiple times per day
# 491                                                       NaN
# 539         I have never participated in Q&A on Stack Over...
# 770         I have never participated in Q&A on Stack Over...
# 789         I have never participated in Q&A on Stack Over...
# 1232                      Less than once per month or monthly
# 1381                      Less than once per month or monthly
# 1382                      Less than once per month or monthly
# 1411                      Less than once per month or monthly
# 1452                                                      NaN
# 1573                      Less than once per month or monthly
# 1758                                                      NaN
# 2113                      Less than once per month or monthly
# 2115        I have never participated in Q&A on Stack Over...
# 2164                      Less than once per month or monthly
# 2217                      Less than once per month or monthly
#
#                                                        SOJobs  \
# Respondent
# 58          No, I knew that Stack Overflow had a job board...
# 102                                                       Yes
# 166         No, I knew that Stack Overflow had a job board...
# 436         No, I didn't know that Stack Overflow had a jo...
# 452                                                       Yes
# 491                                                       Yes
# 539         No, I knew that Stack Overflow had a job board...
# 770                                                       Yes
# 789         No, I knew that Stack Overflow had a job board...
# 1232                                                      Yes
# 1381                                                      Yes
# 1382        No, I didn't know that Stack Overflow had a jo...
# 1411                                                      Yes
# 1452        No, I didn't know that Stack Overflow had a jo...
# 1573        No, I knew that Stack Overflow had a job board...
# 1758        No, I knew that Stack Overflow had a job board...
# 2113                                                      Yes
# 2115                                                      Yes
# 2164                                                      Yes
# 2217                                                      Yes
#
#                                                      EntTeams  \
# Respondent
# 58                        No, and I don't know what those are
# 102         No, I've heard of them, but I am not part of a...
# 166         No, I've heard of them, but I am not part of a...
# 436                       No, and I don't know what those are
# 452         No, I've heard of them, but I am not part of a...
# 491         No, I've heard of them, but I am not part of a...
# 539                       No, and I don't know what those are
# 770         No, I've heard of them, but I am not part of a...
# 789         No, I've heard of them, but I am not part of a...
# 1232                      No, and I don't know what those are
# 1381        No, I've heard of them, but I am not part of a...
# 1382                      No, and I don't know what those are
# 1411                      No, and I don't know what those are
# 1452                      No, and I don't know what those are
# 1573        No, I've heard of them, but I am not part of a...
# 1758                      No, and I don't know what those are
# 2113                      No, and I don't know what those are
# 2115                      No, and I don't know what those are
# 2164        No, I've heard of them, but I am not part of a...
# 2217        No, I've heard of them, but I am not part of a...
#
#                      SOComm                             WelcomeChange  \
# Respondent
# 58           No, not really   Just as welcome now as I felt last year
# 102                 Neutral   Just as welcome now as I felt last year
# 166          No, not at all   Just as welcome now as I felt last year
# 436           Yes, somewhat   Just as welcome now as I felt last year
# 452         Yes, definitely  Somewhat more welcome now than last year
# 491                 Neutral   Just as welcome now as I felt last year
# 539          No, not really   Just as welcome now as I felt last year
# 770                 Neutral   Just as welcome now as I felt last year
# 789          No, not really   Just as welcome now as I felt last year
# 1232          Yes, somewhat   Just as welcome now as I felt last year
# 1381                Neutral   Just as welcome now as I felt last year
# 1382                Neutral   Just as welcome now as I felt last year
# 1411         No, not really   Just as welcome now as I felt last year
# 1452         No, not really   Just as welcome now as I felt last year
# 1573          Yes, somewhat  Somewhat more welcome now than last year
# 1758         No, not at all   Just as welcome now as I felt last year
# 2113                Neutral   Just as welcome now as I felt last year
# 2115          Yes, somewhat   Just as welcome now as I felt last year
# 2164         No, not really   Just as welcome now as I felt last year
# 2217        Yes, definitely  Somewhat more welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 58                                                        NaN  47.0    Man
# 102         Tech articles written by other developers;Indu...  37.0    Man
# 166                                                       NaN  30.0    Man
# 436         Tech articles written by other developers;Tech...  38.0    Man
# 452         Tech articles written by other developers;Cour...  35.0    Man
# 491         Tech articles written by other developers;Tech...  22.0    Man
# 539              Courses on technologies you're interested in  40.0    Man
# 770         Tech articles written by other developers;Tech...  29.0    Man
# 789         Tech articles written by other developers;Cour...  31.0  Woman
# 1232                Tech articles written by other developers  25.0    Man
# 1381        Tech articles written by other developers;Tech...  33.0    Man
# 1382        Tech articles written by other developers;Indu...  32.0    Man
# 1411                                                      NaN  34.0    Man
# 1452        Tech articles written by other developers;Indu...  28.0    Man
# 1573                                                      NaN  25.0    Man
# 1758                      Tech meetups or events in your area  26.0  Woman
# 2113        Tech articles written by other developers;Tech...  32.0    Man
# 2115                      Tech meetups or events in your area  29.0    Man
# 2164        Tech articles written by other developers;Indu...  26.0    Man
# 2217                Tech articles written by other developers  25.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 58            No  Straight / Heterosexual
# 102           No  Straight / Heterosexual
# 166           No  Straight / Heterosexual
# 436           No  Straight / Heterosexual
# 452           No                      NaN
# 491           No  Straight / Heterosexual
# 539           No  Straight / Heterosexual
# 770           No  Straight / Heterosexual
# 789           No                 Bisexual
# 1232          No  Straight / Heterosexual
# 1381          No  Straight / Heterosexual
# 1382          No  Straight / Heterosexual
# 1411          No  Straight / Heterosexual
# 1452          No  Straight / Heterosexual
# 1573          No  Straight / Heterosexual
# 1758          No  Straight / Heterosexual
# 2113          No  Straight / Heterosexual
# 2115          No  Straight / Heterosexual
# 2164          No  Straight / Heterosexual
# 2217          No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 58                               White or of European descent        Yes
# 102                              White or of European descent        Yes
# 166                              White or of European descent         No
# 436                              White or of European descent        Yes
# 452                              White or of European descent         No
# 491         Hispanic or Latino/Latina;White or of European...         No
# 539                              White or of European descent        Yes
# 770                              White or of European descent         No
# 789                                               South Asian         No
# 1232                                               East Asian         No
# 1381                             White or of European descent         No
# 1382                             White or of European descent         No
# 1411                             White or of European descent        Yes
# 1452                             White or of European descent        Yes
# 1573                             White or of European descent         No
# 1758                             White or of European descent         No
# 2113                             White or of European descent        Yes
# 2115        Black or of African descent;White or of Europe...        Yes
# 2164        Black or of African descent;White or of Europe...         No
# 2217                             White or of European descent        Yes
#
#                      SurveyLength                  SurveyEase fullname
# Respondent
# 58                            NaN                        Easy      NaN
# 102                      Too long                        Easy      NaN
# 166         Appropriate in length  Neither easy nor difficult      NaN
# 436                      Too long                        Easy      NaN
# 452         Appropriate in length                        Easy      NaN
# 491         Appropriate in length  Neither easy nor difficult      NaN
# 539         Appropriate in length                        Easy      NaN
# 770         Appropriate in length                        Easy      NaN
# 789         Appropriate in length  Neither easy nor difficult      NaN
# 1232        Appropriate in length  Neither easy nor difficult      NaN
# 1381        Appropriate in length                        Easy      NaN
# 1382                     Too long                        Easy      NaN
# 1411                     Too long                        Easy      NaN
# 1452                     Too long  Neither easy nor difficult      NaN
# 1573                     Too long  Neither easy nor difficult      NaN
# 1758        Appropriate in length                        Easy      NaN
# 2113                     Too long                        Easy      NaN
# 2115        Appropriate in length  Neither easy nor difficult      NaN
# 2164        Appropriate in length                        Easy      NaN
# 2217        Appropriate in length  Neither easy nor difficult      NaN

# %% [markdown]
# # 6. სტატისტიკური ოპერაციები

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df.ConvertedComp.describe()
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df.ConvertedComp.describe().apply(lambda x: format(x, 'f'))
# Out:
# count      55823.000000
# mean      127110.738423
# std       284152.303842
# min            0.000000
# 25%        25777.500000
# 50%        57287.000000
# 75%       100000.000000
# max      2000000.000000
# Name: ConvertedComp, dtype: object

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df.describe().apply(lambda x: x.apply('{0:.2f}'.format))
# Out:
#                   CompTotal ConvertedComp WorkWeekHrs CodeRevHrs       Age
# count              55945.00      55823.00    64503.00   49790.00  79210.00
# mean        551901414118.76     127110.74       42.13       5.08     30.34
# std       73319262253434.70     284152.30       37.29       5.51      9.18
# min                    0.00          0.00        1.00       0.00      1.00
# 25%                20000.00      25777.50       40.00       2.00     24.00
# 50%                62000.00      57287.00       40.00       4.00     29.00
# 75%               120000.00     100000.00       44.75       6.00     35.00
# max    10000000000000000.00    2000000.00     4850.00      99.00     99.00

# %%
df.ConvertedComp.mean()
# Out:
# 127110.73842323056

# %%
df.ConvertedComp.std()
# Out:
# 284152.3038420774

# %%
df.Hobbyist.value_counts(normalize=True)*100
# Out:
# Yes    80.169436
# No     19.830564
# Name: Hobbyist, dtype: float64

# %%
df.ConvertedComp.mean()
# Out:
# 127110.73842323056

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('Georgia')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 774                            I am a developer by profession      Yes
# 2019                           I am a developer by profession       No
# 2036                           I am a developer by profession      Yes
# 4703                           I am a developer by profession      Yes
# 4704                           I am a developer by profession      Yes
# 5933                           I am a developer by profession      Yes
# 7464                           I am a developer by profession      Yes
# 8679                              I code primarily as a hobby      Yes
# 9590                           I am a developer by profession       No
# 9657                           I am a developer by profession      Yes
# 10909                          I am a developer by profession      Yes
# 13494                  I am a student who is learning to code      Yes
# 13623                          I am a developer by profession      Yes
# 13780                          I am a developer by profession      Yes
# 14013                          I am a developer by profession      Yes
# 14918                          I am a developer by profession      Yes
# 15096                          I am a developer by profession      Yes
# 15445                          I am a developer by profession      Yes
# 17822                          I am a developer by profession       No
# 19861                          I am a developer by profession       No
# 23808                  I am a student who is learning to code      Yes
# 27617                          I am a developer by profession      Yes
# 28147                          I am a developer by profession      Yes
# 28399                  I am a student who is learning to code      Yes
# 29693                             I code primarily as a hobby      Yes
# 30436                          I am a developer by profession       No
# 31561                             I code primarily as a hobby      Yes
# 32966                          I am a developer by profession       No
# 34021                          I am a developer by profession       No
# 34214                          I am a developer by profession       No
# 35026                  I am a student who is learning to code      Yes
# 37311                          I am a developer by profession      Yes
# 37750                          I am a developer by profession      Yes
# 38074                  I am a student who is learning to code      Yes
# 38974                          I am a developer by profession      Yes
# 42831                          I am a developer by profession      Yes
# 42839                  I am a student who is learning to code      Yes
# 43123                          I am a developer by profession      Yes
# 46536                          I am a developer by profession      Yes
# 47067       I am not primarily a developer, but I write co...      Yes
# 48586                          I am a developer by profession       No
# 49832                  I am a student who is learning to code       No
# 52685                          I am a developer by profession       No
# 52824                          I am a developer by profession      Yes
# 52855                          I am a developer by profession      Yes
# 54612                          I am a developer by profession      Yes
# 55308                          I am a developer by profession      Yes
# 58996       I am not primarily a developer, but I write co...      Yes
# 59330                          I am a developer by profession      Yes
# 60063                          I am a developer by profession      Yes
# 60365                          I am a developer by profession      Yes
# 61831                          I am a developer by profession       No
# 62191                          I am a developer by profession      Yes
# 62834                          I am a developer by profession      Yes
# 64615                          I am a developer by profession       No
# 64990                          I am a developer by profession      Yes
# 66632                          I am a developer by profession      Yes
# 67712                          I am a developer by profession      Yes
# 68956                          I am a developer by profession      Yes
# 71132                          I am a developer by profession       No
# 72347                          I am a developer by profession      Yes
# 72502                  I am a student who is learning to code      Yes
# 72794                          I am a developer by profession      Yes
# 73096                          I am a developer by profession      Yes
# 75985                  I am a student who is learning to code      Yes
# 76170                          I am a developer by profession       No
# 76780                          I am a developer by profession      Yes
# 77272                          I am a developer by profession      Yes
# 80032                  I am a student who is learning to code      Yes
# 80433       I am not primarily a developer, but I write co...      Yes
# 80621                  I am a student who is learning to code      Yes
# 81833                          I am a developer by profession       No
# 82030       I am not primarily a developer, but I write co...      Yes
# 82968       I am not primarily a developer, but I write co...      Yes
# 83079                          I am a developer by profession       No
# 83152                          I am a developer by profession      Yes
# 84099                          I am a developer by profession      Yes
# 87571                          I am a developer by profession      Yes
# 43870                                                     NaN      Yes
# 46303                                                     NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 774                                Once a month or more often
# 2019                               Once a month or more often
# 2036                                                    Never
# 4703                                                    Never
# 4704                                                    Never
# 5933        Less than once a month but more than once per ...
# 7464                                                    Never
# 8679                                                    Never
# 9590        Less than once a month but more than once per ...
# 9657                                  Less than once per year
# 10909                                                   Never
# 13494       Less than once a month but more than once per ...
# 13623                                 Less than once per year
# 13780                                 Less than once per year
# 14013       Less than once a month but more than once per ...
# 14918                                                   Never
# 15096       Less than once a month but more than once per ...
# 15445       Less than once a month but more than once per ...
# 17822       Less than once a month but more than once per ...
# 19861                                                   Never
# 23808                                                   Never
# 27617                                                   Never
# 28147       Less than once a month but more than once per ...
# 28399                                                   Never
# 29693                                                   Never
# 30436                                 Less than once per year
# 31561                                 Less than once per year
# 32966                                                   Never
# 34021                                                   Never
# 34214       Less than once a month but more than once per ...
# 35026                                 Less than once per year
# 37311       Less than once a month but more than once per ...
# 37750       Less than once a month but more than once per ...
# 38074                              Once a month or more often
# 38974       Less than once a month but more than once per ...
# 42831                                                   Never
# 42839                              Once a month or more often
# 43123                                 Less than once per year
# 46536                                 Less than once per year
# 47067                                                   Never
# 48586       Less than once a month but more than once per ...
# 49832       Less than once a month but more than once per ...
# 52685                                                   Never
# 52824                              Once a month or more often
# 52855       Less than once a month but more than once per ...
# 54612                              Once a month or more often
# 55308                                 Less than once per year
# 58996                              Once a month or more often
# 59330                                 Less than once per year
# 60063       Less than once a month but more than once per ...
# 60365                                                   Never
# 61831                                                   Never
# 62191                              Once a month or more often
# 62834                                 Less than once per year
# 64615                                                   Never
# 64990       Less than once a month but more than once per ...
# 66632                                 Less than once per year
# 67712                                                   Never
# 68956                              Once a month or more often
# 71132                                                   Never
# 72347       Less than once a month but more than once per ...
# 72502                                                   Never
# 72794                              Once a month or more often
# 73096                                 Less than once per year
# 75985                              Once a month or more often
# 76170                                                   Never
# 76780       Less than once a month but more than once per ...
# 77272                                                   Never
# 80032       Less than once a month but more than once per ...
# 80433                              Once a month or more often
# 80621       Less than once a month but more than once per ...
# 81833                                                   Never
# 82030                                 Less than once per year
# 82968       Less than once a month but more than once per ...
# 83079                              Once a month or more often
# 83152                              Once a month or more often
# 84099                                                   Never
# 87571                                 Less than once per year
# 43870                                                   Never
# 46303                              Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 774         The quality of OSS and closed source software ...
# 2019        The quality of OSS and closed source software ...
# 2036        OSS is, on average, of HIGHER quality than pro...
# 4703        OSS is, on average, of HIGHER quality than pro...
# 4704        The quality of OSS and closed source software ...
# 5933        The quality of OSS and closed source software ...
# 7464        OSS is, on average, of LOWER quality than prop...
# 8679        The quality of OSS and closed source software ...
# 9590        OSS is, on average, of HIGHER quality than pro...
# 9657        OSS is, on average, of HIGHER quality than pro...
# 10909       The quality of OSS and closed source software ...
# 13494       The quality of OSS and closed source software ...
# 13623       The quality of OSS and closed source software ...
# 13780       OSS is, on average, of HIGHER quality than pro...
# 14013       OSS is, on average, of HIGHER quality than pro...
# 14918       The quality of OSS and closed source software ...
# 15096       The quality of OSS and closed source software ...
# 15445       The quality of OSS and closed source software ...
# 17822       OSS is, on average, of HIGHER quality than pro...
# 19861       OSS is, on average, of HIGHER quality than pro...
# 23808       The quality of OSS and closed source software ...
# 27617       The quality of OSS and closed source software ...
# 28147       OSS is, on average, of HIGHER quality than pro...
# 28399       The quality of OSS and closed source software ...
# 29693       OSS is, on average, of HIGHER quality than pro...
# 30436                                                     NaN
# 31561       OSS is, on average, of LOWER quality than prop...
# 32966       OSS is, on average, of HIGHER quality than pro...
# 34021       OSS is, on average, of LOWER quality than prop...
# 34214       OSS is, on average, of HIGHER quality than pro...
# 35026       OSS is, on average, of HIGHER quality than pro...
# 37311       OSS is, on average, of HIGHER quality than pro...
# 37750       OSS is, on average, of HIGHER quality than pro...
# 38074       OSS is, on average, of HIGHER quality than pro...
# 38974       OSS is, on average, of HIGHER quality than pro...
# 42831       OSS is, on average, of HIGHER quality than pro...
# 42839       OSS is, on average, of HIGHER quality than pro...
# 43123       The quality of OSS and closed source software ...
# 46536       OSS is, on average, of HIGHER quality than pro...
# 47067       The quality of OSS and closed source software ...
# 48586       The quality of OSS and closed source software ...
# 49832       OSS is, on average, of HIGHER quality than pro...
# 52685       The quality of OSS and closed source software ...
# 52824       OSS is, on average, of HIGHER quality than pro...
# 52855       The quality of OSS and closed source software ...
# 54612       OSS is, on average, of HIGHER quality than pro...
# 55308       OSS is, on average, of HIGHER quality than pro...
# 58996       OSS is, on average, of LOWER quality than prop...
# 59330       OSS is, on average, of LOWER quality than prop...
# 60063       OSS is, on average, of HIGHER quality than pro...
# 60365       The quality of OSS and closed source software ...
# 61831       OSS is, on average, of HIGHER quality than pro...
# 62191       The quality of OSS and closed source software ...
# 62834       The quality of OSS and closed source software ...
# 64615       OSS is, on average, of HIGHER quality than pro...
# 64990       OSS is, on average, of LOWER quality than prop...
# 66632       OSS is, on average, of HIGHER quality than pro...
# 67712       OSS is, on average, of HIGHER quality than pro...
# 68956       The quality of OSS and closed source software ...
# 71132       The quality of OSS and closed source software ...
# 72347       OSS is, on average, of HIGHER quality than pro...
# 72502       OSS is, on average, of HIGHER quality than pro...
# 72794       OSS is, on average, of HIGHER quality than pro...
# 73096       The quality of OSS and closed source software ...
# 75985       OSS is, on average, of HIGHER quality than pro...
# 76170       OSS is, on average, of HIGHER quality than pro...
# 76780       OSS is, on average, of LOWER quality than prop...
# 77272       OSS is, on average, of HIGHER quality than pro...
# 80032       OSS is, on average, of HIGHER quality than pro...
# 80433       OSS is, on average, of LOWER quality than prop...
# 80621       OSS is, on average, of HIGHER quality than pro...
# 81833       OSS is, on average, of HIGHER quality than pro...
# 82030       OSS is, on average, of HIGHER quality than pro...
# 82968       OSS is, on average, of HIGHER quality than pro...
# 83079       OSS is, on average, of HIGHER quality than pro...
# 83152       OSS is, on average, of LOWER quality than prop...
# 84099       OSS is, on average, of HIGHER quality than pro...
# 87571       OSS is, on average, of HIGHER quality than pro...
# 43870                                                     NaN
# 46303       OSS is, on average, of LOWER quality than prop...
#
#                                                    Employment  Country  \
# Respondent
# 774                                        Employed full-time  Georgia
# 2019                                       Employed full-time  Georgia
# 2036                                       Employed full-time  Georgia
# 4703                                       Employed full-time  Georgia
# 4704                                       Employed full-time  Georgia
# 5933        Independent contractor, freelancer, or self-em...  Georgia
# 7464        Independent contractor, freelancer, or self-em...  Georgia
# 8679        Independent contractor, freelancer, or self-em...  Georgia
# 9590                                       Employed full-time  Georgia
# 9657                                       Employed full-time  Georgia
# 10909                                      Employed full-time  Georgia
# 13494                  Not employed, and not looking for work  Georgia
# 13623                                      Employed full-time  Georgia
# 13780                                      Employed full-time  Georgia
# 14013                                      Employed full-time  Georgia
# 14918                                      Employed full-time  Georgia
# 15096                                      Employed full-time  Georgia
# 15445                                      Employed full-time  Georgia
# 17822       Independent contractor, freelancer, or self-em...  Georgia
# 19861                                      Employed part-time  Georgia
# 23808                                      Employed full-time  Georgia
# 27617                                      Employed full-time  Georgia
# 28147                      Not employed, but looking for work  Georgia
# 28399                                      Employed part-time  Georgia
# 29693                                                     NaN  Georgia
# 30436                                      Employed full-time  Georgia
# 31561                                                     NaN  Georgia
# 32966                                      Employed full-time  Georgia
# 34021                                      Employed full-time  Georgia
# 34214       Independent contractor, freelancer, or self-em...  Georgia
# 35026                  Not employed, and not looking for work  Georgia
# 37311                                      Employed full-time  Georgia
# 37750                                      Employed full-time  Georgia
# 38074                      Not employed, but looking for work  Georgia
# 38974                                      Employed full-time  Georgia
# 42831                                      Employed full-time  Georgia
# 42839                                      Employed part-time  Georgia
# 43123                                      Employed full-time  Georgia
# 46536                                      Employed full-time  Georgia
# 47067       Independent contractor, freelancer, or self-em...  Georgia
# 48586                                      Employed part-time  Georgia
# 49832                      Not employed, but looking for work  Georgia
# 52685                                      Employed full-time  Georgia
# 52824                                      Employed full-time  Georgia
# 52855                                      Employed full-time  Georgia
# 54612       Independent contractor, freelancer, or self-em...  Georgia
# 55308       Independent contractor, freelancer, or self-em...  Georgia
# 58996                                      Employed full-time  Georgia
# 59330                                      Employed full-time  Georgia
# 60063                                      Employed full-time  Georgia
# 60365                                      Employed full-time  Georgia
# 61831                                      Employed full-time  Georgia
# 62191                                      Employed full-time  Georgia
# 62834                                      Employed full-time  Georgia
# 64615                                      Employed full-time  Georgia
# 64990       Independent contractor, freelancer, or self-em...  Georgia
# 66632                                      Employed full-time  Georgia
# 67712       Independent contractor, freelancer, or self-em...  Georgia
# 68956                                      Employed full-time  Georgia
# 71132                                      Employed full-time  Georgia
# 72347       Independent contractor, freelancer, or self-em...  Georgia
# 72502                                      Employed full-time  Georgia
# 72794                                      Employed full-time  Georgia
# 73096                                      Employed full-time  Georgia
# 75985                      Not employed, but looking for work  Georgia
# 76170                                      Employed full-time  Georgia
# 76780                                      Employed full-time  Georgia
# 77272                                      Employed full-time  Georgia
# 80032                      Not employed, but looking for work  Georgia
# 80433                                      Employed full-time  Georgia
# 80621                                      Employed full-time  Georgia
# 81833                                      Employed full-time  Georgia
# 82030                                      Employed full-time  Georgia
# 82968                                      Employed full-time  Georgia
# 83079                                      Employed full-time  Georgia
# 83152                                      Employed full-time  Georgia
# 84099                                      Employed full-time  Georgia
# 87571       Independent contractor, freelancer, or self-em...  Georgia
# 43870                                      Employed full-time  Georgia
# 46303                                      Employed full-time  Georgia
#
#                    Student                                            EdLevel  \
# Respondent
# 774                     No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2019                    No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 2036        Yes, full-time                          Primary/elementary school
# 4703                    No                          Primary/elementary school
# 4704        Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5933        Yes, part-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7464                    No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 8679                    No                          Primary/elementary school
# 9590        Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9657        Yes, part-time  Some college/university study without earning ...
# 10909                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13494       Yes, full-time                          Primary/elementary school
# 13623                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13780       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14013       Yes, full-time  Secondary school (e.g. American high school, G...
# 14918                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15096       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15445       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 17822       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 19861       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 23808                  NaN  Some college/university study without earning ...
# 27617       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28147       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28399       Yes, full-time                                                NaN
# 29693       Yes, part-time                                                NaN
# 30436                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 31561                   No                 Professional degree (JD, MD, etc.)
# 32966       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34021                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 34214                   No  Some college/university study without earning ...
# 35026       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37311       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 37750                   No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 38074       Yes, full-time  Secondary school (e.g. American high school, G...
# 38974                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42831       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42839       Yes, full-time  Some college/university study without earning ...
# 43123       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46536       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47067                   No                          Primary/elementary school
# 48586                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 49832                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52685       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52824                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52855                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 54612                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 55308                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 58996       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 59330       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 60063       Yes, part-time  Some college/university study without earning ...
# 60365       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 61831                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62191                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 62834                   No  Some college/university study without earning ...
# 64615       Yes, full-time  Secondary school (e.g. American high school, G...
# 64990                   No  Some college/university study without earning ...
# 66632                   No                 Professional degree (JD, MD, etc.)
# 67712       Yes, part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 68956                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 71132       Yes, part-time  Secondary school (e.g. American high school, G...
# 72347                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 72502       Yes, full-time                          Primary/elementary school
# 72794       Yes, full-time  Some college/university study without earning ...
# 73096                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75985                   No  Secondary school (e.g. American high school, G...
# 76170                  NaN           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76780                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77272                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 80032       Yes, full-time  Some college/university study without earning ...
# 80433       Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 80621       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 81833                   No  Secondary school (e.g. American high school, G...
# 82030                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 82968                   No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 83079       Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83152                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84099                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87571                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43870                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46303                   No                          Primary/elementary school
#
#                                                UndergradMajor  \
# Respondent
# 774         Computer science, computer engineering, or sof...
# 2019                            Web development or web design
# 2036                                                      NaN
# 4703                                                      NaN
# 4704        Computer science, computer engineering, or sof...
# 5933        Computer science, computer engineering, or sof...
# 7464        Information systems, information technology, o...
# 8679                                                      NaN
# 9590        Computer science, computer engineering, or sof...
# 9657        A natural science (ex. biology, chemistry, phy...
# 10909       Computer science, computer engineering, or sof...
# 13494                                                     NaN
# 13623       Computer science, computer engineering, or sof...
# 13780       Information systems, information technology, o...
# 14013                                                     NaN
# 14918       Information systems, information technology, o...
# 15096                                                     NaN
# 15445                           Web development or web design
# 17822                               Mathematics or statistics
# 19861       Computer science, computer engineering, or sof...
# 23808       A humanities discipline (ex. literature, histo...
# 27617                           Web development or web design
# 28147       Computer science, computer engineering, or sof...
# 28399       Computer science, computer engineering, or sof...
# 29693                           Web development or web design
# 30436       Computer science, computer engineering, or sof...
# 31561       A health science (ex. nursing, pharmacy, radio...
# 32966       Computer science, computer engineering, or sof...
# 34021       Computer science, computer engineering, or sof...
# 34214       Fine arts or performing arts (ex. graphic desi...
# 35026       Another engineering discipline (ex. civil, ele...
# 37311       Computer science, computer engineering, or sof...
# 37750       A natural science (ex. biology, chemistry, phy...
# 38074                                                     NaN
# 38974       Computer science, computer engineering, or sof...
# 42831       Computer science, computer engineering, or sof...
# 42839                           Web development or web design
# 43123       Computer science, computer engineering, or sof...
# 46536       Computer science, computer engineering, or sof...
# 47067                                                     NaN
# 48586       Computer science, computer engineering, or sof...
# 49832       Another engineering discipline (ex. civil, ele...
# 52685       Computer science, computer engineering, or sof...
# 52824       Computer science, computer engineering, or sof...
# 52855       Computer science, computer engineering, or sof...
# 54612       Computer science, computer engineering, or sof...
# 55308       Computer science, computer engineering, or sof...
# 58996       Computer science, computer engineering, or sof...
# 59330       Computer science, computer engineering, or sof...
# 60063       Computer science, computer engineering, or sof...
# 60365       Computer science, computer engineering, or sof...
# 61831       Computer science, computer engineering, or sof...
# 62191                               Mathematics or statistics
# 62834       Computer science, computer engineering, or sof...
# 64615                                                     NaN
# 64990       A business discipline (ex. accounting, finance...
# 66632       Computer science, computer engineering, or sof...
# 67712       A natural science (ex. biology, chemistry, phy...
# 68956       A business discipline (ex. accounting, finance...
# 71132                                                     NaN
# 72347                           Web development or web design
# 72502                                                     NaN
# 72794       Computer science, computer engineering, or sof...
# 73096       Computer science, computer engineering, or sof...
# 75985                                                     NaN
# 76170       Computer science, computer engineering, or sof...
# 76780       Computer science, computer engineering, or sof...
# 77272       Computer science, computer engineering, or sof...
# 80032                           Web development or web design
# 80433                               Mathematics or statistics
# 80621       Computer science, computer engineering, or sof...
# 81833                                                     NaN
# 82030       A humanities discipline (ex. literature, histo...
# 82968       Computer science, computer engineering, or sof...
# 83079       Computer science, computer engineering, or sof...
# 83152       Another engineering discipline (ex. civil, ele...
# 84099       Computer science, computer engineering, or sof...
# 87571       Computer science, computer engineering, or sof...
# 43870                                                     NaN
# 46303                                                     NaN
#
#                                                      EduOther  \
# Respondent
# 774         Taken an online course in programming or softw...
# 2019        Taken an online course in programming or softw...
# 2036        Taken an online course in programming or softw...
# 4703        Taught yourself a new language, framework, or ...
# 4704        Taken a part-time in-person course in programm...
# 5933        Taken an online course in programming or softw...
# 7464        Taught yourself a new language, framework, or ...
# 8679        Taken an online course in programming or softw...
# 9590        Taken an online course in programming or softw...
# 9657        Participated in a full-time developer training...
# 10909       Taken an online course in programming or softw...
# 13494       Taken an online course in programming or softw...
# 13623       Taken an online course in programming or softw...
# 13780       Taken an online course in programming or softw...
# 14013       Taken an online course in programming or softw...
# 14918       Taught yourself a new language, framework, or ...
# 15096       Taken an online course in programming or softw...
# 15445       Taken an online course in programming or softw...
# 17822       Taken an online course in programming or softw...
# 19861       Taken an online course in programming or softw...
# 23808       Taken an online course in programming or softw...
# 27617       Taken an online course in programming or softw...
# 28147       Taken an online course in programming or softw...
# 28399       Taken an online course in programming or softw...
# 29693       Taken an online course in programming or softw...
# 30436       Taken an online course in programming or softw...
# 31561       Taken an online course in programming or softw...
# 32966       Taken an online course in programming or softw...
# 34021       Taken an online course in programming or softw...
# 34214                                                     NaN
# 35026       Taken an online course in programming or softw...
# 37311                                                     NaN
# 37750       Taught yourself a new language, framework, or ...
# 38074       Taken an online course in programming or softw...
# 38974       Completed an industry certification program (e...
# 42831       Taken an online course in programming or softw...
# 42839       Taken an online course in programming or softw...
# 43123       Taken an online course in programming or softw...
# 46536       Taken an online course in programming or softw...
# 47067                                                     NaN
# 48586       Taken an online course in programming or softw...
# 49832       Taken an online course in programming or softw...
# 52685       Taken an online course in programming or softw...
# 52824       Taken an online course in programming or softw...
# 52855       Taken an online course in programming or softw...
# 54612       Taught yourself a new language, framework, or ...
# 55308       Taken an online course in programming or softw...
# 58996                     Contributed to open source software
# 59330       Taken an online course in programming or softw...
# 60063       Taken an online course in programming or softw...
# 60365       Taken an online course in programming or softw...
# 61831       Taken an online course in programming or softw...
# 62191                             Participated in a hackathon
# 62834       Taught yourself a new language, framework, or ...
# 64615       Taken an online course in programming or softw...
# 64990       Taken an online course in programming or softw...
# 66632       Taken an online course in programming or softw...
# 67712       Taught yourself a new language, framework, or ...
# 68956       Taken an online course in programming or softw...
# 71132       Taken an online course in programming or softw...
# 72347                                                     NaN
# 72502       Taught yourself a new language, framework, or ...
# 72794       Taken an online course in programming or softw...
# 73096       Taken an online course in programming or softw...
# 75985       Taken a part-time in-person course in programm...
# 76170       Received on-the-job training in software devel...
# 76780       Received on-the-job training in software devel...
# 77272                                                     NaN
# 80032       Taught yourself a new language, framework, or ...
# 80433       Taken a part-time in-person course in programm...
# 80621       Taken an online course in programming or softw...
# 81833                                                     NaN
# 82030       Taken an online course in programming or softw...
# 82968       Taken an online course in programming or softw...
# 83079                     Contributed to open source software
# 83152       Taught yourself a new language, framework, or ...
# 84099                             Participated in a hackathon
# 87571       Taken an online course in programming or softw...
# 43870       Taught yourself a new language, framework, or ...
# 46303                                                     NaN
#
#                                                       OrgSize  \
# Respondent
# 774                                        20 to 99 employees
# 2019                                       10 to 19 employees
# 2036                                     100 to 499 employees
# 4703                                       20 to 99 employees
# 4704                                       20 to 99 employees
# 5933                                            2-9 employees
# 7464                                            2-9 employees
# 8679        Just me - I am a freelancer, sole proprietor, ...
# 9590                                            2-9 employees
# 9657                                     100 to 499 employees
# 10909                                      20 to 99 employees
# 13494                                                     NaN
# 13623                                1,000 to 4,999 employees
# 13780                                           2-9 employees
# 14013                                      20 to 99 employees
# 14918                                           2-9 employees
# 15096                                      10 to 19 employees
# 15445                                      10 to 19 employees
# 17822       Just me - I am a freelancer, sole proprietor, ...
# 19861                                           2-9 employees
# 23808                                                     NaN
# 27617                                                     NaN
# 28147                                                     NaN
# 28399                                                     NaN
# 29693                                                     NaN
# 30436                                                     NaN
# 31561                                                     NaN
# 32966                                           2-9 employees
# 34021                                           2-9 employees
# 34214                                           2-9 employees
# 35026                                                     NaN
# 37311                                      20 to 99 employees
# 37750                                           2-9 employees
# 38074                                                     NaN
# 38974                                1,000 to 4,999 employees
# 42831                                      20 to 99 employees
# 42839                                                     NaN
# 43123                                      10 to 19 employees
# 46536                                10,000 or more employees
# 47067       Just me - I am a freelancer, sole proprietor, ...
# 48586                                      20 to 99 employees
# 49832                                                     NaN
# 52685                                      10 to 19 employees
# 52824                                      20 to 99 employees
# 52855                                      10 to 19 employees
# 54612       Just me - I am a freelancer, sole proprietor, ...
# 55308                                      20 to 99 employees
# 58996                                    500 to 999 employees
# 59330                                      20 to 99 employees
# 60063                                    100 to 499 employees
# 60365                                      20 to 99 employees
# 61831                                      10 to 19 employees
# 62191                                1,000 to 4,999 employees
# 62834                                    100 to 499 employees
# 64615                                           2-9 employees
# 64990                                           2-9 employees
# 66632                                      10 to 19 employees
# 67712       Just me - I am a freelancer, sole proprietor, ...
# 68956                                      10 to 19 employees
# 71132                                           2-9 employees
# 72347       Just me - I am a freelancer, sole proprietor, ...
# 72502                                                     NaN
# 72794                                      10 to 19 employees
# 73096                                    100 to 499 employees
# 75985                                                     NaN
# 76170                                      10 to 19 employees
# 76780                                           2-9 employees
# 77272                                    500 to 999 employees
# 80032                                                     NaN
# 80433                                                     NaN
# 80621                                                     NaN
# 81833       Just me - I am a freelancer, sole proprietor, ...
# 82030                                      20 to 99 employees
# 82968                                    100 to 499 employees
# 83079                                      20 to 99 employees
# 83152                                5,000 to 9,999 employees
# 84099                                      20 to 99 employees
# 87571       Just me - I am a freelancer, sole proprietor, ...
# 43870                                      10 to 19 employees
# 46303                                    100 to 499 employees
#
#                                                       DevType  \
# Respondent
# 774                                       Developer, back-end
# 2019        Academic researcher;Data or business analyst;D...
# 2036        Developer, back-end;Developer, desktop or ente...
# 4703        Developer, back-end;Developer, desktop or ente...
# 4704                            Developer, full-stack;Student
# 5933        Developer, back-end;Developer, front-end;Devel...
# 7464                              Developer, game or graphics
# 8679                                     Developer, front-end
# 9590        Developer, back-end;Developer, front-end;Devel...
# 9657        Developer, back-end;Developer, front-end;Devel...
# 10909       Developer, back-end;Developer, front-end;Devel...
# 13494                                                     NaN
# 13623       Data or business analyst;Database administrato...
# 13780       Developer, front-end;Developer, mobile;Enginee...
# 14013       Developer, embedded applications or devices;De...
# 14918                                   Developer, full-stack
# 15096       Developer, back-end;Developer, front-end;Devel...
# 15445       Developer, back-end;Developer, front-end;Devel...
# 17822       Data or business analyst;Developer, front-end;...
# 19861                             Developer, back-end;Student
# 23808                            Developer, front-end;Student
# 27617                           Developer, full-stack;Student
# 28147       Developer, front-end;Developer, full-stack;Edu...
# 28399       Database administrator;Developer, back-end;Dev...
# 29693                                                     NaN
# 30436       Data or business analyst;Data scientist or mac...
# 31561                                                     NaN
# 32966                                     Developer, back-end
# 34021       Database administrator;Designer;Developer, bac...
# 34214       Designer;Developer, back-end;Developer, deskto...
# 35026                                                     NaN
# 37311       Developer, back-end;Developer, front-end;Devel...
# 37750       Academic researcher;Developer, back-end;Develo...
# 38074       Data scientist or machine learning specialist;...
# 38974       Developer, back-end;Developer, desktop or ente...
# 42831       Developer, back-end;Developer, front-end;Devel...
# 42839       Developer, back-end;Developer, desktop or ente...
# ...
# 80032                     Tech meetups or events in your area  21.0
# 80433       Industry news about technologies you're intere...  25.0
# 80621       Tech articles written by other developers;Indu...  20.0
# 81833       Tech articles written by other developers;Indu...  43.0
# 82030       Tech articles written by other developers;Cour...  29.0
# 82968       Tech articles written by other developers;Indu...  34.0
# 83079       Tech articles written by other developers;Indu...  19.0
# 83152       Tech articles written by other developers;Indu...  32.0
# 84099       Tech articles written by other developers;Cour...  29.0
# 87571       Industry news about technologies you're intere...  23.0
# 43870       Industry news about technologies you're intere...  30.0
# 46303                     Tech meetups or events in your area   NaN
#
#                Gender Trans                Sexuality  \
# Respondent
# 774             Woman    No                      NaN
# 2019              Man    No                      NaN
# 2036              Man    No  Straight / Heterosexual
# 4703              Man    No  Straight / Heterosexual
# 4704              Man    No  Straight / Heterosexual
# 5933              Man    No  Straight / Heterosexual
# 7464              Man    No  Straight / Heterosexual
# 8679              Man    No  Straight / Heterosexual
# 9590        Woman;Man    No                      NaN
# 9657              Man    No  Straight / Heterosexual
# 10909             Man    No  Straight / Heterosexual
# 13494             Man    No  Straight / Heterosexual
# 13623             Man    No  Straight / Heterosexual
# 13780             Man    No  Straight / Heterosexual
# 14013             Man    No  Straight / Heterosexual
# 14918             Man    No  Straight / Heterosexual
# 15096             Man    No  Straight / Heterosexual
# 15445             Man    No  Straight / Heterosexual
# 17822             Man    No  Straight / Heterosexual
# 19861             Man    No  Straight / Heterosexual
# 23808             Man    No  Straight / Heterosexual
# 27617             NaN   NaN                      NaN
# 28147             Man    No  Straight / Heterosexual
# 28399             Man    No  Straight / Heterosexual
# 29693             Man    No  Straight / Heterosexual
# 30436           Woman    No                      NaN
# 31561             Man    No  Straight / Heterosexual
# 32966             Man    No  Straight / Heterosexual
# 34021             Man    No  Straight / Heterosexual
# 34214             Man    No  Straight / Heterosexual
# 35026             Man    No  Straight / Heterosexual
# 37311             Man    No  Straight / Heterosexual
# 37750             Man    No  Straight / Heterosexual
# 38074             Man    No                      NaN
# 38974             Man    No  Straight / Heterosexual
# 42831             Man   NaN  Straight / Heterosexual
# 42839             Man    No  Straight / Heterosexual
# 43123             Man   NaN  Straight / Heterosexual
# 46536             NaN   NaN                      NaN
# 47067             Man    No                      NaN
# 48586             Man    No  Straight / Heterosexual
# 49832           Woman    No  Straight / Heterosexual
# 52685           Woman    No                 Bisexual
# 52824             Man   NaN  Straight / Heterosexual
# 52855             Man    No  Straight / Heterosexual
# 54612             Man    No  Straight / Heterosexual
# 55308             Man    No  Straight / Heterosexual
# 58996             Man    No  Straight / Heterosexual
# 59330             Man    No  Straight / Heterosexual
# 60063             Man    No  Straight / Heterosexual
# 60365             Man   NaN  Straight / Heterosexual
# 61831             Man    No  Straight / Heterosexual
# 62191             Man    No  Straight / Heterosexual
# 62834             Man    No  Straight / Heterosexual
# 64615             Man    No  Straight / Heterosexual
# 64990             Man    No  Straight / Heterosexual
# 66632             Man    No  Straight / Heterosexual
# 67712             Man    No  Straight / Heterosexual
# 68956             Man    No  Straight / Heterosexual
# 71132           Woman    No                      NaN
# 72347             Man    No  Straight / Heterosexual
# 72502             Man    No  Straight / Heterosexual
# 72794             Man    No  Straight / Heterosexual
# 73096             Man    No  Straight / Heterosexual
# 75985             Man    No  Straight / Heterosexual
# 76170             Man    No  Straight / Heterosexual
# 76780             Man    No  Straight / Heterosexual
# 77272             Man   NaN  Straight / Heterosexual
# 80032             Man    No                      NaN
# 80433             Man    No  Straight / Heterosexual
# 80621           Woman    No                      NaN
# 81833             Man    No  Straight / Heterosexual
# 82030             Man    No  Straight / Heterosexual
# 82968             Man    No  Straight / Heterosexual
# 83079             Man    No  Straight / Heterosexual
# 83152             Man    No  Straight / Heterosexual
# 84099             Man    No  Straight / Heterosexual
# 87571             Man    No  Straight / Heterosexual
# 43870           Woman   NaN                 Bisexual
# 46303             NaN    No  Straight / Heterosexual
#
#                                Ethnicity Dependents           SurveyLength  \
# Respondent
# 774         White or of European descent         No               Too long
# 2019         Black or of African descent        Yes               Too long
# 2036        White or of European descent        Yes  Appropriate in length
# 4703        White or of European descent        Yes  Appropriate in length
# 4704        White or of European descent        Yes  Appropriate in length
# 5933        White or of European descent         No  Appropriate in length
# 7464        White or of European descent        Yes  Appropriate in length
# 8679        White or of European descent         No  Appropriate in length
# 9590                                 NaN        NaN  Appropriate in length
# 9657        White or of European descent        Yes  Appropriate in length
# 10909       White or of European descent        Yes  Appropriate in length
# 13494       White or of European descent        NaN  Appropriate in length
# 13623       White or of European descent        Yes  Appropriate in length
# 13780                                NaN         No               Too long
# 14013       White or of European descent         No               Too long
# 14918       White or of European descent        Yes  Appropriate in length
# 15096       White or of European descent        Yes  Appropriate in length
# 15445       White or of European descent        Yes  Appropriate in length
# 17822       White or of European descent         No  Appropriate in length
# 19861       White or of European descent        Yes  Appropriate in length
# 23808       White or of European descent         No  Appropriate in length
# 27617                                NaN        NaN  Appropriate in length
# 28147       White or of European descent         No  Appropriate in length
# 28399       White or of European descent        NaN  Appropriate in length
# 29693       White or of European descent        Yes  Appropriate in length
# 30436                                NaN        NaN               Too long
# 31561       White or of European descent         No  Appropriate in length
# 32966       White or of European descent         No               Too long
# 34021       White or of European descent        Yes  Appropriate in length
# 34214                        South Asian        Yes  Appropriate in length
# 35026       White or of European descent        Yes  Appropriate in length
# 37311       White or of European descent         No               Too long
# 37750       White or of European descent        Yes  Appropriate in length
# 38074                                NaN         No  Appropriate in length
# 38974       White or of European descent        Yes  Appropriate in length
# 42831       White or of European descent         No  Appropriate in length
# 42839       White or of European descent        Yes               Too long
# 43123       White or of European descent         No               Too long
# 46536                                NaN        NaN                    NaN
# 47067       White or of European descent         No  Appropriate in length
# 48586                     Middle Eastern        Yes               Too long
# 49832       White or of European descent         No  Appropriate in length
# 52685       White or of European descent         No  Appropriate in length
# 52824       White or of European descent         No               Too long
# 52855       White or of European descent        Yes  Appropriate in length
# 54612       White or of European descent        Yes  Appropriate in length
# 55308                                NaN        Yes  Appropriate in length
# 58996                                NaN        Yes  Appropriate in length
# 59330       White or of European descent         No  Appropriate in length
# 60063       White or of European descent        Yes              Too short
# 60365       White or of European descent        Yes              Too short
# 61831       White or of European descent         No  Appropriate in length
# 62191                                NaN         No               Too long
# 62834       White or of European descent        Yes               Too long
# 64615                                NaN         No  Appropriate in length
# 64990       White or of European descent        Yes  Appropriate in length
# 66632                                NaN        Yes               Too long
# 67712       White or of European descent         No  Appropriate in length
# 68956       White or of European descent         No  Appropriate in length
# 71132       White or of European descent         No  Appropriate in length
# 72347       White or of European descent        NaN  Appropriate in length
# 72502       White or of European descent         No  Appropriate in length
# 72794       White or of European descent         No  Appropriate in length
# 73096                                NaN         No               Too long
# 75985       White or of European descent         No               Too long
# 76170       White or of European descent         No  Appropriate in length
# 76780       White or of European descent        Yes  Appropriate in length
# 77272                                NaN        NaN               Too long
# 80032                                NaN        NaN                    NaN
# 80433       White or of European descent         No               Too long
# 80621       White or of European descent        Yes               Too long
# 81833                     Middle Eastern        Yes               Too long
# 82030       White or of European descent        Yes  Appropriate in length
# 82968       White or of European descent        Yes  Appropriate in length
# 83079       White or of European descent         No  Appropriate in length
# 83152       White or of European descent        Yes  Appropriate in length
# 84099                                NaN         No               Too long
# 87571       White or of European descent         No  Appropriate in length
# 43870       White or of European descent        Yes  Appropriate in length
# 46303        Black or of African descent        Yes  Appropriate in length
#
#                             SurveyEase fullname
# Respondent
# 774         Neither easy nor difficult      NaN
# 2019                              Easy      NaN
# 2036                              Easy      NaN
# 4703        Neither easy nor difficult      NaN
# 4704        Neither easy nor difficult      NaN
# 5933                              Easy      NaN
# 7464                              Easy      NaN
# 8679                              Easy      NaN
# 9590                              Easy      NaN
# 9657                              Easy      NaN
# 10909                             Easy      NaN
# 13494                             Easy      NaN
# 13623                             Easy      NaN
# 13780                        Difficult      NaN
# 14013                             Easy      NaN
# 14918                             Easy      NaN
# 15096       Neither easy nor difficult      NaN
# 15445       Neither easy nor difficult      NaN
# 17822       Neither easy nor difficult      NaN
# 19861                             Easy      NaN
# 23808                             Easy      NaN
# 27617                             Easy      NaN
# 28147                             Easy      NaN
# 28399                             Easy      NaN
# 29693                             Easy      NaN
# 30436                             Easy      NaN
# 31561                             Easy      NaN
# 32966                             Easy      NaN
# 34021                             Easy      NaN
# 34214                             Easy      NaN
# 35026                             Easy      NaN
# 37311                        Difficult      NaN
# 37750                             Easy      NaN
# 38074       Neither easy nor difficult      NaN
# 38974                             Easy      NaN
# 42831       Neither easy nor difficult      NaN
# 42839                             Easy      NaN
# 43123       Neither easy nor difficult      NaN
# 46536                              NaN      NaN
# 47067                        Difficult      NaN
# 48586       Neither easy nor difficult      NaN
# 49832                             Easy      NaN
# 52685                             Easy      NaN
# 52824                             Easy      NaN
# 52855                             Easy      NaN
# 54612                             Easy      NaN
# 55308       Neither easy nor difficult      NaN
# 58996       Neither easy nor difficult      NaN
# 59330                             Easy      NaN
# 60063       Neither easy nor difficult      NaN
# 60365       Neither easy nor difficult      NaN
# 61831       Neither easy nor difficult      NaN
# 62191                             Easy      NaN
# 62834                             Easy      NaN
# 64615       Neither easy nor difficult      NaN
# 64990                             Easy      NaN
# 66632                             Easy      NaN
# 67712       Neither easy nor difficult      NaN
# 68956       Neither easy nor difficult      NaN
# 71132                             Easy      NaN
# 72347                             Easy      NaN
# 72502                             Easy      NaN
# 72794                              NaN      NaN
# 73096                             Easy      NaN
# 75985                             Easy      NaN
# 76170                             Easy      NaN
# 76780       Neither easy nor difficult      NaN
# 77272                              NaN      NaN
# 80032                              NaN      NaN
# 80433       Neither easy nor difficult      NaN
# 80621                        Difficult      NaN
# 81833       Neither easy nor difficult      NaN
# 82030                             Easy      NaN
# 82968                             Easy      NaN
# 83079                             Easy      NaN
# 83152                             Easy      NaN
# 84099       Neither easy nor difficult      NaN
# 87571       Neither easy nor difficult      NaN
# 43870       Neither easy nor difficult      NaN
# 46303                             Easy      NaN

# %%
country_grp['SocialMedia'].value_counts().head(30)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#              LinkedIn                     1
#              Twitter                      1
# Albania      WhatsApp                    18
#              Facebook                    16
#              Instagram                   13
#              YouTube                     10
#              Twitter                      8
#              LinkedIn                     7
#              Reddit                       6
#              I don't use social media     4
#              Snapchat                     1
#              WeChat 微信                    1
# Algeria      YouTube                     42
#              Facebook                    41
#              Twitter                     14
#              LinkedIn                     9
#              I don't use social media     7
#              Instagram                    7
#              Reddit                       2
#              WhatsApp                     2
# Andorra      Facebook                     2
#              I don't use social media     2
#              Reddit                       1
#              Snapchat                     1
#              YouTube                      1
# Name: SocialMedia, dtype: int64

# %%
country_grp['ConvertedComp'].mean().Georgia
# Out:
# 42008.204081632655

# %%
country_grp['ConvertedComp'].mean().Germany
# Out:
# 109256.8840656432
